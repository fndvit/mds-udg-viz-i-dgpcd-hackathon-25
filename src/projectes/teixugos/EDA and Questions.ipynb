# %% [markdown]
# # EDA

# %% [markdown]
# > Autors: Ivan Aguilar, Marc Serrano, Pau Maranges, Oksana K., Juan Diego Bustamante, Alam
# >
# > Data: 08/02/2025

# %% [markdown]
# ### Notebook preparation

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)

# %%
from IPython.display import display
import pandas as pd
import pandas as pd
from google.colab import files
import io
import requests

# %% [markdown]
# ## Read and clean dataset

# %%
certificats = pd.read_csv("/content/drive/MyDrive/HACKATHON_PROVES/certificats.csv")

# %%
display(certificats)
# Out:
#            num_cas                   adre_a numero escala  pis porta  \
# 0        BMGDF6CPF        Plaça Constitució      3    NaN  NaN   NaN
# 1        YT0MZMXMG        Carrer de la Font     44    NaN  NaN   NaN
# 2        D4F3KFL7T  Avinguda LLUIS COMPANYS     25    NaN    4     3
# 3        WNCV3P13M        Carrer de la Font     27    NaN  NaN   NaN
# 4        9K0RVRLD4         Carrer SANT PERE      4    NaN   AT     1
# ...            ...                      ...    ...    ...  ...   ...
# 1336920  WGVBWQCCS         Partida Mas Grau      1    NaN  NaN   NaN
# 1336921  J20RTDPHP         Carrer Torrentet      8    NaN   BJ    4ª
# 1336922  L0C4VRTWB          Carrer Pau Coll     11    NaN    3   NaN
# 1336923  YQF488ZVJ   Paseo RAFAEL CAMPALANS    S/N      A    0     1
# 1336924  34XQR8KYB        Avinguda BENESTAR     17    NaN  NaN   NaN
#
#          codi_postal                    poblacio         comarca  \
# 0             8630.0                      Abrera  Baix Llobregat
# 1             8630.0                      Abrera  Baix Llobregat
# 2             8630.0                      Abrera  Baix Llobregat
# 3             8630.0                      Abrera  Baix Llobregat
# 4             8630.0                      Abrera  Baix Llobregat
# ...              ...                         ...             ...
# 1336920      43775.0                       Marçà         Priorat
# 1336921       8505.0  Santa Eulàlia de Riuprimer           Osona
# 1336922      25630.0                      Talarn   Pallars Jussà
# 1336923      43830.0               Torredembarra      Tarragonès
# 1336924       8505.0  Santa Eulàlia de Riuprimer           Osona
#
#         nom_provincia  ...  qualificaci_energia_2  \
# 0           Barcelona  ...                    NaN
# 1           Barcelona  ...                    NaN
# 2           Barcelona  ...                    NaN
# 3           Barcelona  ...                    NaN
# 4           Barcelona  ...                      D
# ...               ...  ...                    ...
# 1336920     Tarragona  ...                      B
# 1336921     Barcelona  ...                    NaN
# 1336922        Lleida  ...                      G
# 1336923     Tarragona  ...                      G
# 1336924     Barcelona  ...                      D
#
#          energia_refrigeraci_demanda  ventilacio_us_residencial  longitud  \
# 0                                NaN                        NaN  1.901261
# 1                                NaN                       0.63  1.902843
# 2                                NaN                        NaN  1.899301
# 3                                NaN                       0.63  1.903057
# 4                               9.91                        NaN  1.902255
# ...                              ...                        ...       ...
# 1336920                        12.65                        NaN       NaN
# 1336921                         0.02                       0.63  2.190868
# 1336922                        57.57                        NaN  0.899886
# 1336923                       144.09                        NaN  1.402140
# 1336924                        12.24                        NaN  2.186559
#
#            latitud                           georeferencia  \
# 0        41.515900  POINT (1.901261244149 41.515899972165)
# 1        41.513518  POINT (1.902843106253 41.513517711742)
# 2        41.515738   POINT (1.899300634003 41.51573845805)
# 3        41.513610  POINT (1.903056537018 41.513609820129)
# 4        41.513983  POINT (1.902255349697 41.513983450863)
# ...            ...                                     ...
# 1336920        NaN                                     NaN
# 1336921  41.912715  POINT (2.190867874724 41.912715454327)
# 1336922  42.185600  POINT (0.899885987426 42.185599824229)
# 1336923  41.135469  POINT (1.402139949595 41.135468924025)
# 1336924  41.910682   POINT (2.186558796006 41.91068209703)
#
#          rehabilitacio_energetica actuacions_rehabilitacio data_entrada  \
# 0                             NaN                      NaN   26/01/2016
# 1                             NaN                      NaN   16/11/2015
# 2                             NaN                      NaN   22/04/2016
# 3                             NaN                      NaN   22/04/2015
# 4                              NO                      NaN   02/06/2023
# ...                           ...                      ...          ...
# 1336920                        NO                      NaN   07/01/2025
# 1336921                       NaN                      NaN   06/06/2016
# 1336922                        NO                      NaN   30/09/2019
# 1336923                        NO                      NaN   14/04/2021
# 1336924                        NO                      NaN   11/08/2022
#
#             mundissec
# 0        8.001801e+09
# 1        8.001801e+09
# 2        8.001801e+09
# 3        8.001801e+09
# 4        8.001801e+09
# ...               ...
# 1336920           NaN
# 1336921           NaN
# 1336922           NaN
# 1336923           NaN
# 1336924           NaN
#
# [1336925 rows x 70 columns]

# %% [markdown]
# A simple vista tenim columnes que no necessitem:
#
#   - **adre_a** (Nom del carrer):	És informació textual sense rellevància per l’eficiència energètica.
#
#   - **numero, escala, pis, porta**: Dades específiques de l'adreça que no tenen impacte en l’anàlisi energètic.
#
#   - **codi_postal**: Si ja tenim el codi de província i codi de població, el codi postal és redundant.
#
#   - **poblacio, comarca, nom_provincia**:	No són necessaris si ja tenim els codis (codi_poblacio, codi_comarca, codi_provincia), que són més fàcils d'usar que text.
#
#   - **vehicle_electric**:	Disposar d’un vehicle elèctric no influeix en l’eficiència energètica global de l’edifici.
#
#   - **eina_de_certificacio**:	No afecta el consum energètic; només indica l'eina utilitzada per a la certificació.
#
#   - **motiu_de_la_certificacio**:	No és rellevant per a l'anàlisi del consum d’energia i emissions.
#
#   - **normativa_construccio**:	La normativa pot ser important en altres contextos, però no aporta informació directa sobre l’eficiència de l’edifici.
#
#   - **actuacions_rehabilitacio**:	Pot ser útil en altres tipus d’anàlisis, però aquí no aporta dades quantitatives sobre el consum o les emissions.

# %%
# Llista de columnes a eliminar
columnes_a_eliminar = [
    "adre_a", "numero", "escala", "pis", "porta", "codi_postal", "poblacio",
    "comarca", "nom_provincia", "vehicle_electric", "eina_de_certificacio",
    "motiu_de_la_certificacio", "normativa_construcci", "actuacions_rehabilitacio"
]

# Eliminar columnes
certificats = certificats.drop(columns=columnes_a_eliminar)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-07474c5dfff5> in <cell line: 0>()
#       7
#       8 # Eliminar columnes
# ----> 9 certificats = certificats.drop(columns=columnes_a_eliminar)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['adre_a', 'numero', 'escala', 'pis', 'porta', 'codi_postal', 'poblacio', 'comarca', 'nom_provincia', 'vehicle_electric', 'eina_de_certificacio', 'motiu_de_la_certificacio', 'normativa_construcci', 'actuacions_rehabilitacio'] not found in axis"

# %%
certificats.shape

# %%
# Calcular el porcentaje de valores nulos por columna
porcentaje_nulos = certificats.isnull().sum() / len(certificats) * 100
# Filtrar columnas con 70% o más de valores nulos
columnas_mas_70_nulos = porcentaje_nulos[porcentaje_nulos >= 70].index
print(porcentaje_nulos)
print("Columnas con 70% o más valores nulos:")
display(columnas_mas_70_nulos)

# %%
# Eliminar columnes
certificats = certificats.drop(columns=columnas_mas_70_nulos)

# %%
certificats.shape
# Out:
# (1336925, 51)

# %% [markdown]
# ### Categorical data

# %% [markdown]
# Podem veure com hi ha columnes categóriques amb un sol valor, com son: "**solar_termica**" i "**solar_fotovoltaica**". Aquest tipus de columnes no aporten informació rellevant per a l'anàlisi, ja que no permeten cap tipus de diferenciació entre les observacions, per tant, també s'eliminen.

# %%
categorical_columns = certificats.select_dtypes(include=['object']).columns
display(certificats[categorical_columns].nunique())
# Out:
# num_cas                            1336900
# referencia_cadastral               1179294
# zona_climatica                           7
# us_edifici                              11
# qualificaci_de_consum_d                  7
# qualificacio_d_emissions                 7
# solar_termica                            1
# solar_fotovoltaica                       1
# sistema_biomassa                         2
# xarxa_districte                          2
# energia_geotermica                       2
# tipus_tramit                             3
# qualificaci_emissions                    7
# qualificaci_emissions_1                  7
# qualificaci_emissions_acs                7
# qualificaci_energia_calefacci            7
# qualificaci_energia                      7
# qualificaci_energia_acs                  7
# qualificaci_energia_calefacci_1          7
# qualificaci_energia_2                    8
# georeferencia                       426554
# rehabilitacio_energetica                 2
# data_entrada                          3640
# dtype: int64

# %%
# Llista de columnes a eliminar
columnes_a_eliminar = [
    "solar_termica", "solar_fotovoltaica"
]

# Eliminar columnes
certificats = certificats.drop(columns=columnes_a_eliminar)

# %%
certificats.shape
# Out:
# (1336925, 49)

# %%
categorical_columns = certificats.select_dtypes(include=['object']).columns
for col in categorical_columns:
    print(f"Valores únicos en {col}: {certificats[col].unique()}")
# Out:
# Valores únicos en num_cas: ['BMGDF6CPF' 'YT0MZMXMG' 'D4F3KFL7T' ... 'L0C4VRTWB' 'YQF488ZVJ'
#  '34XQR8KYB']
# Valores únicos en referencia_cadastral: ['8468003DF0986N0001TA' '8566417DF0986N0001PA' '8367801DF0986N0015PX' ...
#  '6728033CG2762N0007PE' '5852701CF6555S0017UL' '2603005DG3420S0001HA']
# Valores únicos en zona_climatica: ['C2' 'D2' 'D1' nan 'C3' 'E1' 'B3' 'D3']
# Valores únicos en us_edifici: ['Habitatge unifamiliar' "Habitatge individual en bloc d'habitatges"
#  'Terciari' "Bloc d'habitatges plurifamiliar" 'Vivienda unifamiliar'
#  'Vivienda individual en bloque de viviendas' 'Terciario'
#  "Bloc d'habitatges" 'Bloque de viviendas'
#  'Bloque de viviendas plurifamiliar' 'Habitatge Unifamiliar']
# Valores únicos en qualificaci_de_consum_d: ['D' 'E' 'G' 'F' 'C' 'B' 'A']
# Valores únicos en qualificacio_d_emissions: ['D' 'E' 'F' 'G' 'C' 'B' 'A']
# Valores únicos en sistema_biomassa: ['NO' nan 'SI']
# Valores únicos en xarxa_districte: [nan 'NO' 'SI']
# Valores únicos en energia_geotermica: ['NO' 'SI' nan]
# Valores únicos en tipus_tramit: ['Edificis existents' 'Edificis existents acabats' 'Edificis acabats']
# Valores únicos en qualificaci_emissions: [nan 'E' 'C' 'D' 'F' 'G' 'B' 'A']
# Valores únicos en qualificaci_emissions_1: [nan 'C' 'B' 'A' 'D' 'E' 'F' 'G']
# Valores únicos en qualificaci_emissions_acs: [nan 'G' 'E' 'D' 'F' 'A' 'C' 'B']
# Valores únicos en qualificaci_energia_calefacci: [nan 'E' 'C' 'F' 'D' 'G' 'B' 'A']
# Valores únicos en qualificaci_energia: [nan 'D' 'B' 'C' 'A' 'E' 'G' 'F']
# Valores únicos en qualificaci_energia_acs: [nan 'G' 'F' 'E' 'B' 'C' 'D' 'A']
# Valores únicos en qualificaci_energia_calefacci_1: [nan 'G' 'C' 'E' 'F' 'D' 'B' 'A']
# Valores únicos en qualificaci_energia_2: [nan 'D' 'B' 'C' 'A' 'E' 'G' 'F' '-']
# Valores únicos en georeferencia: ['POINT (1.901261244149 41.515899972165)'
#  'POINT (1.902843106253 41.513517711742)'
#  'POINT (1.899300634003 41.51573845805)' ...
#  'POINT (0.899417757899 42.187097913344)'
#  'POINT (2.188015372842 41.910615399107)'
#  'POINT (2.186558796006 41.91068209703)']
# Valores únicos en rehabilitacio_energetica: [nan 'NO' 'SI']
# Valores únicos en data_entrada: ['26/01/2016' '16/11/2015' '22/04/2016' ... '27/08/2022' '18/01/2025'
#  '09/04/2023']

# %% [markdown]
# Transformar variables categóriques amb valors SI/NO a Numericas transformant-les en binàries

# %%
# Lista de las columnas para transformar a valores binarios
cols_a_transformar = [
    'sistema_biomassa',
    'xarxa_districte',
    'energia_geotermica',
    'rehabilitacio_energetica'
]

# Aplicar la transformación binaria
for col in cols_a_transformar:
    certificats[col] = certificats[col].map({'SI': 1, 'NO': 0})

# %%
for col in cols_a_transformar:
    print(f"Valores únicos en {col}: {certificats[col].unique()}")
# Out:
# Valores únicos en sistema_biomassa: [ 0. nan  1.]
# Valores únicos en xarxa_districte: [nan  0.  1.]
# Valores únicos en energia_geotermica: [ 0.  1. nan]
# Valores únicos en rehabilitacio_energetica: [nan  0.  1.]

# %% [markdown]
# ### Numerical data

# %%
numerical_columns = certificats.select_dtypes(include=['float64', 'int64']).columns
display(certificats[numerical_columns].nunique())
# Out:
# codi_poblacio                        948
# codi_comarca                          42
# codi_provincia                         4
# metres_cadastre                    35844
# energia_prim_ria_no_renovable      60877
# emissions_de_co2                   17910
# consum_d_energia_final             47403
# cost_anual_aproximat_d_energia    211107
# sistema_biomassa                       2
# xarxa_districte                        2
# energia_geotermica                     2
# valor_aillaments                     520
# valor_finestres                      722
# valor_aillaments_cte                   5
# valor_finestres_cte                    4
# utm_x                             417473
# utm_y                             415671
# emissions_calefacci                13605
# emissions_refrigeraci               2698
# emissions_acs                       6767
# emissions_enllumenament             5716
# energia_calefacci                  48148
# energia_refrigeraci                 9752
# energia_acs                        24607
# energia_enllumenament              16821
# energia_calefacci_demanda          31346
# energia_refrigeraci_demanda         8766
# ventilacio_us_residencial            362
# longitud                          426554
# latitud                           426554
# rehabilitacio_energetica               2
# mundissec                           5088
# dtype: int64

# %%
certificats.shape
# Out:
# (1336925, 49)

# %% [markdown]
# ### Meteorological data

# %% [markdown]
# Irradiància solar global, la velocitat i la direccio del vent, precipitació, (per centrals eòliques, hidroelectriques, posar plaques solars, etc).

# %%
url = "https://analisi.transparenciacatalunya.cat/resource/4fb2-n3yi.json?$query=SELECT%0A%20%20%60codi_variable%60%2C%0A%20%20%60nom_variable%60%2C%0A%20%20%60unitat%60%2C%0A%20%20%60acronim%60%2C%0A%20%20%60codi_tipus_var%60%2C%0A%20%20%60decimals%60"
response = requests.get(url)

if response.status_code == 200:
    data_codis_variables = response.json()  # Parse JSON response

# %%
url = "https://analisi.transparenciacatalunya.cat/resource/nzvn-apee.json?$query=SELECT%0A%20%20%60id%60%2C%0A%20%20%60codi_estacio%60%2C%0A%20%20%60codi_variable%60%2C%0A%20%20%60data_lectura%60%2C%0A%20%20%60data_extrem%60%2C%0A%20%20%60valor_lectura%60%2C%0A%20%20%60codi_estat%60%2C%0A%20%20%60codi_base%60"
response = requests.get(url)

if response.status_code == 200:
    data_lectura = response.json()  # Parse JSON response
    display(data_lectura)
# Out:
# [{'id': 'U2401901170400',
#   'codi_estacio': 'U2',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:29:00.000',
#   'valor_lectura': '-1.3',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U2421901170400',
#   'codi_estacio': 'U2',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:12:00.000',
#   'valor_lectura': '-1.7',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U2331901170400',
#   'codi_estacio': 'U2',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '67',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U2441901170400',
#   'codi_estacio': 'U2',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '66',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U2031901170400',
#   'codi_estacio': 'U2',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:10:00.000',
#   'valor_lectura': '68',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U2301901170400',
#   'codi_estacio': 'U2',
#   'codi_variable': '30',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '1.4',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U2311901170400',
#   'codi_estacio': 'U2',
#   'codi_variable': '31',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '304',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U2351901170400',
#   'codi_estacio': 'U2',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U3351901170400',
#   'codi_estacio': 'U3',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U3721901170400',
#   'codi_estacio': 'U3',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U3361901170400',
#   'codi_estacio': 'U3',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U3591901170400',
#   'codi_estacio': 'U3',
#   'codi_variable': '59',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-30',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U3321901170400',
#   'codi_estacio': 'U3',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '1.4',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U3401901170400',
#   'codi_estacio': 'U3',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:15:00.000',
#   'valor_lectura': '1.6',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U3571901170400',
#   'codi_estacio': 'U3',
#   'codi_variable': '57',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '35',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U3331901170400',
#   'codi_estacio': 'U3',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '43',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U3441901170400',
#   'codi_estacio': 'U3',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:10:00.000',
#   'valor_lectura': '41',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U3031901170400',
#   'codi_estacio': 'U3',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:23:00.000',
#   'valor_lectura': '45',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U3461901170400',
#   'codi_estacio': 'U3',
#   'codi_variable': '46',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0.8',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U3471901170400',
#   'codi_estacio': 'U3',
#   'codi_variable': '47',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '10',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U3561901170400',
#   'codi_estacio': 'U3',
#   'codi_variable': '56',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:16:00.000',
#   'valor_lectura': '2.4',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U3421901170400',
#   'codi_estacio': 'U3',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:26:00.000',
#   'valor_lectura': '1.2',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U4351901170400',
#   'codi_estacio': 'U4',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U4721901170400',
#   'codi_estacio': 'U4',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U4361901170400',
#   'codi_estacio': 'U4',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U4501901170400',
#   'codi_estacio': 'U4',
#   'codi_variable': '50',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:16:00.000',
#   'valor_lectura': '2.9',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U4511901170400',
#   'codi_estacio': 'U4',
#   'codi_variable': '51',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '314',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U4311901170400',
#   'codi_estacio': 'U4',
#   'codi_variable': '31',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '339',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U4301901170400',
#   'codi_estacio': 'U4',
#   'codi_variable': '30',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '1.3',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U4401901170400',
#   'codi_estacio': 'U4',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:19:00.000',
#   'valor_lectura': '-2.8',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U4421901170400',
#   'codi_estacio': 'U4',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:13:00.000',
#   'valor_lectura': '-2.9',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U4331901170400',
#   'codi_estacio': 'U4',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '57',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U4441901170400',
#   'codi_estacio': 'U4',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:26:00.000',
#   'valor_lectura': '56',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U4031901170400',
#   'codi_estacio': 'U4',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '57',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U4321901170400',
#   'codi_estacio': 'U4',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-2.9',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U6561901170400',
#   'codi_estacio': 'U6',
#   'codi_variable': '56',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:11:00.000',
#   'valor_lectura': '3.4',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U6721901170400',
#   'codi_estacio': 'U6',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U6361901170400',
#   'codi_estacio': 'U6',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U6401901170400',
#   'codi_estacio': 'U6',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:12:00.000',
#   'valor_lectura': '3.2',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U6421901170400',
#   'codi_estacio': 'U6',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:29:00.000',
#   'valor_lectura': '2.9',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U6331901170400',
#   'codi_estacio': 'U6',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '47',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U6351901170400',
#   'codi_estacio': 'U6',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U6031901170400',
#   'codi_estacio': 'U6',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:29:00.000',
#   'valor_lectura': '48',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U6461901170400',
#   'codi_estacio': 'U6',
#   'codi_variable': '46',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '1.1',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U6471901170400',
#   'codi_estacio': 'U6',
#   'codi_variable': '47',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '313',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U6321901170400',
#   'codi_estacio': 'U6',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '3.1',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U6571901170400',
#   'codi_estacio': 'U6',
#   'codi_variable': '57',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '289',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U6441901170400',
#   'codi_estacio': 'U6',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:12:00.000',
#   'valor_lectura': '46',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U7321901170400',
#   'codi_estacio': 'U7',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '2.6',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U7401901170400',
#   'codi_estacio': 'U7',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:16:00.000',
#   'valor_lectura': '2.7',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U7421901170400',
#   'codi_estacio': 'U7',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:01:00.000',
#   'valor_lectura': '2.5',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U7331901170400',
#   'codi_estacio': 'U7',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '51',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U7441901170400',
#   'codi_estacio': 'U7',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:14:00.000',
#   'valor_lectura': '50',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U7031901170400',
#   'codi_estacio': 'U7',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:24:00.000',
#   'valor_lectura': '51',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U7361901170400',
#   'codi_estacio': 'U7',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U7471901170400',
#   'codi_estacio': 'U7',
#   'codi_variable': '47',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '10',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U7561901170400',
#   'codi_estacio': 'U7',
#   'codi_variable': '56',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:13:00.000',
#   'valor_lectura': '7.2',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U7571901170400',
#   'codi_estacio': 'U7',
#   'codi_variable': '57',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '10',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U7351901170400',
#   'codi_estacio': 'U7',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U7721901170400',
#   'codi_estacio': 'U7',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U7461901170400',
#   'codi_estacio': 'U7',
#   'codi_variable': '46',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '3.3',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U9321901170400',
#   'codi_estacio': 'U9',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '3.1',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U9401901170400',
#   'codi_estacio': 'U9',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:23:00.000',
#   'valor_lectura': '3.3',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U9421901170400',
#   'codi_estacio': 'U9',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:02:00.000',
#   'valor_lectura': '2.8',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U9331901170400',
#   'codi_estacio': 'U9',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '43',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U9441901170400',
#   'codi_estacio': 'U9',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:22:00.000',
#   'valor_lectura': '42',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U9031901170400',
#   'codi_estacio': 'U9',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:01:00.000',
#   'valor_lectura': '44',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U9361901170400',
#   'codi_estacio': 'U9',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U9471901170400',
#   'codi_estacio': 'U9',
#   'codi_variable': '47',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '345',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U9561901170400',
#   'codi_estacio': 'U9',
#   'codi_variable': '56',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:23:00.000',
#   'valor_lectura': '7.1',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U9571901170400',
#   'codi_estacio': 'U9',
#   'codi_variable': '57',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '329',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U9351901170400',
#   'codi_estacio': 'U9',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U9721901170400',
#   'codi_estacio': 'U9',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'U9461901170400',
#   'codi_estacio': 'U9',
#   'codi_variable': '46',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '2.6',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VA461901170400',
#   'codi_estacio': 'VA',
#   'codi_variable': '46',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '2',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VA471901170400',
#   'codi_estacio': 'VA',
#   'codi_variable': '47',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '288',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VA321901170400',
#   'codi_estacio': 'VA',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-0.9',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VA721901170400',
#   'codi_estacio': 'VA',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VA361901170400',
#   'codi_estacio': 'VA',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VA561901170400',
#   'codi_estacio': 'VA',
#   'codi_variable': '56',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:15:00.000',
#   'valor_lectura': '5.7',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VA031901170400',
#   'codi_estacio': 'VA',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:12:00.000',
#   'valor_lectura': '66',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VA351901170400',
#   'codi_estacio': 'VA',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VA401901170400',
#   'codi_estacio': 'VA',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-0.8',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VA421901170400',
#   'codi_estacio': 'VA',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:14:00.000',
#   'valor_lectura': '-0.9',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VA331901170400',
#   'codi_estacio': 'VA',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '66',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VA441901170400',
#   'codi_estacio': 'VA',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '66',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VA571901170400',
#   'codi_estacio': 'VA',
#   'codi_variable': '57',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '271',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VB351901170400',
#   'codi_estacio': 'VB',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VB721901170400',
#   'codi_estacio': 'VB',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VB361901170400',
#   'codi_estacio': 'VB',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VB321901170400',
#   'codi_estacio': 'VB',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-0.1',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VB401901170400',
#   'codi_estacio': 'VB',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-0.1',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VB421901170400',
#   'codi_estacio': 'VB',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:13:00.000',
#   'valor_lectura': '-0.2',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VB511901170400',
#   'codi_estacio': 'VB',
#   'codi_variable': '51',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '43',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VB441901170400',
#   'codi_estacio': 'VB',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '66',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VB031901170400',
#   'codi_estacio': 'VB',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:12:00.000',
#   'valor_lectura': '67',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VB301901170400',
#   'codi_estacio': 'VB',
#   'codi_variable': '30',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '2.4',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VB311901170400',
#   'codi_estacio': 'VB',
#   'codi_variable': '31',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '40',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VB501901170400',
#   'codi_estacio': 'VB',
#   'codi_variable': '50',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:29:00.000',
#   'valor_lectura': '3.5',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VB331901170400',
#   'codi_estacio': 'VB',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '66',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VC721901170400',
#   'codi_estacio': 'VC',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VC361901170400',
#   'codi_estacio': 'VC',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VC461901170400',
#   'codi_estacio': 'VC',
#   'codi_variable': '46',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '3.1',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VC471901170400',
#   'codi_estacio': 'VC',
#   'codi_variable': '47',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '255',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VC561901170400',
#   'codi_estacio': 'VC',
#   'codi_variable': '56',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:09:00.000',
#   'valor_lectura': '5.6',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VC571901170400',
#   'codi_estacio': 'VC',
#   'codi_variable': '57',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '263',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VC331901170400',
#   'codi_estacio': 'VC',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '72',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VC441901170400',
#   'codi_estacio': 'VC',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:11:00.000',
#   'valor_lectura': '69',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VC031901170400',
#   'codi_estacio': 'VC',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:21:00.000',
#   'valor_lectura': '74',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VC321901170400',
#   'codi_estacio': 'VC',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-0.5',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VC401901170400',
#   'codi_estacio': 'VC',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:22:00.000',
#   'valor_lectura': '-0.4',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VC421901170400',
#   'codi_estacio': 'VC',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-0.6',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VC351901170400',
#   'codi_estacio': 'VC',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VD461901170400',
#   'codi_estacio': 'VD',
#   'codi_variable': '46',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0.1',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VD361901170400',
#   'codi_estacio': 'VD',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VD471901170400',
#   'codi_estacio': 'VD',
#   'codi_variable': '47',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '85',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VD561901170400',
#   'codi_estacio': 'VD',
#   'codi_variable': '56',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:28:00.000',
#   'valor_lectura': '0.6',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VD571901170400',
#   'codi_estacio': 'VD',
#   'codi_variable': '57',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '99',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VD351901170400',
#   'codi_estacio': 'VD',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VD031901170400',
#   'codi_estacio': 'VD',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:09:00.000',
#   'valor_lectura': '78',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VD321901170400',
#   'codi_estacio': 'VD',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-3.8',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VD401901170400',
#   'codi_estacio': 'VD',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-3.7',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VD421901170400',
#   'codi_estacio': 'VD',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:18:00.000',
#   'valor_lectura': '-3.8',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VD331901170400',
#   'codi_estacio': 'VD',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '77',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VD441901170400',
#   'codi_estacio': 'VD',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '76',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VD721901170400',
#   'codi_estacio': 'VD',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VE441901170400',
#   'codi_estacio': 'VE',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:03:00.000',
#   'valor_lectura': '87',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VE031901170400',
#   'codi_estacio': 'VE',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:18:00.000',
#   'valor_lectura': '88',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VE721901170400',
#   'codi_estacio': 'VE',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VE361901170400',
#   'codi_estacio': 'VE',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VE461901170400',
#   'codi_estacio': 'VE',
#   'codi_variable': '46',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0.2',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VE471901170400',
#   'codi_estacio': 'VE',
#   'codi_variable': '47',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '65',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VE331901170400',
#   'codi_estacio': 'VE',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '87',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VE571901170400',
#   'codi_estacio': 'VE',
#   'codi_variable': '57',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '74',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VE351901170400',
#   'codi_estacio': 'VE',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VE321901170400',
#   'codi_estacio': 'VE',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-3.5',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VE401901170400',
#   'codi_estacio': 'VE',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-3.4',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VE421901170400',
#   'codi_estacio': 'VE',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:25:00.000',
#   'valor_lectura': '-3.5',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VE561901170400',
#   'codi_estacio': 'VE',
#   'codi_variable': '56',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0.8',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VH461901170400',
#   'codi_estacio': 'VH',
#   'codi_variable': '46',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VH471901170400',
#   'codi_estacio': 'VH',
#   'codi_variable': '47',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '214',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VH561901170400',
#   'codi_estacio': 'VH',
#   'codi_variable': '56',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:29:00.000',
#   'valor_lectura': '0.5',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VH571901170400',
#   'codi_estacio': 'VH',
#   'codi_variable': '57',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '214',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VH351901170400',
#   'codi_estacio': 'VH',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VH721901170400',
#   'codi_estacio': 'VH',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VH331901170400',
#   'codi_estacio': 'VH',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '87',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VH441901170400',
#   'codi_estacio': 'VH',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:09:00.000',
#   'valor_lectura': '86',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VH031901170400',
#   'codi_estacio': 'VH',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '88',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VH321901170400',
#   'codi_estacio': 'VH',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-5',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VH401901170400',
#   'codi_estacio': 'VH',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:09:00.000',
#   'valor_lectura': '-4.8',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VH421901170400',
#   'codi_estacio': 'VH',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:29:00.000',
#   'valor_lectura': '-5.4',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VH361901170400',
#   'codi_estacio': 'VH',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VK311901170400',
#   'codi_estacio': 'VK',
#   'codi_variable': '31',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '104',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VK301901170400',
#   'codi_estacio': 'VK',
#   'codi_variable': '30',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '1.7',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VK511901170400',
#   'codi_estacio': 'VK',
#   'codi_variable': '51',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '109',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VK351901170400',
#   'codi_estacio': 'VK',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VK721901170400',
#   'codi_estacio': 'VK',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VK361901170400',
#   'codi_estacio': 'VK',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VK341901170400',
#   'codi_estacio': 'VK',
#   'codi_variable': '34',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '989.4',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VK011901170400',
#   'codi_estacio': 'VK',
#   'codi_variable': '1',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '989.5',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VK021901170400',
#   'codi_estacio': 'VK',
#   'codi_variable': '2',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:22:00.000',
#   'valor_lectura': '989.3',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VK321901170400',
#   'codi_estacio': 'VK',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-5.3',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VK401901170400',
#   'codi_estacio': 'VK',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:24:00.000',
#   'valor_lectura': '-5',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VK421901170400',
#   'codi_estacio': 'VK',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:02:00.000',
#   'valor_lectura': '-5.6',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VK331901170400',
#   'codi_estacio': 'VK',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '84',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VK441901170400',
#   'codi_estacio': 'VK',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:25:00.000',
#   'valor_lectura': '83',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VK031901170400',
#   'codi_estacio': 'VK',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:03:00.000',
#   'valor_lectura': '86',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VK501901170400',
#   'codi_estacio': 'VK',
#   'codi_variable': '50',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '2',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VM461901170400',
#   'codi_estacio': 'VM',
#   'codi_variable': '46',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0.6',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VM471901170400',
#   'codi_estacio': 'VM',
#   'codi_variable': '47',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '308',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VM561901170400',
#   'codi_estacio': 'VM',
#   'codi_variable': '56',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:23:00.000',
#   'valor_lectura': '1.2',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VM571901170400',
#   'codi_estacio': 'VM',
#   'codi_variable': '57',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '309',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VM351901170400',
#   'codi_estacio': 'VM',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VM721901170400',
#   'codi_estacio': 'VM',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VM031901170400',
#   'codi_estacio': 'VM',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:02:00.000',
#   'valor_lectura': '86',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VM321901170400',
#   'codi_estacio': 'VM',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-6.4',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VM401901170400',
#   'codi_estacio': 'VM',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:20:00.000',
#   'valor_lectura': '-6.3',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VM421901170400',
#   'codi_estacio': 'VM',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-6.5',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VM331901170400',
#   'codi_estacio': 'VM',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '86',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VM441901170400',
#   'codi_estacio': 'VM',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:13:00.000',
#   'valor_lectura': '85',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VM361901170400',
#   'codi_estacio': 'VM',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VN321901170400',
#   'codi_estacio': 'VN',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-4',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VN401901170400',
#   'codi_estacio': 'VN',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-3.9',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VN421901170400',
#   'codi_estacio': 'VN',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:29:00.000',
#   'valor_lectura': '-4.3',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VN721901170400',
#   'codi_estacio': 'VN',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VN441901170400',
#   'codi_estacio': 'VN',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:23:00.000',
#   'valor_lectura': '74',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VN031901170400',
#   'codi_estacio': 'VN',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:29:00.000',
#   'valor_lectura': '81',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VN351901170400',
#   'codi_estacio': 'VN',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VN331901170400',
#   'codi_estacio': 'VN',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '75',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VO321901170400',
#   'codi_estacio': 'VO',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-5.3',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VO441901170400',
#   'codi_estacio': 'VO',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:08:00.000',
#   'valor_lectura': '67',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VO031901170400',
#   'codi_estacio': 'VO',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:29:00.000',
#   'valor_lectura': '71',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VO461901170400',
#   'codi_estacio': 'VO',
#   'codi_variable': '46',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0.5',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VO401901170400',
#   'codi_estacio': 'VO',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:06:00.000',
#   'valor_lectura': '-5',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VO421901170400',
#   'codi_estacio': 'VO',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:29:00.000',
#   'valor_lectura': '-5.9',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VO361901170400',
#   'codi_estacio': 'VO',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VO471901170400',
#   'codi_estacio': 'VO',
#   'codi_variable': '47',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '105',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VO561901170400',
#   'codi_estacio': 'VO',
#   'codi_variable': '56',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:18:00.000',
#   'valor_lectura': '1.9',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VO571901170400',
#   'codi_estacio': 'VO',
#   'codi_variable': '57',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '78',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VO351901170400',
#   'codi_estacio': 'VO',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VO721901170400',
#   'codi_estacio': 'VO',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VO331901170400',
#   'codi_estacio': 'VO',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '69',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VP721901170400',
#   'codi_estacio': 'VP',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VP361901170400',
#   'codi_estacio': 'VP',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VP401901170400',
#   'codi_estacio': 'VP',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-5.1',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VP031901170400',
#   'codi_estacio': 'VP',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:29:00.000',
#   'valor_lectura': '80',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VP481901170400',
#   'codi_estacio': 'VP',
#   'codi_variable': '48',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0.4',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VP491901170400',
#   'codi_estacio': 'VP',
#   'codi_variable': '49',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '205',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VP321901170400',
#   'codi_estacio': 'VP',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-5.3',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VP541901170400',
#   'codi_estacio': 'VP',
#   'codi_variable': '54',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '231',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VP351901170400',
#   'codi_estacio': 'VP',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VP421901170400',
#   'codi_estacio': 'VP',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:29:00.000',
#   'valor_lectura': '-5.5',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VP331901170400',
#   'codi_estacio': 'VP',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '79',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VP441901170400',
#   'codi_estacio': 'VP',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:03:00.000',
#   'valor_lectura': '79',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VP531901170400',
#   'codi_estacio': 'VP',
#   'codi_variable': '53',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:03:00.000',
#   'valor_lectura': '1.5',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VQ321901170400',
#   'codi_estacio': 'VQ',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '1.8',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VQ021901170400',
#   'codi_estacio': 'VQ',
#   'codi_variable': '2',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:16:00.000',
#   'valor_lectura': '1007.3',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VQ421901170400',
#   'codi_estacio': 'VQ',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0.4',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VQ331901170400',
#   'codi_estacio': 'VQ',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '50',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VQ441901170400',
#   'codi_estacio': 'VQ',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:29:00.000',
#   'valor_lectura': '41',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VQ031901170400',
#   'codi_estacio': 'VQ',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:03:00.000',
#   'valor_lectura': '59',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VQ301901170400',
#   'codi_estacio': 'VQ',
#   'codi_variable': '30',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '2.7',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VQ311901170400',
#   'codi_estacio': 'VQ',
#   'codi_variable': '31',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '17',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VQ501901170400',
#   'codi_estacio': 'VQ',
#   'codi_variable': '50',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:24:00.000',
#   'valor_lectura': '5.1',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VQ511901170400',
#   'codi_estacio': 'VQ',
#   'codi_variable': '51',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '20',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VQ351901170400',
#   'codi_estacio': 'VQ',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VQ721901170400',
#   'codi_estacio': 'VQ',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VQ361901170400',
#   'codi_estacio': 'VQ',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VQ591901170400',
#   'codi_estacio': 'VQ',
#   'codi_variable': '59',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-8',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'VQ341901170400',
#   'codi_estacio': 'VQ',
#   'codi_variable': '34',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '1007.4',
# ...
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XN421901170400',
#   'codi_estacio': 'XN',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:25:00.000',
#   'valor_lectura': '-3.2',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XN331901170400',
#   'codi_estacio': 'XN',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '88',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XN361901170400',
#   'codi_estacio': 'XN',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XN441901170400',
#   'codi_estacio': 'XN',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:16:00.000',
#   'valor_lectura': '86',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XN031901170400',
#   'codi_estacio': 'XN',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '90',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XN461901170400',
#   'codi_estacio': 'XN',
#   'codi_variable': '46',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0.7',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XN401901170400',
#   'codi_estacio': 'XN',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:15:00.000',
#   'valor_lectura': '-2.8',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XN561901170400',
#   'codi_estacio': 'XN',
#   'codi_variable': '56',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:04:00.000',
#   'valor_lectura': '1.8',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XN571901170400',
#   'codi_estacio': 'XN',
#   'codi_variable': '57',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '77',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XN351901170400',
#   'codi_estacio': 'XN',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XN721901170400',
#   'codi_estacio': 'XN',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XN321901170400',
#   'codi_estacio': 'XN',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-3',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XN471901170400',
#   'codi_estacio': 'XN',
#   'codi_variable': '47',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '39',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XO721901170400',
#   'codi_estacio': 'XO',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XO321901170400',
#   'codi_estacio': 'XO',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-4.2',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XO401901170400',
#   'codi_estacio': 'XO',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:01:00.000',
#   'valor_lectura': '-3.9',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XO351901170400',
#   'codi_estacio': 'XO',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XO331901170400',
#   'codi_estacio': 'XO',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '82',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XO441901170400',
#   'codi_estacio': 'XO',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:09:00.000',
#   'valor_lectura': '81',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XO031901170400',
#   'codi_estacio': 'XO',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:28:00.000',
#   'valor_lectura': '83',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XO421901170400',
#   'codi_estacio': 'XO',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:27:00.000',
#   'valor_lectura': '-4.5',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XP361901170400',
#   'codi_estacio': 'XP',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XP031901170400',
#   'codi_estacio': 'XP',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:10:00.000',
#   'valor_lectura': '71',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XP461901170400',
#   'codi_estacio': 'XP',
#   'codi_variable': '46',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '2',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XP471901170400',
#   'codi_estacio': 'XP',
#   'codi_variable': '47',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '268',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XP561901170400',
#   'codi_estacio': 'XP',
#   'codi_variable': '56',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:05:00.000',
#   'valor_lectura': '4',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XP571901170400',
#   'codi_estacio': 'XP',
#   'codi_variable': '57',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '282',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XP441901170400',
#   'codi_estacio': 'XP',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:02:00.000',
#   'valor_lectura': '70',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XP721901170400',
#   'codi_estacio': 'XP',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XP321901170400',
#   'codi_estacio': 'XP',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-1.3',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XP401901170400',
#   'codi_estacio': 'XP',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-1.3',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XP421901170400',
#   'codi_estacio': 'XP',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:29:00.000',
#   'valor_lectura': '-1.4',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XP331901170400',
#   'codi_estacio': 'XP',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '71',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XP351901170400',
#   'codi_estacio': 'XP',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XQ421901170400',
#   'codi_estacio': 'XQ',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-6.6',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XQ331901170400',
#   'codi_estacio': 'XQ',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '73',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XQ441901170400',
#   'codi_estacio': 'XQ',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:29:00.000',
#   'valor_lectura': '71',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XQ401901170400',
#   'codi_estacio': 'XQ',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:28:00.000',
#   'valor_lectura': '-5.9',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XQ351901170400',
#   'codi_estacio': 'XQ',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XQ721901170400',
#   'codi_estacio': 'XQ',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XQ321901170400',
#   'codi_estacio': 'XQ',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-6.2',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XQ031901170400',
#   'codi_estacio': 'XQ',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:04:00.000',
#   'valor_lectura': '74',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XR401901170400',
#   'codi_estacio': 'XR',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:16:00.000',
#   'valor_lectura': '-3.8',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XR441901170400',
#   'codi_estacio': 'XR',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:22:00.000',
#   'valor_lectura': '53',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XR031901170400',
#   'codi_estacio': 'XR',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:03:00.000',
#   'valor_lectura': '56',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XR421901170400',
#   'codi_estacio': 'XR',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-4',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XR331901170400',
#   'codi_estacio': 'XR',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '54',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XR381901170400',
#   'codi_estacio': 'XR',
#   'codi_variable': '38',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XR321901170400',
#   'codi_estacio': 'XR',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-3.9',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XR471901170400',
#   'codi_estacio': 'XR',
#   'codi_variable': '47',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '308',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XR561901170400',
#   'codi_estacio': 'XR',
#   'codi_variable': '56',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:23:00.000',
#   'valor_lectura': '3.1',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XR571901170400',
#   'codi_estacio': 'XR',
#   'codi_variable': '57',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '298',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XR351901170400',
#   'codi_estacio': 'XR',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XR721901170400',
#   'codi_estacio': 'XR',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XR361901170400',
#   'codi_estacio': 'XR',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XR461901170400',
#   'codi_estacio': 'XR',
#   'codi_variable': '46',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '1.6',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XS401901170400',
#   'codi_estacio': 'XS',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:16:00.000',
#   'valor_lectura': '-1.6',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XS421901170400',
#   'codi_estacio': 'XS',
#   'codi_variable': '42',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:04:00.000',
#   'valor_lectura': '-2.3',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XS331901170400',
#   'codi_estacio': 'XS',
#   'codi_variable': '33',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '58',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XS441901170400',
#   'codi_estacio': 'XS',
#   'codi_variable': '44',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:29:00.000',
#   'valor_lectura': '55',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XS031901170400',
#   'codi_estacio': 'XS',
#   'codi_variable': '3',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:04:00.000',
#   'valor_lectura': '61',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XS311901170400',
#   'codi_estacio': 'XS',
#   'codi_variable': '31',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '340',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XS301901170400',
#   'codi_estacio': 'XS',
#   'codi_variable': '30',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '1.3',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XS511901170400',
#   'codi_estacio': 'XS',
#   'codi_variable': '51',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '304',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XS351901170400',
#   'codi_estacio': 'XS',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XS721901170400',
#   'codi_estacio': 'XS',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XS361901170400',
#   'codi_estacio': 'XS',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XS321901170400',
#   'codi_estacio': 'XS',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-1.9',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XS501901170400',
#   'codi_estacio': 'XS',
#   'codi_variable': '50',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:02:00.000',
#   'valor_lectura': '2.6',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XT401901170400',
#   'codi_estacio': 'XT',
#   'codi_variable': '40',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:27:00.000',
#   'valor_lectura': '-4.9',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XT351901170400',
#   'codi_estacio': 'XT',
#   'codi_variable': '35',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XT721901170400',
#   'codi_estacio': 'XT',
#   'codi_variable': '72',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XT361901170400',
#   'codi_estacio': 'XT',
#   'codi_variable': '36',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '0',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XT341901170400',
#   'codi_estacio': 'XT',
#   'codi_variable': '34',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '940.4',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XT321901170400',
#   'codi_estacio': 'XT',
#   'codi_variable': '32',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'valor_lectura': '-5.6',
#   'codi_estat': 'V',
#   'codi_base': 'SH'},
#  {'id': 'XT021901170400',
#   'codi_estacio': 'XT',
#   'codi_variable': '2',
#   'data_lectura': '2017-01-19T04:00:00.000',
#   'data_extrem': '2017-01-19T04:26:00.000',
#   'valor_lectura': '940.2',
#   'codi_estat': 'V',
#   'codi_base': 'SH'}]

# %%
url = "https://analisi.transparenciacatalunya.cat/resource/yqwd-vj5e.json?$query=SELECT%0A%20%20%60codi_estacio%60%2C%0A%20%20%60nom_estacio%60%2C%0A%20%20%60codi_tipus%60%2C%0A%20%20%60latitud%60%2C%0A%20%20%60longitud%60%2C%0A%20%20%60geocoded_column%60%2C%0A%20%20%60emplacament%60%2C%0A%20%20%60altitud%60%2C%0A%20%20%60codi_municipi%60%2C%0A%20%20%60nom_municipi%60%2C%0A%20%20%60codi_comarca%60%2C%0A%20%20%60nom_comarca%60%2C%0A%20%20%60codi_provincia%60%2C%0A%20%20%60nom_provincia%60%2C%0A%20%20%60codi_xarxa%60%2C%0A%20%20%60nom_xarxa%60%2C%0A%20%20%60codi_estat_ema%60%2C%0A%20%20%60nom_estat_ema%60%2C%0A%20%20%60data_inici%60%2C%0A%20%20%60data_fi%60"
response = requests.get(url)

if response.status_code == 200:
    data_estacions = response.json()  # Parse JSON response
    display(data_estacions)
# Out:
# [{'codi_estacio': 'DH',
#   'nom_estacio': 'Badalona - Mas Ram',
#   'codi_tipus': 'A',
#   'latitud': '41.47638',
#   'longitud': '2.25213',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.25213, 41.47638]},
#   'emplacament': 'Urb. Mas Ram - Escola Pere Vergès',
#   'altitud': '126',
#   'codi_municipi': '080155',
#   'nom_municipi': 'Badalona',
#   'codi_comarca': '13',
#   'nom_comarca': 'Barcelonès',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1998-03-23T00:00:00.000',
#   'data_fi': '2005-09-08T00:00:00.000'},
#  {'codi_estacio': 'WQ',
#   'nom_estacio': "Montsec d'Ares (1.572 m)",
#   'codi_tipus': 'A',
#   'latitud': '42.0513',
#   'longitud': '0.72952',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.72952, 42.0513]},
#   'emplacament': "Serra de la Corona - Centre d'Observació de l'Univers",
#   'altitud': '1572',
#   'codi_municipi': '251961',
#   'nom_municipi': 'Sant Esteve de la Sarga',
#   'codi_comarca': '25',
#   'nom_comarca': 'Pallars Jussà',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2003-06-17T00:00:00.000'},
#  {'codi_estacio': 'XJ',
#   'nom_estacio': 'Girona',
#   'codi_tipus': 'A',
#   'latitud': '41.98223',
#   'longitud': '2.80686',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.80686, 41.98223]},
#   'emplacament': 'Horts de Santa Eugènia',
#   'altitud': '72',
#   'codi_municipi': '170792',
#   'nom_municipi': 'Girona',
#   'codi_comarca': '20',
#   'nom_comarca': 'Gironès',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2010-09-15T00:00:00.000'},
#  {'codi_estacio': 'KX',
#   'nom_estacio': 'la Roca del Vallès - ETAP Cardedeu',
#   'codi_tipus': 'A',
#   'latitud': '41.61865',
#   'longitud': '2.36114',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.36114, 41.61865]},
#   'emplacament': "Planta tractament d'Aigües Ter - Llobregat",
#   'altitud': '156',
#   'codi_municipi': '081810',
#   'nom_municipi': 'La Roca del Vallès',
#   'codi_comarca': '41',
#   'nom_comarca': 'Vallès Oriental',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1996-01-05T00:00:00.000'},
#  {'codi_estacio': 'VY',
#   'nom_estacio': 'Nulles',
#   'codi_tipus': 'A',
#   'latitud': '41.25095',
#   'longitud': '1.29863',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.29863, 41.25095]},
#   'emplacament': 'Cooperativa agrària',
#   'altitud': '240',
#   'codi_municipi': '430982',
#   'nom_municipi': 'Nulles',
#   'codi_comarca': '1',
#   'nom_comarca': 'Alt Camp',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2000-09-18T00:00:00.000'},
#  {'codi_estacio': 'CW',
#   'nom_estacio': "l'Espluga de Francolí",
#   'codi_tipus': 'A',
#   'latitud': '41.39241',
#   'longitud': '1.09894',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.09894, 41.39241]},
#   'emplacament': 'Urb. Espluga Parc',
#   'altitud': '446',
#   'codi_municipi': '430542',
#   'nom_municipi': "L'Espluga de Francolí",
#   'codi_comarca': '16',
#   'nom_comarca': 'Conca de Barberà',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1996-02-23T00:00:00.000'},
#  {'codi_estacio': 'M6',
#   'nom_estacio': 'Sant Joan de les Abadesses',
#   'codi_tipus': 'A',
#   'latitud': '42.22189',
#   'longitud': '2.2427',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.2427, 42.22189]},
#   'emplacament': 'Agrupació Esportiva del Ripollès',
#   'altitud': '730',
#   'codi_municipi': '171674',
#   'nom_municipi': 'Sant Joan de les Abadesses',
#   'codi_comarca': '31',
#   'nom_comarca': 'Ripollès',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1996-01-13T00:00:00.000'},
#  {'codi_estacio': 'UV',
#   'nom_estacio': 'Mas de Barberans - Mitanplana',
#   'codi_tipus': 'A',
#   'latitud': '40.71727',
#   'longitud': '0.41633',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.41633, 40.71727]},
#   'emplacament': 'Finca del Sifonero',
#   'altitud': '205',
#   'codi_municipi': '430770',
#   'nom_municipi': 'Mas de Barberans',
#   'codi_comarca': '22',
#   'nom_comarca': 'Montsià',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1992-11-17T00:00:00.000',
#   'data_fi': '2011-01-03T00:00:00.000'},
#  {'codi_estacio': 'C7',
#   'nom_estacio': 'Tàrrega',
#   'codi_tipus': 'A',
#   'latitud': '41.66695',
#   'longitud': '1.16234',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.16234, 41.66695]},
#   'emplacament': 'Abocador comarcal',
#   'altitud': '427',
#   'codi_municipi': '252173',
#   'nom_municipi': 'Tàrrega',
#   'codi_comarca': '38',
#   'nom_comarca': 'Urgell',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1995-11-06T00:00:00.000'},
#  {'codi_estacio': 'W1',
#   'nom_estacio': "Castelló d'Empúries",
#   'codi_tipus': 'A',
#   'latitud': '42.24726',
#   'longitud': '3.09021',
#   'geocoded_column': {'type': 'Point', 'coordinates': [3.09021, 42.24726]},
#   'emplacament': 'Can Garriga - Mas Bellesguard',
#   'altitud': '2',
#   'codi_municipi': '170470',
#   'nom_municipi': "Castelló d'Empúries",
#   'codi_comarca': '2',
#   'nom_comarca': 'Alt Empordà',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2000-03-14T00:00:00.000'},
#  {'codi_estacio': 'X6',
#   'nom_estacio': 'Baldomar',
#   'codi_tipus': 'A',
#   'latitud': '41.92173',
#   'longitud': '1.02901',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.02901, 41.92173]},
#   'emplacament': 'Baldomar',
#   'altitud': '366',
#   'codi_municipi': '250349',
#   'nom_municipi': 'Artesa de Segre',
#   'codi_comarca': '23',
#   'nom_comarca': 'Noguera',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2006-10-24T00:00:00.000'},
#  {'codi_estacio': 'CA',
#   'nom_estacio': 'Clariana de Cardener',
#   'codi_tipus': 'A',
#   'latitud': '41.95378',
#   'longitud': '1.5851',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.5851, 41.95378]},
#   'emplacament': 'Abocador comarcal',
#   'altitud': '693',
#   'codi_municipi': '250753',
#   'nom_municipi': 'Clariana de Cardener',
#   'codi_comarca': '35',
#   'nom_comarca': 'Solsonès',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1996-05-02T00:00:00.000',
#   'data_fi': '2012-07-10T00:00:00.000'},
#  {'codi_estacio': 'D4',
#   'nom_estacio': 'Roses',
#   'codi_tipus': 'A',
#   'latitud': '42.27065',
#   'longitud': '3.18165',
#   'geocoded_column': {'type': 'Point', 'coordinates': [3.18165, 42.27065]},
#   'emplacament': 'Poliesportiu Municipal',
#   'altitud': '24',
#   'codi_municipi': '171523',
#   'nom_municipi': 'Roses',
#   'codi_comarca': '2',
#   'nom_comarca': 'Alt Empordà',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1996-02-07T00:00:00.000'},
#  {'codi_estacio': 'UD',
#   'nom_estacio': 'Serra de Daró',
#   'codi_tipus': 'A',
#   'latitud': '42.02895',
#   'longitud': '3.06227',
#   'geocoded_column': {'type': 'Point', 'coordinates': [3.06227, 42.02895]},
#   'emplacament': "Camí de la Barceloneta - St. Iscle d'Empordà",
#   'altitud': '12',
#   'codi_municipi': '171910',
#   'nom_municipi': 'Serra de Daró',
#   'codi_comarca': '10',
#   'nom_comarca': 'Baix Empordà',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1999-06-09T00:00:00.000',
#   'data_fi': '2013-06-01T00:00:00.000'},
#  {'codi_estacio': 'Z5',
#   'nom_estacio': 'Certascan (2.400 m)',
#   'codi_tipus': 'A',
#   'latitud': '42.70029',
#   'longitud': '1.27201',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.27201, 42.70029]},
#   'emplacament': 'Certascan',
#   'altitud': '2400',
#   'codi_municipi': '251235',
#   'nom_municipi': 'Lladorre',
#   'codi_comarca': '26',
#   'nom_comarca': 'Pallars Sobirà',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2000-11-11T00:00:00.000'},
#  {'codi_estacio': 'XI',
#   'nom_estacio': 'Mollerussa',
#   'codi_tipus': 'A',
#   'latitud': '41.61817',
#   'longitud': '0.87182',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.87182, 41.61817]},
#   'emplacament': '-',
#   'altitud': '247',
#   'codi_municipi': '251370',
#   'nom_municipi': 'Mollerussa',
#   'codi_comarca': '27',
#   'nom_comarca': "Pla d'Urgell",
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2010-01-20T00:00:00.000'},
#  {'codi_estacio': 'C8',
#   'nom_estacio': 'Cervera',
#   'codi_tipus': 'A',
#   'latitud': '41.67555',
#   'longitud': '1.29609',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.29609, 41.67555]},
#   'emplacament': 'Abocador comarcal',
#   'altitud': '554',
#   'codi_municipi': '250729',
#   'nom_municipi': 'Cervera',
#   'codi_comarca': '32',
#   'nom_comarca': 'Segarra',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1995-10-27T00:00:00.000'},
#  {'codi_estacio': 'XW',
#   'nom_estacio': 'Lleida - la Bordeta',
#   'codi_tipus': 'A',
#   'latitud': '41.59822',
#   'longitud': '0.64855',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.64855, 41.59822]},
#   'emplacament': 'Torre de Vallverdú',
#   'altitud': '165',
#   'codi_municipi': '251207',
#   'nom_municipi': 'Lleida',
#   'codi_comarca': '33',
#   'nom_comarca': 'Segrià',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '2013-07-24T00:00:00.000',
#   'data_fi': '2018-10-17T00:00:00.000'},
#  {'codi_estacio': 'YL',
#   'nom_estacio': 'Riudecanyes',
#   'codi_tipus': 'A',
#   'latitud': '41.1227',
#   'longitud': '0.96951',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.96951, 41.1227]},
#   'emplacament': 'els Gorgs',
#   'altitud': '170',
#   'codi_municipi': '431270',
#   'nom_municipi': 'Riudecanyes',
#   'codi_comarca': '8',
#   'nom_comarca': 'Baix Camp',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2019-02-06T00:00:00.000'},
#  {'codi_estacio': 'CJ',
#   'nom_estacio': 'Organyà',
#   'codi_tipus': 'A',
#   'latitud': '42.21624',
#   'longitud': '1.33132',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.33132, 42.21624]},
#   'emplacament': 'Càmping municipal',
#   'altitud': '566.5',
#   'codi_municipi': '251556',
#   'nom_municipi': 'Organyà',
#   'codi_comarca': '4',
#   'nom_comarca': 'Alt Urgell',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1996-01-16T00:00:00.000'},
#  {'codi_estacio': 'CL',
#   'nom_estacio': 'Sant Salvador de Guardiola',
#   'codi_tipus': 'A',
#   'latitud': '41.67399',
#   'longitud': '1.76796',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.76796, 41.67399]},
#   'emplacament': 'Urbanització Miralda',
#   'altitud': '349',
#   'codi_municipi': '080983',
#   'nom_municipi': 'Sant Salvador de Guardiola',
#   'codi_comarca': '7',
#   'nom_comarca': 'Bages',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1996-02-02T00:00:00.000'},
#  {'codi_estacio': 'Z2',
#   'nom_estacio': 'Boí (2.535 m)',
#   'codi_tipus': 'A',
#   'latitud': '42.46602',
#   'longitud': '0.88405',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.88405, 42.46602]},
#   'emplacament': 'Vall de Boí',
#   'altitud': '2535',
#   'codi_municipi': '250432',
#   'nom_municipi': 'La Vall de Boí',
#   'codi_comarca': '5',
#   'nom_comarca': 'Alta Ribagorça',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1998-11-13T00:00:00.000'},
#  {'codi_estacio': 'DF',
#   'nom_estacio': "la Bisbal d'Empordà",
#   'codi_tipus': 'A',
#   'latitud': '41.97751',
#   'longitud': '3.03543',
#   'geocoded_column': {'type': 'Point', 'coordinates': [3.03543, 41.97751]},
#   'emplacament': 'Estació depuradora',
#   'altitud': '28.6',
#   'codi_municipi': '170221',
#   'nom_municipi': "La Bisbal d'Empordà",
#   'codi_comarca': '10',
#   'nom_comarca': 'Baix Empordà',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1998-03-25T00:00:00.000'},
#  {'codi_estacio': 'W3',
#   'nom_estacio': 'Ventalló',
#   'codi_tipus': 'A',
#   'latitud': '42.15006',
#   'longitud': '3.06494',
#   'geocoded_column': {'type': 'Point', 'coordinates': [3.06494, 42.15006]},
#   'emplacament': "el Camp Lletget - Mare de Déu de l'Om - Montiró",
#   'altitud': '4',
#   'codi_municipi': '172109',
#   'nom_municipi': 'Ventalló',
#   'codi_comarca': '2',
#   'nom_comarca': 'Alt Empordà',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '2000-03-14T00:00:00.000',
#   'data_fi': '2015-01-12T00:00:00.000'},
#  {'codi_estacio': 'VI',
#   'nom_estacio': 'Lleida',
#   'codi_tipus': 'A',
#   'latitud': '41.62918',
#   'longitud': '0.59622',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.59622, 41.62918]},
#   'emplacament': 'Av. Alcalde Rovira Roure',
#   'altitud': '190',
#   'codi_municipi': '251207',
#   'nom_municipi': 'Lleida',
#   'codi_comarca': '33',
#   'nom_comarca': 'Segrià',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1990-03-30T00:00:00.000',
#   'data_fi': '2000-06-15T00:00:00.000'},
#  {'codi_estacio': 'UU',
#   'nom_estacio': 'Amposta',
#   'codi_tipus': 'A',
#   'latitud': '40.70776',
#   'longitud': '0.6321',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.6321, 40.70776]},
#   'emplacament': 'IRTA - Estació Exp. Ebre, ctra. de Balada, s/n',
#   'altitud': '3',
#   'codi_municipi': '430141',
#   'nom_municipi': 'Amposta',
#   'codi_comarca': '22',
#   'nom_comarca': 'Montsià',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1992-02-06T00:00:00.000'},
#  {'codi_estacio': 'CQ',
#   'nom_estacio': 'Vilanova de Meià',
#   'codi_tipus': 'A',
#   'latitud': '41.99546',
#   'longitud': '1.02569',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.02569, 41.99546]},
#   'emplacament': 'Camp de fútbol',
#   'altitud': '594',
#   'codi_municipi': '252509',
#   'nom_municipi': 'Vilanova de Meià',
#   'codi_comarca': '23',
#   'nom_comarca': 'Noguera',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1996-04-01T00:00:00.000'},
#  {'codi_estacio': 'KP',
#   'nom_estacio': 'Fogars de la Selva',
#   'codi_tipus': 'A',
#   'latitud': '41.73894',
#   'longitud': '2.69436',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.69436, 41.73894]},
#   'emplacament': 'Can Simó',
#   'altitud': '36',
#   'codi_municipi': '080826',
#   'nom_municipi': 'Fogars de la Selva',
#   'codi_comarca': '34',
#   'nom_comarca': 'Selva',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1996-01-05T00:00:00.000'},
#  {'codi_estacio': 'D1',
#   'nom_estacio': 'Margalef',
#   'codi_tipus': 'A',
#   'latitud': '41.28521',
#   'longitud': '0.75383',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.75383, 41.28521]},
#   'emplacament': "Dipòsit d'aigua",
#   'altitud': '404',
#   'codi_municipi': '430751',
#   'nom_municipi': 'Margalef',
#   'codi_comarca': '29',
#   'nom_comarca': 'Priorat',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1996-01-14T00:00:00.000'},
#  {'codi_estacio': 'VK',
#   'nom_estacio': 'Raimat',
#   'codi_tipus': 'A',
#   'latitud': '41.68328',
#   'longitud': '0.4487',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.4487, 41.68328]},
#   'emplacament': 'Finca Montserrat - Raimat',
#   'altitud': '286',
#   'codi_municipi': '251207',
#   'nom_municipi': 'Lleida',
#   'codi_comarca': '33',
#   'nom_comarca': 'Segrià',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1988-08-31T00:00:00.000'},
#  {'codi_estacio': 'W4',
#   'nom_estacio': 'Vilafranca del Penedès - la Granada',
#   'codi_tipus': 'A',
#   'latitud': '41.36619',
#   'longitud': '1.72857',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.72857, 41.36619]},
#   'emplacament': 'Rasa de Sagols',
#   'altitud': '240',
#   'codi_municipi': '083054',
#   'nom_municipi': 'Vilafranca del Penedès',
#   'codi_comarca': '3',
#   'nom_comarca': 'Alt Penedès',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1999-12-25T00:00:00.000'},
#  {'codi_estacio': 'DB',
#   'nom_estacio': 'el Perelló',
#   'codi_tipus': 'A',
#   'latitud': '40.87287',
#   'longitud': '0.71581',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.71581, 40.87287]},
#   'emplacament': "Dipòsit d'aigua",
#   'altitud': '179',
#   'codi_municipi': '431042',
#   'nom_municipi': 'El Perelló',
#   'codi_comarca': '9',
#   'nom_comarca': 'Baix Ebre',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1998-02-05T00:00:00.000'},
#  {'codi_estacio': 'UL',
#   'nom_estacio': 'Castelldans',
#   'codi_tipus': 'A',
#   'latitud': '41.52911',
#   'longitud': '0.75303',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.75303, 41.52911]},
#   'emplacament': 'Mas de St. Jaume, crta. de Castelldans a Puigvert',
#   'altitud': '228',
#   'codi_municipi': '250674',
#   'nom_municipi': 'Castelldans',
#   'codi_comarca': '18',
#   'nom_comarca': 'Garrigues',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1997-09-16T00:00:00.000',
#   'data_fi': '2017-02-21T00:00:00.000'},
#  {'codi_estacio': 'V9',
#   'nom_estacio': 'Miralcamp',
#   'codi_tipus': 'A',
#   'latitud': '41.61333',
#   'longitud': '0.87608',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.87608, 41.61333]},
#   'emplacament': 'Partida la Boletera',
#   'altitud': '256',
#   'codi_municipi': '251351',
#   'nom_municipi': 'Miralcamp',
#   'codi_comarca': '27',
#   'nom_comarca': "Pla d'Urgell",
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1997-09-26T00:00:00.000',
#   'data_fi': '2010-02-01T00:00:00.000'},
#  {'codi_estacio': 'VV',
#   'nom_estacio': 'Sant Llorenç Savall',
#   'codi_tipus': 'A',
#   'latitud': '41.68129',
#   'longitud': '2.02647',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.02647, 41.68129]},
#   'emplacament': 'Masia Can Brossa',
#   'altitud': '528',
#   'codi_municipi': '082233',
#   'nom_municipi': 'Sant Llorenç Savall',
#   'codi_comarca': '40',
#   'nom_comarca': 'Vallès Occidental',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1998-03-25T00:00:00.000'},
#  {'codi_estacio': 'UE',
#   'nom_estacio': 'Torroella de Montgrí',
#   'codi_tipus': 'A',
#   'latitud': '42.02306',
#   'longitud': '3.15719',
#   'geocoded_column': {'type': 'Point', 'coordinates': [3.15719, 42.02306]},
#   'emplacament': 'la Feixa Gata',
#   'altitud': '4',
#   'codi_municipi': '171997',
#   'nom_municipi': 'Torroella de Montgrí',
#   'codi_comarca': '10',
#   'nom_comarca': 'Baix Empordà',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1999-06-09T00:00:00.000'},
#  {'codi_estacio': 'WV',
#   'nom_estacio': 'Guardiola de Berguedà',
#   'codi_tipus': 'A',
#   'latitud': '42.23414',
#   'longitud': '1.87485',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.87485, 42.23414]},
#   'emplacament': 'Monestir de Sant Llorenç prop Bagà',
#   'altitud': '788',
#   'codi_municipi': '080996',
#   'nom_municipi': 'Guardiola de Berguedà',
#   'codi_comarca': '14',
#   'nom_comarca': 'Berguedà',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2005-11-28T00:00:00.000'},
#  {'codi_estacio': 'XA',
#   'nom_estacio': 'la Panadella',
#   'codi_tipus': 'A',
#   'latitud': '41.60257',
#   'longitud': '1.4007',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.4007, 41.60257]},
#   'emplacament': 'La Creu del Vent',
#   'altitud': '785',
#   'codi_municipi': '081332',
#   'nom_municipi': 'Montmaneu',
#   'codi_comarca': '6',
#   'nom_comarca': 'Anoia',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2008-12-18T00:00:00.000'},
#  {'codi_estacio': 'WL',
#   'nom_estacio': 'Sant Martí de Riucorb',
#   'codi_tipus': 'A',
#   'latitud': '41.57236',
#   'longitud': '1.0882',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.0882, 41.57236]},
#   'emplacament': 'Camí de les Comes, pol. 2, parc. 137',
#   'altitud': '413',
#   'codi_municipi': '259025',
#   'nom_municipi': 'Sant Martí de Riucorb',
#   'codi_comarca': '38',
#   'nom_comarca': 'Urgell',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2002-02-05T00:00:00.000'},
#  {'codi_estacio': 'VC',
#   'nom_estacio': 'Pantà de Riba-roja',
#   'codi_tipus': 'A',
#   'latitud': '41.24415',
#   'longitud': '0.43266',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.43266, 41.24415]},
#   'emplacament': 'Presa de Riba-roja',
#   'altitud': '69',
#   'codi_municipi': '431251',
#   'nom_municipi': "Riba-roja d'Ebre",
#   'codi_comarca': '30',
#   'nom_comarca': "Ribera d'Ebre",
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1996-11-18T00:00:00.000'},
#  {'codi_estacio': 'VF',
#   'nom_estacio': "Alcarràs - Torrent d'Alcarràs",
#   'codi_tipus': 'A',
#   'latitud': '41.56482',
#   'longitud': '0.54999',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.54999, 41.56482]},
#   'emplacament': 'Partida Graminella',
#   'altitud': '122',
#   'codi_municipi': '250117',
#   'nom_municipi': 'Alcarràs',
#   'codi_comarca': '33',
#   'nom_comarca': 'Segrià',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1997-09-17T00:00:00.000',
#   'data_fi': '2013-07-31T00:00:00.000'},
#  {'codi_estacio': 'DK',
#   'nom_estacio': 'Torredembarra',
#   'codi_tipus': 'A',
#   'latitud': '41.14677',
#   'longitud': '1.41846',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.41846, 41.14677]},
#   'emplacament': 'Aiguamolls els Muntanyans',
#   'altitud': '2',
#   'codi_municipi': '431536',
#   'nom_municipi': 'Torredembarra',
#   'codi_comarca': '36',
#   'nom_comarca': 'Tarragonès',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1999-11-24T00:00:00.000'},
#  {'codi_estacio': 'UQ',
#   'nom_estacio': 'Dosrius - PN Montnegre Corredor',
#   'codi_tipus': 'A',
#   'latitud': '41.61991',
#   'longitud': '2.44532',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.44532, 41.61991]},
#   'emplacament': 'Parc Natural del Corredor. Masia Can Bosc',
#   'altitud': '460',
#   'codi_municipi': '080752',
#   'nom_municipi': 'Dosrius',
#   'codi_comarca': '21',
#   'nom_comarca': 'Maresme',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1996-08-09T00:00:00.000'},
#  {'codi_estacio': 'VX',
#   'nom_estacio': 'Tagamanent - PN del Montseny',
#   'codi_tipus': 'A',
#   'latitud': '41.74761',
#   'longitud': '2.30291',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.30291, 41.74761]},
#   'emplacament': 'Can Bellver - Serrat de Bellver. Parc Natural del Montseny',
#   'altitud': '1030',
#   'codi_municipi': '082763',
#   'nom_municipi': 'Tagamanent',
#   'codi_comarca': '41',
#   'nom_comarca': 'Vallès Oriental',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1996-01-04T00:00:00.000'},
#  {'codi_estacio': 'WX',
#   'nom_estacio': 'Camarasa',
#   'codi_tipus': 'A',
#   'latitud': '41.9178',
#   'longitud': '0.88175',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.88175, 41.9178]},
#   'emplacament': 'Camarasa',
#   'altitud': '668',
#   'codi_municipi': '250621',
#   'nom_municipi': 'Camarasa',
#   'codi_comarca': '23',
#   'nom_comarca': 'Noguera',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2006-03-07T00:00:00.000'},
#  {'codi_estacio': 'ZD',
#   'nom_estacio': "la Tosa d'Alp (2.478 m)",
#   'codi_tipus': 'A',
#   'latitud': '42.32211',
#   'longitud': '1.89716',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.89716, 42.32211]},
#   'emplacament': "Tosa d'Alp",
#   'altitud': '2478',
#   'codi_municipi': '170062',
#   'nom_municipi': 'Alp',
#   'codi_comarca': '15',
#   'nom_comarca': 'Cerdanya',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2014-09-04T00:00:00.000'},
#  {'codi_estacio': 'DJ',
#   'nom_estacio': 'Banyoles',
#   'codi_tipus': 'A',
#   'latitud': '42.11653',
#   'longitud': '2.78969',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.78969, 42.11653]},
#   'emplacament': 'Abocador comarcal de Puigpalter',
#   'altitud': '176',
#   'codi_municipi': '170157',
#   'nom_municipi': 'Banyoles',
#   'codi_comarca': '28',
#   'nom_comarca': "Pla de l'Estany",
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1999-10-11T00:00:00.000'},
#  {'codi_estacio': 'YQ',
#   'nom_estacio': 'Port de Barcelona - ZAL Prat',
#   'codi_tipus': 'A',
#   'latitud': '41.31926',
#   'longitud': '2.137',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.137, 41.31926]},
#   'emplacament': 'Port de Barcelona',
#   'altitud': '7',
#   'codi_municipi': '081691',
#   'nom_municipi': 'El Prat de Llobregat',
#   'codi_comarca': '11',
#   'nom_comarca': 'Baix Llobregat',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2021-12-02T00:00:00.000'},
#  {'codi_estacio': 'CU',
#   'nom_estacio': 'Vielha',
#   'codi_tipus': 'A',
#   'latitud': '42.69856',
#   'longitud': '0.79397',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.79397, 42.69856]},
#   'emplacament': 'Prat de Tixineret',
#   'altitud': '1002',
#   'codi_municipi': '252430',
#   'nom_municipi': 'Vielha e Mijaran',
#   'codi_comarca': '39',
#   'nom_comarca': "Val d'Aran",
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1996-02-15T00:00:00.000',
#   'data_fi': '2022-06-01T00:00:00.000'},
#  {'codi_estacio': 'XO',
#   'nom_estacio': 'Vic',
#   'codi_tipus': 'A',
#   'latitud': '41.93497',
#   'longitud': '2.23987',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.23987, 41.93497]},
#   'emplacament': 'Vic',
#   'altitud': '499',
#   'codi_municipi': '082981',
#   'nom_municipi': 'Vic',
#   'codi_comarca': '24',
#   'nom_comarca': 'Osona',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2011-12-22T00:00:00.000'},
#  {'codi_estacio': 'UJ',
#   'nom_estacio': 'Santa Coloma de Queralt',
#   'codi_tipus': 'A',
#   'latitud': '41.52879',
#   'longitud': '1.3683',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.3683, 41.52879]},
#   'emplacament': 'Partida la Cabana',
#   'altitud': '709',
#   'codi_municipi': '431397',
#   'nom_municipi': 'Santa Coloma de Queralt',
#   'codi_comarca': '16',
#   'nom_comarca': 'Conca de Barberà',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1996-11-19T00:00:00.000'},
#  {'codi_estacio': 'CX',
#   'nom_estacio': 'Vic - 1',
#   'codi_tipus': 'A',
#   'latitud': '41.93582',
#   'longitud': '2.23857',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.23857, 41.93582]},
#   'emplacament': "Estadi d'atletisme",
#   'altitud': '497.8',
#   'codi_municipi': '082981',
#   'nom_municipi': 'Vic',
#   'codi_comarca': '24',
#   'nom_comarca': 'Osona',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1996-01-18T00:00:00.000',
#   'data_fi': '2003-01-01T00:00:00.000'},
#  {'codi_estacio': 'Z1',
#   'nom_estacio': 'Bonaigua (2.266 m)',
#   'codi_tipus': 'A',
#   'latitud': '42.64691',
#   'longitud': '0.98486',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.98486, 42.64691]},
#   'emplacament': 'Port de la Bonaigua',
#   'altitud': '2266',
#   'codi_municipi': '250241',
#   'nom_municipi': 'Alt Àneu',
#   'codi_comarca': '26',
#   'nom_comarca': 'Pallars Sobirà',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1997-11-06T00:00:00.000'},
#  {'codi_estacio': 'UT',
#   'nom_estacio': "Port de les Cases d'Alcanar",
#   'codi_tipus': 'A',
#   'latitud': '40.55219',
#   'longitud': '0.53252',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.53252, 40.55219]},
#   'emplacament': "Port de les Cases d'Alcanar",
#   'altitud': '3',
#   'codi_municipi': '430043',
#   'nom_municipi': 'Alcanar',
#   'codi_comarca': '22',
#   'nom_comarca': 'Montsià',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1993-08-31T00:00:00.000',
#   'data_fi': '2001-11-11T00:00:00.000'},
#  {'codi_estacio': 'DQ',
#   'nom_estacio': 'Vila-rodona',
#   'codi_tipus': 'A',
#   'latitud': '41.30728',
#   'longitud': '1.36259',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.36259, 41.30728]},
#   'emplacament': 'Nova estació',
#   'altitud': '287',
#   'codi_municipi': '431704',
#   'nom_municipi': 'Vila-rodona',
#   'codi_comarca': '1',
#   'nom_comarca': 'Alt Camp',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2005-07-29T00:00:00.000'},
#  {'codi_estacio': 'X8',
#   'nom_estacio': 'Barcelona - Zona Universitària',
#   'codi_tipus': 'A',
#   'latitud': '41.37919',
#   'longitud': '2.1054',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.1054, 41.37919]},
#   'emplacament': 'Pistes UB',
#   'altitud': '79',
#   'codi_municipi': '080193',
#   'nom_municipi': 'Barcelona',
#   'codi_comarca': '13',
#   'nom_comarca': 'Barcelonès',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2008-04-17T00:00:00.000'},
#  {'codi_estacio': 'MW',
#   'nom_estacio': 'Navès',
#   'codi_tipus': 'A',
#   'latitud': '42.00707',
#   'longitud': '1.65239',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.65239, 42.00707]},
#   'emplacament': 'el Garrigar',
#   'altitud': '545',
#   'codi_municipi': '251462',
#   'nom_municipi': 'Navès',
#   'codi_comarca': '35',
#   'nom_comarca': 'Solsonès',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2010-03-22T00:00:00.000'},
#  {'codi_estacio': 'YM',
#   'nom_estacio': 'Granollers',
#   'codi_tipus': 'A',
#   'latitud': '41.60922',
#   'longitud': '2.29841',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.29841, 41.60922]},
#   'emplacament': 'Parc del Puig de les Tres Torres',
#   'altitud': '210',
#   'codi_municipi': '080961',
#   'nom_municipi': 'Granollers',
#   'codi_comarca': '41',
#   'nom_comarca': 'Vallès Oriental',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2019-09-17T00:00:00.000'},
#  {'codi_estacio': 'VZ',
#   'nom_estacio': 'Espolla',
#   'codi_tipus': 'A',
#   'latitud': '42.38443',
#   'longitud': '3.00736',
#   'geocoded_column': {'type': 'Point', 'coordinates': [3.00736, 42.38443]},
#   'emplacament': 'Llaurants. Ref. Cadastral: Pol. 5, parc.195',
#   'altitud': '83',
#   'codi_municipi': '170643',
#   'nom_municipi': 'Espolla',
#   'codi_comarca': '2',
#   'nom_comarca': 'Alt Empordà',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2000-06-07T00:00:00.000'},
#  {'codi_estacio': 'Y7',
#   'nom_estacio': 'Port de Barcelona - Bocana Sud',
#   'codi_tipus': 'A',
#   'latitud': '41.31725',
#   'longitud': '2.16537',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.16537, 41.31725]},
#   'emplacament': 'Port de Barcelona',
#   'altitud': '3',
#   'codi_municipi': '081691',
#   'nom_municipi': 'El Prat de Llobregat',
#   'codi_comarca': '11',
#   'nom_comarca': 'Baix Llobregat',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2015-04-08T00:00:00.000'},
#  {'codi_estacio': 'UX',
#   'nom_estacio': 'Ulldecona - els Valentins',
#   'codi_tipus': 'A',
#   'latitud': '40.62652',
#   'longitud': '0.37112',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.37112, 40.62652]},
#   'emplacament': 'Comunitat de regants del Pou Valentins',
#   'altitud': '210',
#   'codi_municipi': '431567',
#   'nom_municipi': 'Ulldecona',
#   'codi_comarca': '22',
#   'nom_comarca': 'Montsià',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1990-11-15T00:00:00.000'},
#  {'codi_estacio': 'Z3',
#   'nom_estacio': 'Malniu (2.230 m)',
#   'codi_tipus': 'A',
#   'latitud': '42.46605',
#   'longitud': '1.7785',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.7785, 42.46605]},
#   'emplacament': 'Estany de Malniu',
#   'altitud': '2230',
#   'codi_municipi': '170998',
#   'nom_municipi': 'Meranges',
#   'codi_comarca': '15',
#   'nom_comarca': 'Cerdanya',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1999-11-03T00:00:00.000'},
#  {'codi_estacio': 'VN',
#   'nom_estacio': "Vilobí d'Onyar",
#   'codi_tipus': 'A',
#   'latitud': '41.88244',
#   'longitud': '2.74262',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.74262, 41.88244]},
#   'emplacament': 'Camps de Can Salvà',
#   'altitud': '117',
#   'codi_municipi': '172333',
#   'nom_municipi': "Vilobí d'Onyar",
#   'codi_comarca': '34',
#   'nom_comarca': 'Selva',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1998-11-10T00:00:00.000',
#   'data_fi': '2024-09-10T00:00:00.000'},
#  {'codi_estacio': 'Z6',
#   'nom_estacio': 'Sasseuva (2.228 m)',
#   'codi_tipus': 'A',
#   'latitud': '42.77011',
#   'longitud': '0.73198',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.73198, 42.77011]},
#   'emplacament': 'Sasseuva',
#   'altitud': '2228',
#   'codi_municipi': '250313',
#   'nom_municipi': 'Arres',
#   'codi_comarca': '39',
#   'nom_comarca': "Val d'Aran",
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2001-09-20T00:00:00.000'},
#  {'codi_estacio': 'DM',
#   'nom_estacio': 'Girona - Bombers',
#   'codi_tipus': 'A',
#   'latitud': '41.96012',
#   'longitud': '2.80696',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.80696, 41.96012]},
#   'emplacament': 'Parc de Bombers',
#   'altitud': '90',
#   'codi_municipi': '170792',
#   'nom_municipi': 'Girona',
#   'codi_comarca': '20',
#   'nom_comarca': 'Gironès',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '2001-05-10T00:00:00.000',
#   'data_fi': '2010-09-15T00:00:00.000'},
#  {'codi_estacio': 'XB',
#   'nom_estacio': 'la Llacuna',
#   'codi_tipus': 'A',
#   'latitud': '41.4779',
#   'longitud': '1.53529',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.53529, 41.4779]},
#   'emplacament': 'Cal Mateu',
#   'altitud': '584',
#   'codi_municipi': '081043',
#   'nom_municipi': 'La Llacuna',
#   'codi_comarca': '6',
#   'nom_comarca': 'Anoia',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2008-03-19T00:00:00.000'},
#  {'codi_estacio': 'DE',
#   'nom_estacio': 'Botarell',
#   'codi_tipus': 'A',
#   'latitud': '41.15404',
#   'longitud': '0.9977200000000001',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.99772, 41.15404]},
#   'emplacament': 'Planta de compostatge',
#   'altitud': '231',
#   'codi_municipi': '430332',
#   'nom_municipi': 'Botarell',
#   'codi_comarca': '8',
#   'nom_comarca': 'Baix Camp',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1998-01-16T00:00:00.000',
#   'data_fi': '2007-01-16T00:00:00.000'},
#  {'codi_estacio': 'XD',
#   'nom_estacio': 'Ulldemolins',
#   'codi_tipus': 'A',
#   'latitud': '41.32',
#   'longitud': '0.8857',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.8857, 41.32]},
#   'emplacament': 'Pigrossos',
#   'altitud': '687',
#   'codi_municipi': '431573',
#   'nom_municipi': 'Ulldemolins',
#   'codi_comarca': '29',
#   'nom_comarca': 'Priorat',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2008-04-17T00:00:00.000'},
#  {'codi_estacio': 'WU',
#   'nom_estacio': 'Badalona - Museu',
#   'codi_tipus': 'A',
#   'latitud': '41.45215',
#   'longitud': '2.24757',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.24757, 41.45215]},
#   'emplacament': 'Museu',
#   'altitud': '42',
#   'codi_municipi': '080155',
#   'nom_municipi': 'Badalona',
#   'codi_comarca': '13',
#   'nom_comarca': 'Barcelonès',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2005-09-21T00:00:00.000'},
#  {'codi_estacio': 'X7',
#   'nom_estacio': 'Torres de Segre',
#   'codi_tipus': 'A',
#   'latitud': '41.51909',
#   'longitud': '0.55314',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.55314, 41.51909]},
#   'emplacament': 'Torres de Segre',
#   'altitud': '215',
#   'codi_municipi': '252326',
#   'nom_municipi': 'Torres de Segre',
#   'codi_comarca': '33',
#   'nom_comarca': 'Segrià',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2007-07-02T00:00:00.000'},
#  {'codi_estacio': 'Y4',
#   'nom_estacio': 'Alinyà',
#   'codi_tipus': 'A',
#   'latitud': '42.17426',
#   'longitud': '1.42775',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.42775, 42.17426]},
#   'emplacament': 'Tossal de Salamó',
#   'altitud': '1162',
#   'codi_municipi': '259084',
#   'nom_municipi': 'Fígols i Alinyà',
#   'codi_comarca': '4',
#   'nom_comarca': 'Alt Urgell',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2014-07-01T00:00:00.000'},
#  {'codi_estacio': 'CV',
#   'nom_estacio': 'la Pobla de Segur - Bombers',
#   'codi_tipus': 'A',
#   'latitud': '42.23939',
#   'longitud': '0.96434',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.96434, 42.23939]},
#   'emplacament': 'Parc de Bombers',
#   'altitud': '513.3',
#   'codi_municipi': '251713',
#   'nom_municipi': 'La Pobla de Segur',
#   'codi_comarca': '25',
#   'nom_comarca': 'Pallars Jussà',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1995-12-22T00:00:00.000',
#   'data_fi': '2016-11-18T00:00:00.000'},
#  {'codi_estacio': 'Y6',
#   'nom_estacio': 'Tivissa',
#   'codi_tipus': 'A',
#   'latitud': '41.04343',
#   'longitud': '0.74032',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.74032, 41.04343]},
#   'emplacament': '-',
#   'altitud': '317',
#   'codi_municipi': '431508',
#   'nom_municipi': 'Tivissa',
#   'codi_comarca': '30',
#   'nom_comarca': "Ribera d'Ebre",
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2015-03-26T00:00:00.000'},
#  {'codi_estacio': 'MQ',
#   'nom_estacio': 'Cardona',
#   'codi_tipus': 'A',
#   'latitud': '41.92047',
#   'longitud': '1.69584',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.69584, 41.92047]},
#   'emplacament': 'Boca nord del túnel de desviament del Cardener',
#   'altitud': '402',
#   'codi_municipi': '080478',
#   'nom_municipi': 'Cardona',
#   'codi_comarca': '7',
#   'nom_comarca': 'Bages',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2003-01-16T00:00:00.000'},
#  {'codi_estacio': 'YR',
#   'nom_estacio': 'Vilanova i la Geltrú',
#   'codi_tipus': 'A',
#   'latitud': '41.23575',
#   'longitud': '1.73148',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.73148, 41.23575]},
#   'emplacament': 'Circuit de ciclisme',
#   'altitud': '31',
#   'codi_municipi': '083073',
#   'nom_municipi': 'Vilanova i la Geltrú',
#   'codi_comarca': '17',
#   'nom_comarca': 'Garraf',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2023-04-13T00:00:00.000'},
#  {'codi_estacio': 'YK',
#   'nom_estacio': 'Terrassa',
#   'codi_tipus': 'A',
#   'latitud': '41.55361',
#   'longitud': '1.99005',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.99005, 41.55361]},
#   'emplacament': 'Can Poal',
#   'altitud': '313',
#   'codi_municipi': '082798',
#   'nom_municipi': 'Terrassa',
#   'codi_comarca': '40',
#   'nom_comarca': 'Vallès Occidental',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2018-12-20T00:00:00.000'},
#  {'codi_estacio': 'CF',
#   'nom_estacio': 'Lloret de Mar',
#   'codi_tipus': 'A',
#   'latitud': '41.72346',
#   'longitud': '2.84282',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.84282, 41.72346]},
#   'emplacament': 'Abocador municipal',
#   'altitud': '63.3',
#   'codi_municipi': '170950',
#   'nom_municipi': 'Lloret de Mar',
#   'codi_comarca': '34',
#   'nom_comarca': 'Selva',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1996-02-05T00:00:00.000',
#   'data_fi': '2003-06-16T00:00:00.000'},
#  {'codi_estacio': 'WZ',
#   'nom_estacio': 'Cunit',
#   'codi_tipus': 'A',
#   'latitud': '41.20187',
#   'longitud': '1.63346',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.63346, 41.20187]},
#   'emplacament': '-',
#   'altitud': '17',
#   'codi_municipi': '430516',
#   'nom_municipi': 'Cunit',
#   'codi_comarca': '12',
#   'nom_comarca': 'Baix Penedès',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2006-06-27T00:00:00.000'},
#  {'codi_estacio': 'YB',
#   'nom_estacio': 'Olot',
#   'codi_tipus': 'A',
#   'latitud': '42.18813',
#   'longitud': '2.47097',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.47097, 42.18813]},
#   'emplacament': 'Pla de Dalt',
#   'altitud': '433',
#   'codi_municipi': '171143',
#   'nom_municipi': 'Olot',
#   'codi_comarca': '19',
#   'nom_comarca': 'Garrotxa',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2016-07-21T00:00:00.000'},
#  {'codi_estacio': 'VT',
#   'nom_estacio': 'Cerdanyola del Vallès',
#   'codi_tipus': 'A',
#   'latitud': '41.48401',
#   'longitud': '2.12745',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.12745, 41.48401]},
#   'emplacament': 'Parc Tecnològic del Vallès. Masia Can Fatjó del Molí',
#   'altitud': '84',
#   'codi_municipi': '082665',
#   'nom_municipi': 'Cerdanyola del Vallès',
#   'codi_comarca': '40',
#   'nom_comarca': 'Vallès Occidental',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1998-05-15T00:00:00.000',
#   'data_fi': '2014-01-03T00:00:00.000'},
#  {'codi_estacio': 'CH',
#   'nom_estacio': 'Falset - Escola',
#   'codi_tipus': 'A',
#   'latitud': '41.15076',
#   'longitud': '0.82357',
# ...
#   'codi_comarca': '3',
#   'nom_comarca': 'Alt Penedès',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '2006-04-11T00:00:00.000',
#   'data_fi': '2021-05-07T00:00:00.000'},
#  {'codi_estacio': 'XE',
#   'nom_estacio': 'Tarragona - Complex Educatiu',
#   'codi_tipus': 'A',
#   'latitud': '41.10393',
#   'longitud': '1.201',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.201, 41.10393]},
#   'emplacament': 'Complex Educatiu',
#   'altitud': '5',
#   'codi_municipi': '431482',
#   'nom_municipi': 'Tarragona',
#   'codi_comarca': '36',
#   'nom_comarca': 'Tarragonès',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2009-02-05T00:00:00.000'},
#  {'codi_estacio': 'WT',
#   'nom_estacio': 'Malgrat de Mar',
#   'codi_tipus': 'A',
#   'latitud': '41.64707',
#   'longitud': '2.75658',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.75658, 41.64707]},
#   'emplacament': 'Camí de la Pomereda',
#   'altitud': '2',
#   'codi_municipi': '081108',
#   'nom_municipi': 'Malgrat de Mar',
#   'codi_comarca': '21',
#   'nom_comarca': 'Maresme',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2005-05-04T00:00:00.000'},
#  {'codi_estacio': 'WE',
#   'nom_estacio': 'Vilanova del Vallès',
#   'codi_tipus': 'A',
#   'latitud': '41.5444',
#   'longitud': '2.30014',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.30014, 41.5444]},
#   'emplacament': 'Mas Casa Alta',
#   'altitud': '126',
#   'codi_municipi': '089024',
#   'nom_municipi': 'Vilanova del Vallès',
#   'codi_comarca': '41',
#   'nom_comarca': 'Vallès Oriental',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2000-07-05T00:00:00.000'},
#  {'codi_estacio': 'U1',
#   'nom_estacio': 'Cabanes - Mas de la Rajoleria',
#   'codi_tipus': 'A',
#   'latitud': '42.30648',
#   'longitud': '2.95481',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.95481, 42.30648]},
#   'emplacament': 'Mas St. Feliu, S.A., camí de St. Feli, s/n',
#   'altitud': '31',
#   'codi_municipi': '170307',
#   'nom_municipi': 'Cabanes',
#   'codi_comarca': '2',
#   'nom_comarca': 'Alt Empordà',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1991-06-11T00:00:00.000',
#   'data_fi': '2024-05-10T00:00:00.000'},
#  {'codi_estacio': 'V7',
#   'nom_estacio': 'Embassament de Sau',
#   'codi_tipus': 'A',
#   'latitud': '41.97554',
#   'longitud': '2.39837',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.39837, 41.97554]},
#   'emplacament': 'Embassament de Sau. Club Nàutic.',
#   'altitud': '435',
#   'codi_municipi': '083036',
#   'nom_municipi': 'Vilanova de Sau',
#   'codi_comarca': '24',
#   'nom_comarca': 'Osona',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1997-05-20T00:00:00.000',
#   'data_fi': '2006-05-02T00:00:00.000'},
#  {'codi_estacio': 'YC',
#   'nom_estacio': 'la Pobla de Segur',
#   'codi_tipus': 'A',
#   'latitud': '42.24388',
#   'longitud': '0.96802',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.96802, 42.24388]},
#   'emplacament': 'Horta de les Feixes',
#   'altitud': '508',
#   'codi_municipi': '251713',
#   'nom_municipi': 'La Pobla de Segur',
#   'codi_comarca': '25',
#   'nom_comarca': 'Pallars Jussà',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2016-11-18T00:00:00.000'},
#  {'codi_estacio': 'CN',
#   'nom_estacio': 'Guardiola de Berguedà - Escola',
#   'codi_tipus': 'A',
#   'latitud': '42.22903',
#   'longitud': '1.87672',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.87672, 42.22903]},
#   'emplacament': "Centre d'Assistència Primària",
#   'altitud': '719.8',
#   'codi_municipi': '080996',
#   'nom_municipi': 'Guardiola de Berguedà',
#   'codi_comarca': '14',
#   'nom_comarca': 'Berguedà',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1996-02-20T00:00:00.000',
#   'data_fi': '2005-03-21T00:00:00.000'},
#  {'codi_estacio': 'DN',
#   'nom_estacio': 'Anglès',
#   'codi_tipus': 'A',
#   'latitud': '41.96095',
#   'longitud': '2.63108',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.63108, 41.96095]},
#   'emplacament': 'Poliesportiu municipal',
#   'altitud': '150',
#   'codi_municipi': '170084',
#   'nom_municipi': 'Anglès',
#   'codi_comarca': '34',
#   'nom_comarca': 'Selva',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2001-05-10T00:00:00.000'},
#  {'codi_estacio': 'UM',
#   'nom_estacio': 'la Granadella',
#   'codi_tipus': 'A',
#   'latitud': '41.35991',
#   'longitud': '0.66789',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.66789, 41.35991]},
#   'emplacament': 'Horts de la Vall Major',
#   'altitud': '505',
#   'codi_municipi': '251018',
#   'nom_municipi': 'La Granadella',
#   'codi_comarca': '18',
#   'nom_comarca': 'Garrigues',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1992-01-30T00:00:00.000'},
#  {'codi_estacio': 'KE',
#   'nom_estacio': 'Pantà de Sau',
#   'codi_tipus': 'A',
#   'latitud': '41.96867',
#   'longitud': '2.41404',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.41404, 41.96867]},
#   'emplacament': 'Central hidroelèctrica de Sau',
#   'altitud': '426',
#   'codi_municipi': '083036',
#   'nom_municipi': 'Vilanova de Sau',
#   'codi_comarca': '24',
#   'nom_comarca': 'Osona',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1996-01-05T00:00:00.000'},
#  {'codi_estacio': 'U9',
#   'nom_estacio': "l'Aldea",
#   'codi_tipus': 'A',
#   'latitud': '40.76947',
#   'longitud': '0.61635',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.61635, 40.76947]},
#   'emplacament': 'Barranc del Mas Roig',
#   'altitud': '62',
#   'codi_municipi': '439044',
#   'nom_municipi': "L'Aldea",
#   'codi_comarca': '9',
#   'nom_comarca': 'Baix Ebre',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1991-06-03T00:00:00.000'},
#  {'codi_estacio': 'WP',
#   'nom_estacio': 'Canaletes',
#   'codi_tipus': 'A',
#   'latitud': '41.48518',
#   'longitud': '1.69337',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.69337, 41.48518]},
#   'emplacament': 'Camp del Roure - Can Feixes',
#   'altitud': '325',
#   'codi_municipi': '081228',
#   'nom_municipi': 'Mediona',
#   'codi_comarca': '3',
#   'nom_comarca': 'Alt Penedès',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2002-05-17T00:00:00.000'},
#  {'codi_estacio': 'VB',
#   'nom_estacio': 'Benissanet',
#   'codi_tipus': 'A',
#   'latitud': '41.06289',
#   'longitud': '0.63517',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.63517, 41.06289]},
#   'emplacament': 'Grup Fruiter Benissanet, crta. de Mora, s/n',
#   'altitud': '32',
#   'codi_municipi': '430265',
#   'nom_municipi': 'Benissanet',
#   'codi_comarca': '30',
#   'nom_comarca': "Ribera d'Ebre",
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1993-07-14T00:00:00.000'},
#  {'codi_estacio': 'V6',
#   'nom_estacio': 'Viladrau - Aigües de Viladrau',
#   'codi_tipus': 'A',
#   'latitud': '41.84256',
#   'longitud': '2.42636',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.42636, 41.84256]},
#   'emplacament': 'Camí vell de Viladrau, s/n',
#   'altitud': '871',
#   'codi_municipi': '170097',
#   'nom_municipi': 'Arbúcies',
#   'codi_comarca': '34',
#   'nom_comarca': 'Selva',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1995-10-03T00:00:00.000',
#   'data_fi': '2005-03-29T00:00:00.000'},
#  {'codi_estacio': 'WO',
#   'nom_estacio': 'la Bisbal del Penedès',
#   'codi_tipus': 'A',
#   'latitud': '41.27151',
#   'longitud': '1.46717',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.46717, 41.27151]},
#   'emplacament': 'Fondo de Cal Sumoi',
#   'altitud': '185',
#   'codi_municipi': '430287',
#   'nom_municipi': 'La Bisbal del Penedès',
#   'codi_comarca': '12',
#   'nom_comarca': 'Baix Penedès',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2002-05-16T00:00:00.000'},
#  {'codi_estacio': 'Y9',
#   'nom_estacio': "Port de Barcelona - ZAL Prat (ca l'Arana)",
#   'codi_tipus': 'A',
#   'latitud': '41.31723',
#   'longitud': '2.13091',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.13091, 41.31723]},
#   'emplacament': 'Port de Barcelona',
#   'altitud': '4',
#   'codi_municipi': '081691',
#   'nom_municipi': 'El Prat de Llobregat',
#   'codi_comarca': '11',
#   'nom_comarca': 'Baix Llobregat',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '2015-06-26T00:00:00.000',
#   'data_fi': '2021-11-30T00:00:00.000'},
#  {'codi_estacio': 'XY',
#   'nom_estacio': 'Alcarràs',
#   'codi_tipus': 'A',
#   'latitud': '41.56509',
#   'longitud': '0.55027',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.55027, 41.56509]},
#   'emplacament': 'Central del revés',
#   'altitud': '122',
#   'codi_municipi': '250117',
#   'nom_municipi': 'Alcarràs',
#   'codi_comarca': '33',
#   'nom_comarca': 'Segrià',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2013-07-31T00:00:00.000'},
#  {'codi_estacio': 'XU',
#   'nom_estacio': 'Canyelles',
#   'codi_tipus': 'A',
#   'latitud': '41.28801',
#   'longitud': '1.72195',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.72195, 41.28801]},
#   'emplacament': 'Cementiri',
#   'altitud': '148',
#   'codi_municipi': '080431',
#   'nom_municipi': 'Canyelles',
#   'codi_comarca': '17',
#   'nom_comarca': 'Garraf',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2013-07-16T00:00:00.000'},
#  {'codi_estacio': 'UW',
#   'nom_estacio': 'els Alfacs',
#   'codi_tipus': 'A',
#   'latitud': '40.62725',
#   'longitud': '0.65922',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.65922, 40.62725]},
#   'emplacament': "IRTA Centre d'Aqüicultura, crta. Poble Nou del Delta, km 5,5",
#   'altitud': '0',
#   'codi_municipi': '431362',
#   'nom_municipi': 'La Ràpita',
#   'codi_comarca': '22',
#   'nom_comarca': 'Montsià',
#   'codi_provincia': '43',
#   'nom_provincia': 'Tarragona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1994-07-06T00:00:00.000'},
#  {'codi_estacio': 'XV',
#   'nom_estacio': 'Sant Cugat del Vallès - CAR',
#   'codi_tipus': 'A',
#   'latitud': '41.48311',
#   'longitud': '2.07956',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.07956, 41.48311]},
#   'emplacament': "Centre d'Alt Rendiment",
#   'altitud': '158',
#   'codi_municipi': '082055',
#   'nom_municipi': 'Sant Cugat del Vallès',
#   'codi_comarca': '40',
#   'nom_comarca': 'Vallès Occidental',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2013-08-08T00:00:00.000'},
#  {'codi_estacio': 'WA',
#   'nom_estacio': 'Oliola',
#   'codi_tipus': 'A',
#   'latitud': '41.87694',
#   'longitud': '1.1541',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.1541, 41.87694]},
#   'emplacament': "Partida l'Era",
#   'altitud': '443',
#   'codi_municipi': '251500',
#   'nom_municipi': 'Oliola',
#   'codi_comarca': '23',
#   'nom_comarca': 'Noguera',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2001-03-26T00:00:00.000'},
#  {'codi_estacio': 'DP',
#   'nom_estacio': 'Das - Aeròdrom',
#   'codi_tipus': 'A',
#   'latitud': '42.38605',
#   'longitud': '1.8664',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.8664, 42.38605]},
#   'emplacament': 'Aeròdrom de la Cerdanya',
#   'altitud': '1097',
#   'codi_municipi': '170617',
#   'nom_municipi': 'Das',
#   'codi_comarca': '15',
#   'nom_comarca': 'Cerdanya',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2001-05-22T00:00:00.000'},
#  {'codi_estacio': 'XX',
#   'nom_estacio': 'Anglesola - Tornabous',
#   'codi_tipus': 'A',
#   'latitud': '41.68835',
#   'longitud': '1.04476',
#   'geocoded_column': {'type': 'Point', 'coordinates': [1.04476, 41.68835]},
#   'emplacament': 'Masia Mingot',
#   'altitud': '291',
#   'codi_municipi': '252252',
#   'nom_municipi': 'Tornabous',
#   'codi_comarca': '38',
#   'nom_comarca': 'Urgell',
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2013-08-06T00:00:00.000'},
#  {'codi_estacio': 'YN',
#   'nom_estacio': 'Vielha - Elipòrt',
#   'codi_tipus': 'A',
#   'latitud': '42.6966',
#   'longitud': '0.80211',
#   'geocoded_column': {'type': 'Point', 'coordinates': [0.80211, 42.6966]},
#   'emplacament': 'Elipòrt de VIelha',
#   'altitud': '1027',
#   'codi_municipi': '252430',
#   'nom_municipi': 'Vielha e Mijaran',
#   'codi_comarca': '39',
#   'nom_comarca': "Val d'Aran",
#   'codi_provincia': '25',
#   'nom_provincia': 'Lleida',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '2021-03-11T00:00:00.000'},
#  {'codi_estacio': 'VW',
#   'nom_estacio': 'Caldes de Montbui - Torre Marimon',
#   'codi_tipus': 'A',
#   'latitud': '41.61235',
#   'longitud': '2.17099',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.17099, 41.61235]},
#   'emplacament': 'Finca Torre Marimon',
#   'altitud': '164.5',
#   'codi_municipi': '080333',
#   'nom_municipi': 'Caldes de Montbui',
#   'codi_comarca': '41',
#   'nom_comarca': 'Vallès Oriental',
#   'codi_provincia': '8',
#   'nom_provincia': 'Barcelona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '1',
#   'nom_estat_ema': 'Desmantellada',
#   'data_inici': '1990-12-23T00:00:00.000',
#   'data_fi': '2007-03-08T00:00:00.000'},
#  {'codi_estacio': 'UO',
#   'nom_estacio': 'Fornells de la Selva',
#   'codi_tipus': 'A',
#   'latitud': '41.91461',
#   'longitud': '2.82069',
#   'geocoded_column': {'type': 'Point', 'coordinates': [2.82069, 41.91461]},
#   'emplacament': 'La Torre de Reset',
#   'altitud': '97',
#   'codi_municipi': '170736',
#   'nom_municipi': 'Fornells de la Selva',
#   'codi_comarca': '20',
#   'nom_comarca': 'Gironès',
#   'codi_provincia': '17',
#   'nom_provincia': 'Girona',
#   'codi_xarxa': '1',
#   'nom_xarxa': 'XEMA',
#   'codi_estat_ema': '2',
#   'nom_estat_ema': 'Operativa',
#   'data_inici': '1998-11-10T00:00:00.000'}]

# %% [markdown]
# Convertir conjunt de dades a dataframes

# %%
data_codis_variables = pd.DataFrame(data_codis_variables)
data_lectura = pd.DataFrame(data_lectura)
data_estacions = pd.DataFrame(data_estacions)
print("DATA CODIS VARIABLES SHAPE:",data_codis_variables.shape)
print("DATA LECTURA SHAPE:",data_lectura.shape)
print("DATA ESTACIONS SHAPE:",data_estacions.shape)
# Out:
# DATA CODIS VARIABLES SHAPE: (26, 6)
# DATA LECTURA SHAPE: (1000, 8)
# DATA ESTACIONS SHAPE: (240, 20)

# %%
display(data_codis_variables)
# Out:
#    codi_variable                                 nom_variable unitat  \
# 0             44                      Humitat relativa mínima      %
# 1             40                           Temperatura màxima     °C
# 2             46              Velocitat del vent a 2 m (esc.)    m/s
# 3             32                                  Temperatura     °C
# 4             72               Precipitació màxima en 1 minut     mm
# 5             51  Direcció de la ratxa màxima del vent a 10 m      °
# 6              3                      Humitat relativa màxima      %
# 7             30             Velocitat del vent a 10 m (esc.)    m/s
# 8             56                  Ratxa màxima del vent a 2 m    m/s
# 9             31                 Direcció de vent 10 m (m. 1)      °
# 10             1                   Pressió atmosfèrica màxima    hPa
# 11            42                           Temperatura mínima     °C
# 12             2                   Pressió atmosfèrica mínima    hPa
# 13            36                     Irradiància solar global   W/m²
# 14            38                         Gruix de neu a terra     cm
# 15            50                 Ratxa màxima del vent a 10 m    m/s
# 16            34                          Pressió atmosfèrica    hPa
# 17            59                             Irradiància neta   W/m²
# 18            47               Direcció del vent a 2 m (m. 1)      °
# 19            35                                 Precipitació     mm
# 20            48              Velocitat del vent a 6 m (esc.)    m/s
# 21            53                  Ratxa màxima del vent a 6 m    m/s
# 22            49               Direcció del vent a 6 m (m. 1)      °
# 23            33                             Humitat relativa      %
# 24            54   Direcció de la ratxa màxima del vent a 6 m      °
# 25            57   Direcció de la ratxa màxima del vent a 2 m      °
#
#      acronim codi_tipus_var decimals
# 0        HRn            DAT        0
# 1         Tx            DAT        1
# 2        VV2            DAT        1
# 3          T            DAT        1
# 4   PPTx1min            DAT        1
# 5     DVVx10            DAT        0
# 6        HRx            DAT        0
# 7       VV10            DAT        1
# 8       VVx2            DAT        1
# 9       DV10            DAT        0
# 10        Px            DAT        1
# 11        Tn            DAT        1
# 12        Pn            DAT        1
# 13        RS            DAT        0
# 14      GNEU            DAT        0
# 15     VVx10            DAT        1
# 16         P            DAT        1
# 17        RN            DAT        0
# 18       DV2            DAT        0
# 19       PPT            DAT        1
# 20       VV6            DAT        1
# 21      VVx6            DAT        1
# 22       DV6            DAT        0
# 23        HR            DAT        0
# 24     DVVx6            DAT        0
# 25     DVVx2            DAT        0

# %%
display(data_lectura)
# Out:
#                  id codi_estacio codi_variable             data_lectura  \
# 0    U2401901170400           U2            40  2017-01-19T04:00:00.000
# 1    U2421901170400           U2            42  2017-01-19T04:00:00.000
# 2    U2331901170400           U2            33  2017-01-19T04:00:00.000
# 3    U2441901170400           U2            44  2017-01-19T04:00:00.000
# 4    U2031901170400           U2             3  2017-01-19T04:00:00.000
# ..              ...          ...           ...                      ...
# 995  XT721901170400           XT            72  2017-01-19T04:00:00.000
# 996  XT361901170400           XT            36  2017-01-19T04:00:00.000
# 997  XT341901170400           XT            34  2017-01-19T04:00:00.000
# 998  XT321901170400           XT            32  2017-01-19T04:00:00.000
# 999  XT021901170400           XT             2  2017-01-19T04:00:00.000
#
#                  data_extrem valor_lectura codi_estat codi_base
# 0    2017-01-19T04:29:00.000          -1.3          V        SH
# 1    2017-01-19T04:12:00.000          -1.7          V        SH
# 2                        NaN            67          V        SH
# 3    2017-01-19T04:00:00.000            66          V        SH
# 4    2017-01-19T04:10:00.000            68          V        SH
# ..                       ...           ...        ...       ...
# 995  2017-01-19T04:00:00.000             0          V        SH
# 996                      NaN             0          V        SH
# 997                      NaN         940.4          V        SH
# 998                      NaN          -5.6          V        SH
# 999  2017-01-19T04:26:00.000         940.2          V        SH
#
# [1000 rows x 8 columns]

# %%
display(data_estacions)
# Out:
#     codi_estacio                         nom_estacio codi_tipus   latitud  \
# 0             DH                  Badalona - Mas Ram          A  41.47638
# 1             WQ            Montsec d'Ares (1.572 m)          A   42.0513
# 2             XJ                              Girona          A  41.98223
# 3             KX  la Roca del Vallès - ETAP Cardedeu          A  41.61865
# 4             VY                              Nulles          A  41.25095
# ..           ...                                 ...        ...       ...
# 235           DP                      Das - Aeròdrom          A  42.38605
# 236           XX               Anglesola - Tornabous          A  41.68835
# 237           YN                    Vielha - Elipòrt          A   42.6966
# 238           VW   Caldes de Montbui - Torre Marimon          A  41.61235
# 239           UO                Fornells de la Selva          A  41.91461
#
#     longitud                                    geocoded_column  \
# 0    2.25213  {'type': 'Point', 'coordinates': [2.25213, 41....
# 1    0.72952  {'type': 'Point', 'coordinates': [0.72952, 42....
# 2    2.80686  {'type': 'Point', 'coordinates': [2.80686, 41....
# 3    2.36114  {'type': 'Point', 'coordinates': [2.36114, 41....
# 4    1.29863  {'type': 'Point', 'coordinates': [1.29863, 41....
# ..       ...                                                ...
# 235   1.8664  {'type': 'Point', 'coordinates': [1.8664, 42.3...
# 236  1.04476  {'type': 'Point', 'coordinates': [1.04476, 41....
# 237  0.80211  {'type': 'Point', 'coordinates': [0.80211, 42....
# 238  2.17099  {'type': 'Point', 'coordinates': [2.17099, 41....
# 239  2.82069  {'type': 'Point', 'coordinates': [2.82069, 41....
#
#                                            emplacament altitud codi_municipi  \
# 0                    Urb. Mas Ram - Escola Pere Vergès     126        080155
# 1    Serra de la Corona - Centre d'Observació de l'...    1572        251961
# 2                               Horts de Santa Eugènia      72        170792
# 3           Planta tractament d'Aigües Ter - Llobregat     156        081810
# 4                                  Cooperativa agrària     240        430982
# ..                                                 ...     ...           ...
# 235                            Aeròdrom de la Cerdanya    1097        170617
# 236                                       Masia Mingot     291        252252
# 237                                  Elipòrt de VIelha    1027        252430
# 238                                Finca Torre Marimon   164.5        080333
# 239                                  La Torre de Reset      97        170736
#
#                 nom_municipi codi_comarca      nom_comarca codi_provincia  \
# 0                   Badalona           13       Barcelonès              8
# 1    Sant Esteve de la Sarga           25    Pallars Jussà             25
# 2                     Girona           20          Gironès             17
# 3         La Roca del Vallès           41  Vallès Oriental              8
# 4                     Nulles            1         Alt Camp             43
# ..                       ...          ...              ...            ...
# 235                      Das           15         Cerdanya             17
# 236                Tornabous           38           Urgell             25
# 237         Vielha e Mijaran           39       Val d'Aran             25
# 238        Caldes de Montbui           41  Vallès Oriental              8
# 239     Fornells de la Selva           20          Gironès             17
#
#     nom_provincia codi_xarxa nom_xarxa codi_estat_ema  nom_estat_ema  \
# 0       Barcelona          1      XEMA              1  Desmantellada
# 1          Lleida          1      XEMA              2      Operativa
# 2          Girona          1      XEMA              2      Operativa
# 3       Barcelona          1      XEMA              2      Operativa
# 4       Tarragona          1      XEMA              2      Operativa
# ..            ...        ...       ...            ...            ...
# 235        Girona          1      XEMA              2      Operativa
# 236        Lleida          1      XEMA              2      Operativa
# 237        Lleida          1      XEMA              2      Operativa
# 238     Barcelona          1      XEMA              1  Desmantellada
# 239        Girona          1      XEMA              2      Operativa
#
#                   data_inici                  data_fi
# 0    1998-03-23T00:00:00.000  2005-09-08T00:00:00.000
# 1    2003-06-17T00:00:00.000                      NaN
# 2    2010-09-15T00:00:00.000                      NaN
# 3    1996-01-05T00:00:00.000                      NaN
# 4    2000-09-18T00:00:00.000                      NaN
# ..                       ...                      ...
# 235  2001-05-22T00:00:00.000                      NaN
# 236  2013-08-06T00:00:00.000                      NaN
# 237  2021-03-11T00:00:00.000                      NaN
# 238  1990-12-23T00:00:00.000  2007-03-08T00:00:00.000
# 239  1998-11-10T00:00:00.000                      NaN
#
# [240 rows x 20 columns]

# %%
merged_df=pd.merge(data_lectura,data_codis_variables,on="codi_variable", how='inner' )
display(merged_df)
# Out:
#                  id codi_estacio codi_variable             data_lectura  \
# 0    U2401901170400           U2            40  2017-01-19T04:00:00.000
# 1    U2421901170400           U2            42  2017-01-19T04:00:00.000
# 2    U2331901170400           U2            33  2017-01-19T04:00:00.000
# 3    U2441901170400           U2            44  2017-01-19T04:00:00.000
# 4    U2031901170400           U2             3  2017-01-19T04:00:00.000
# ..              ...          ...           ...                      ...
# 995  XT721901170400           XT            72  2017-01-19T04:00:00.000
# 996  XT361901170400           XT            36  2017-01-19T04:00:00.000
# 997  XT341901170400           XT            34  2017-01-19T04:00:00.000
# 998  XT321901170400           XT            32  2017-01-19T04:00:00.000
# 999  XT021901170400           XT             2  2017-01-19T04:00:00.000
#
#                  data_extrem valor_lectura codi_estat codi_base  \
# 0    2017-01-19T04:29:00.000          -1.3          V        SH
# 1    2017-01-19T04:12:00.000          -1.7          V        SH
# 2                        NaN            67          V        SH
# 3    2017-01-19T04:00:00.000            66          V        SH
# 4    2017-01-19T04:10:00.000            68          V        SH
# ..                       ...           ...        ...       ...
# 995  2017-01-19T04:00:00.000             0          V        SH
# 996                      NaN             0          V        SH
# 997                      NaN         940.4          V        SH
# 998                      NaN          -5.6          V        SH
# 999  2017-01-19T04:26:00.000         940.2          V        SH
#
#                        nom_variable unitat   acronim codi_tipus_var decimals
# 0                Temperatura màxima     °C        Tx            DAT        1
# 1                Temperatura mínima     °C        Tn            DAT        1
# 2                  Humitat relativa      %        HR            DAT        0
# 3           Humitat relativa mínima      %       HRn            DAT        0
# 4           Humitat relativa màxima      %       HRx            DAT        0
# ..                              ...    ...       ...            ...      ...
# 995  Precipitació màxima en 1 minut     mm  PPTx1min            DAT        1
# 996        Irradiància solar global   W/m²        RS            DAT        0
# 997             Pressió atmosfèrica    hPa         P            DAT        1
# 998                     Temperatura     °C         T            DAT        1
# 999      Pressió atmosfèrica mínima    hPa        Pn            DAT        1
#
# [1000 rows x 13 columns]

# %%
df=pd.merge(merged_df,data_estacions,on="codi_estacio", how='inner' )
display(df)
# Out:
#                  id codi_estacio codi_variable             data_lectura  \
# 0    U2401901170400           U2            40  2017-01-19T04:00:00.000
# 1    U2421901170400           U2            42  2017-01-19T04:00:00.000
# 2    U2331901170400           U2            33  2017-01-19T04:00:00.000
# 3    U2441901170400           U2            44  2017-01-19T04:00:00.000
# 4    U2031901170400           U2             3  2017-01-19T04:00:00.000
# ..              ...          ...           ...                      ...
# 995  XT721901170400           XT            72  2017-01-19T04:00:00.000
# 996  XT361901170400           XT            36  2017-01-19T04:00:00.000
# 997  XT341901170400           XT            34  2017-01-19T04:00:00.000
# 998  XT321901170400           XT            32  2017-01-19T04:00:00.000
# 999  XT021901170400           XT             2  2017-01-19T04:00:00.000
#
#                  data_extrem valor_lectura codi_estat codi_base  \
# 0    2017-01-19T04:29:00.000          -1.3          V        SH
# 1    2017-01-19T04:12:00.000          -1.7          V        SH
# 2                        NaN            67          V        SH
# 3    2017-01-19T04:00:00.000            66          V        SH
# 4    2017-01-19T04:10:00.000            68          V        SH
# ..                       ...           ...        ...       ...
# 995  2017-01-19T04:00:00.000             0          V        SH
# 996                      NaN             0          V        SH
# 997                      NaN         940.4          V        SH
# 998                      NaN          -5.6          V        SH
# 999  2017-01-19T04:26:00.000         940.2          V        SH
#
#                        nom_variable unitat  ... codi_comarca  nom_comarca  \
# 0                Temperatura màxima     °C  ...            2  Alt Empordà
# 1                Temperatura mínima     °C  ...            2  Alt Empordà
# 2                  Humitat relativa      %  ...            2  Alt Empordà
# 3           Humitat relativa mínima      %  ...            2  Alt Empordà
# 4           Humitat relativa màxima      %  ...            2  Alt Empordà
# ..                              ...    ...  ...          ...          ...
# 995  Precipitació màxima en 1 minut     mm  ...           35     Solsonès
# 996        Irradiància solar global   W/m²  ...           35     Solsonès
# 997             Pressió atmosfèrica    hPa  ...           35     Solsonès
# 998                     Temperatura     °C  ...           35     Solsonès
# 999      Pressió atmosfèrica mínima    hPa  ...           35     Solsonès
#
#     codi_provincia nom_provincia codi_xarxa nom_xarxa codi_estat_ema  \
# 0               17        Girona          1      XEMA              2
# 1               17        Girona          1      XEMA              2
# 2               17        Girona          1      XEMA              2
# 3               17        Girona          1      XEMA              2
# 4               17        Girona          1      XEMA              2
# ..             ...           ...        ...       ...            ...
# 995             25        Lleida          1      XEMA              2
# 996             25        Lleida          1      XEMA              2
# 997             25        Lleida          1      XEMA              2
# 998             25        Lleida          1      XEMA              2
# 999             25        Lleida          1      XEMA              2
#
#     nom_estat_ema               data_inici data_fi
# 0       Operativa  1989-05-01T00:00:00.000     NaN
# 1       Operativa  1989-05-01T00:00:00.000     NaN
# 2       Operativa  1989-05-01T00:00:00.000     NaN
# 3       Operativa  1989-05-01T00:00:00.000     NaN
# 4       Operativa  1989-05-01T00:00:00.000     NaN
# ..            ...                      ...     ...
# 995     Operativa  2012-07-12T00:00:00.000     NaN
# 996     Operativa  2012-07-12T00:00:00.000     NaN
# 997     Operativa  2012-07-12T00:00:00.000     NaN
# 998     Operativa  2012-07-12T00:00:00.000     NaN
# 999     Operativa  2012-07-12T00:00:00.000     NaN
#
# [1000 rows x 32 columns]

# %%
df=pd.DataFrame(df)
display(df)
# Out:
#                  id codi_estacio codi_variable             data_lectura  \
# 0    U2401901170400           U2            40  2017-01-19T04:00:00.000
# 1    U2421901170400           U2            42  2017-01-19T04:00:00.000
# 2    U2331901170400           U2            33  2017-01-19T04:00:00.000
# 3    U2441901170400           U2            44  2017-01-19T04:00:00.000
# 4    U2031901170400           U2             3  2017-01-19T04:00:00.000
# ..              ...          ...           ...                      ...
# 995  XT721901170400           XT            72  2017-01-19T04:00:00.000
# 996  XT361901170400           XT            36  2017-01-19T04:00:00.000
# 997  XT341901170400           XT            34  2017-01-19T04:00:00.000
# 998  XT321901170400           XT            32  2017-01-19T04:00:00.000
# 999  XT021901170400           XT             2  2017-01-19T04:00:00.000
#
#                  data_extrem valor_lectura codi_estat codi_base  \
# 0    2017-01-19T04:29:00.000          -1.3          V        SH
# 1    2017-01-19T04:12:00.000          -1.7          V        SH
# 2                        NaN            67          V        SH
# 3    2017-01-19T04:00:00.000            66          V        SH
# 4    2017-01-19T04:10:00.000            68          V        SH
# ..                       ...           ...        ...       ...
# 995  2017-01-19T04:00:00.000             0          V        SH
# 996                      NaN             0          V        SH
# 997                      NaN         940.4          V        SH
# 998                      NaN          -5.6          V        SH
# 999  2017-01-19T04:26:00.000         940.2          V        SH
#
#                        nom_variable unitat  ... codi_comarca  nom_comarca  \
# 0                Temperatura màxima     °C  ...            2  Alt Empordà
# 1                Temperatura mínima     °C  ...            2  Alt Empordà
# 2                  Humitat relativa      %  ...            2  Alt Empordà
# 3           Humitat relativa mínima      %  ...            2  Alt Empordà
# 4           Humitat relativa màxima      %  ...            2  Alt Empordà
# ..                              ...    ...  ...          ...          ...
# 995  Precipitació màxima en 1 minut     mm  ...           35     Solsonès
# 996        Irradiància solar global   W/m²  ...           35     Solsonès
# 997             Pressió atmosfèrica    hPa  ...           35     Solsonès
# 998                     Temperatura     °C  ...           35     Solsonès
# 999      Pressió atmosfèrica mínima    hPa  ...           35     Solsonès
#
#     codi_provincia nom_provincia codi_xarxa nom_xarxa codi_estat_ema  \
# 0               17        Girona          1      XEMA              2
# 1               17        Girona          1      XEMA              2
# 2               17        Girona          1      XEMA              2
# 3               17        Girona          1      XEMA              2
# 4               17        Girona          1      XEMA              2
# ..             ...           ...        ...       ...            ...
# 995             25        Lleida          1      XEMA              2
# 996             25        Lleida          1      XEMA              2
# 997             25        Lleida          1      XEMA              2
# 998             25        Lleida          1      XEMA              2
# 999             25        Lleida          1      XEMA              2
#
#     nom_estat_ema               data_inici data_fi
# 0       Operativa  1989-05-01T00:00:00.000     NaN
# 1       Operativa  1989-05-01T00:00:00.000     NaN
# 2       Operativa  1989-05-01T00:00:00.000     NaN
# 3       Operativa  1989-05-01T00:00:00.000     NaN
# 4       Operativa  1989-05-01T00:00:00.000     NaN
# ..            ...                      ...     ...
# 995     Operativa  2012-07-12T00:00:00.000     NaN
# 996     Operativa  2012-07-12T00:00:00.000     NaN
# 997     Operativa  2012-07-12T00:00:00.000     NaN
# 998     Operativa  2012-07-12T00:00:00.000     NaN
# 999     Operativa  2012-07-12T00:00:00.000     NaN
#
# [1000 rows x 32 columns]

# %% [markdown]
# Elimnar columnes irrelavants o innecessaries:
# **nom_municipi**,
# **nom_provincia**,
# **nom_comarca**,
# **nom_estat_ema**,
# **nom_xarxa**

# %%
# Llista de columnes a eliminar
columnes_a_eliminar = [
    "nom_municipi", "nom_provincia", "nom_comarca", "nom_estat_ema", "nom_xarxa"
]

# Eliminar columnes
df = df.drop(columns=columnes_a_eliminar)

# %%
# Calcular el porcentaje de valores nulos por columna
porcentaje_nulos = df.isnull().sum() / len(df) * 100
# Filtrar columnas con 70% o más de valores nulos
columnas_mas_70_nulos = porcentaje_nulos[porcentaje_nulos >= 70].index

print("Columnas con 70% o más valores nulos:")
display(columnas_mas_70_nulos)
# Out:
# Columnas con 70% o más valores nulos:
# Index(['data_fi'], dtype='object')

# %%
# Eliminar columnes
df = df.drop(columns=columnas_mas_70_nulos)

# %%
# Ver los tipos de datos de todas las columnas en el DataFrame
print(df.dtypes)

# %%
numeric_columns = [
    "codi_variable", "valor_lectura", "codi_comarca", "codi_provincia", "codi_xarxa", "codi_estat_ema",
    "latitud", "longitud"
]

# Convertir las columnas a tipo numérico
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# %%
df.dtypes
# Out:
# id                  object
# codi_estacio        object
# codi_variable        int64
# data_lectura        object
# data_extrem         object
# valor_lectura      float64
# codi_estat          object
# codi_base           object
# nom_variable        object
# unitat              object
# acronim             object
# codi_tipus_var      object
# decimals            object
# nom_estacio         object
# codi_tipus          object
# latitud            float64
# longitud           float64
# geocoded_column     object
# emplacament         object
# altitud             object
# codi_municipi       object
# codi_comarca         int64
# codi_provincia       int64
# codi_xarxa           int64
# codi_estat_ema       int64
# data_inici          object
# dtype: object

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
display(df[categorical_columns])
# Out:
#                  id codi_estacio             data_lectura  \
# 0    U2401901170400           U2  2017-01-19T04:00:00.000
# 1    U2421901170400           U2  2017-01-19T04:00:00.000
# 2    U2331901170400           U2  2017-01-19T04:00:00.000
# 3    U2441901170400           U2  2017-01-19T04:00:00.000
# 4    U2031901170400           U2  2017-01-19T04:00:00.000
# ..              ...          ...                      ...
# 995  XT721901170400           XT  2017-01-19T04:00:00.000
# 996  XT361901170400           XT  2017-01-19T04:00:00.000
# 997  XT341901170400           XT  2017-01-19T04:00:00.000
# 998  XT321901170400           XT  2017-01-19T04:00:00.000
# 999  XT021901170400           XT  2017-01-19T04:00:00.000
#
#                  data_extrem codi_estat codi_base  \
# 0    2017-01-19T04:29:00.000          V        SH
# 1    2017-01-19T04:12:00.000          V        SH
# 2                        NaN          V        SH
# 3    2017-01-19T04:00:00.000          V        SH
# 4    2017-01-19T04:10:00.000          V        SH
# ..                       ...        ...       ...
# 995  2017-01-19T04:00:00.000          V        SH
# 996                      NaN          V        SH
# 997                      NaN          V        SH
# 998                      NaN          V        SH
# 999  2017-01-19T04:26:00.000          V        SH
#
#                        nom_variable unitat   acronim codi_tipus_var decimals  \
# 0                Temperatura màxima     °C        Tx            DAT        1
# 1                Temperatura mínima     °C        Tn            DAT        1
# 2                  Humitat relativa      %        HR            DAT        0
# 3           Humitat relativa mínima      %       HRn            DAT        0
# 4           Humitat relativa màxima      %       HRx            DAT        0
# ..                              ...    ...       ...            ...      ...
# 995  Precipitació màxima en 1 minut     mm  PPTx1min            DAT        1
# 996        Irradiància solar global   W/m²        RS            DAT        0
# 997             Pressió atmosfèrica    hPa         P            DAT        1
# 998                     Temperatura     °C         T            DAT        1
# 999      Pressió atmosfèrica mínima    hPa        Pn            DAT        1
#
#             nom_estacio codi_tipus  \
# 0    Sant Pere Pescador          A
# 1    Sant Pere Pescador          A
# 2    Sant Pere Pescador          A
# 3    Sant Pere Pescador          A
# 4    Sant Pere Pescador          A
# ..                  ...        ...
# 995             Solsona          A
# 996             Solsona          A
# 997             Solsona          A
# 998             Solsona          A
# 999             Solsona          A
#
#                                        geocoded_column  \
# 0    {'type': 'Point', 'coordinates': [3.0968, 42.1...
# 1    {'type': 'Point', 'coordinates': [3.0968, 42.1...
# 2    {'type': 'Point', 'coordinates': [3.0968, 42.1...
# 3    {'type': 'Point', 'coordinates': [3.0968, 42.1...
# 4    {'type': 'Point', 'coordinates': [3.0968, 42.1...
# ..                                                 ...
# 995  {'type': 'Point', 'coordinates': [1.51165, 41....
# 996  {'type': 'Point', 'coordinates': [1.51165, 41....
# 997  {'type': 'Point', 'coordinates': [1.51165, 41....
# 998  {'type': 'Point', 'coordinates': [1.51165, 41....
# 999  {'type': 'Point', 'coordinates': [1.51165, 41....
#
#                  emplacament altitud codi_municipi               data_inici
# 0    Mas Blanc, Mas Fages 17       4        171788  1989-05-01T00:00:00.000
# 1    Mas Blanc, Mas Fages 17       4        171788  1989-05-01T00:00:00.000
# 2    Mas Blanc, Mas Fages 17       4        171788  1989-05-01T00:00:00.000
# 3    Mas Blanc, Mas Fages 17       4        171788  1989-05-01T00:00:00.000
# 4    Mas Blanc, Mas Fages 17       4        171788  1989-05-01T00:00:00.000
# ..                       ...     ...           ...                      ...
# 995       Magatzem Municipal     691        252075  2012-07-12T00:00:00.000
# 996       Magatzem Municipal     691        252075  2012-07-12T00:00:00.000
# 997       Magatzem Municipal     691        252075  2012-07-12T00:00:00.000
# 998       Magatzem Municipal     691        252075  2012-07-12T00:00:00.000
# 999       Magatzem Municipal     691        252075  2012-07-12T00:00:00.000
#
# [1000 rows x 18 columns]

# %%
# Llista de columnes a eliminar
columnes_a_eliminar = [
    "geocoded_column", "unitat", "decimals"
]

# Eliminar columnes
df = df.drop(columns=columnes_a_eliminar)

# %%
display(df)
# Out:
#                  id codi_estacio  codi_variable             data_lectura  \
# 0    U2401901170400           U2             40  2017-01-19T04:00:00.000
# 1    U2421901170400           U2             42  2017-01-19T04:00:00.000
# 2    U2331901170400           U2             33  2017-01-19T04:00:00.000
# 3    U2441901170400           U2             44  2017-01-19T04:00:00.000
# 4    U2031901170400           U2              3  2017-01-19T04:00:00.000
# ..              ...          ...            ...                      ...
# 995  XT721901170400           XT             72  2017-01-19T04:00:00.000
# 996  XT361901170400           XT             36  2017-01-19T04:00:00.000
# 997  XT341901170400           XT             34  2017-01-19T04:00:00.000
# 998  XT321901170400           XT             32  2017-01-19T04:00:00.000
# 999  XT021901170400           XT              2  2017-01-19T04:00:00.000
#
#                  data_extrem  valor_lectura codi_estat codi_base  \
# 0    2017-01-19T04:29:00.000           -1.3          V        SH
# 1    2017-01-19T04:12:00.000           -1.7          V        SH
# 2                        NaN           67.0          V        SH
# 3    2017-01-19T04:00:00.000           66.0          V        SH
# 4    2017-01-19T04:10:00.000           68.0          V        SH
# ..                       ...            ...        ...       ...
# 995  2017-01-19T04:00:00.000            0.0          V        SH
# 996                      NaN            0.0          V        SH
# 997                      NaN          940.4          V        SH
# 998                      NaN           -5.6          V        SH
# 999  2017-01-19T04:26:00.000          940.2          V        SH
#
#                        nom_variable   acronim  ...   latitud longitud  \
# 0                Temperatura màxima        Tx  ...  42.17716  3.09680
# 1                Temperatura mínima        Tn  ...  42.17716  3.09680
# 2                  Humitat relativa        HR  ...  42.17716  3.09680
# 3           Humitat relativa mínima       HRn  ...  42.17716  3.09680
# 4           Humitat relativa màxima       HRx  ...  42.17716  3.09680
# ..                              ...       ...  ...       ...      ...
# 995  Precipitació màxima en 1 minut  PPTx1min  ...  41.98766  1.51165
# 996        Irradiància solar global        RS  ...  41.98766  1.51165
# 997             Pressió atmosfèrica         P  ...  41.98766  1.51165
# 998                     Temperatura         T  ...  41.98766  1.51165
# 999      Pressió atmosfèrica mínima        Pn  ...  41.98766  1.51165
#
#                  emplacament  altitud  codi_municipi codi_comarca  \
# 0    Mas Blanc, Mas Fages 17        4         171788            2
# 1    Mas Blanc, Mas Fages 17        4         171788            2
# 2    Mas Blanc, Mas Fages 17        4         171788            2
# 3    Mas Blanc, Mas Fages 17        4         171788            2
# 4    Mas Blanc, Mas Fages 17        4         171788            2
# ..                       ...      ...            ...          ...
# 995       Magatzem Municipal      691         252075           35
# 996       Magatzem Municipal      691         252075           35
# 997       Magatzem Municipal      691         252075           35
# 998       Magatzem Municipal      691         252075           35
# 999       Magatzem Municipal      691         252075           35
#
#     codi_provincia codi_xarxa  codi_estat_ema               data_inici
# 0               17          1               2  1989-05-01T00:00:00.000
# 1               17          1               2  1989-05-01T00:00:00.000
# 2               17          1               2  1989-05-01T00:00:00.000
# 3               17          1               2  1989-05-01T00:00:00.000
# 4               17          1               2  1989-05-01T00:00:00.000
# ..             ...        ...             ...                      ...
# 995             25          1               2  2012-07-12T00:00:00.000
# 996             25          1               2  2012-07-12T00:00:00.000
# 997             25          1               2  2012-07-12T00:00:00.000
# 998             25          1               2  2012-07-12T00:00:00.000
# 999             25          1               2  2012-07-12T00:00:00.000
#
# [1000 rows x 23 columns]

# %%
df.shape
# Out:
# (1000, 23)

# %%
df.dtypes
# Out:
# id                 object
# codi_estacio       object
# codi_variable       int64
# data_lectura       object
# data_extrem        object
# valor_lectura     float64
# codi_estat         object
# codi_base          object
# nom_variable       object
# acronim            object
# codi_tipus_var     object
# nom_estacio        object
# codi_tipus         object
# latitud           float64
# longitud          float64
# emplacament        object
# altitud            object
# codi_municipi      object
# codi_comarca        int64
# codi_provincia      int64
# codi_xarxa          int64
# codi_estat_ema      int64
# data_inici         object
# dtype: object

# %% [markdown]
# Guardem el conjunt de dades df

# %%
# Guarda el DataFrame como un archivo CSV
df.to_csv('dades_estacions.csv', index=False)
files.download('dades_estacions.csv')

# %%
# Guarda el DataFrame como un archivo CSV
certificats.to_csv('certificats_clean.csv', index=False)

files.download('certificats_clean.csv')

# %%
from google.colab import files

# %%
certificats_clean = pd.read_csv("/content/drive/MyDrive/HACKATHON_PROVES/certificats_clean.csv")

# %%
df = pd.read_csv("/content/drive/MyDrive/HACKATHON_PROVES/dades_estacions.csv")

# %%
for column in certificats_clean.columns:
    print(f"Valores únicos en la columna '{column}':")
    display(certificats_clean[column].unique())
    print("\n")
# Out:
# Valores únicos en la columna 'num_cas':
# array(['BMGDF6CPF', 'YT0MZMXMG', 'D4F3KFL7T', ..., 'L0C4VRTWB',
#        'YQF488ZVJ', '34XQR8KYB'], dtype=object)
# Valores únicos en la columna 'codi_poblacio':
# array([ 8001,  8114,  8019,  8020,  8123,  8245,  8102,  8161,  8156,
#         8147,  8002,  8003,  8118,  8180,  8279,  8281, 43019,  8101,
#         8197,  8068,  8120,  8004,  8005, 43038,  8184,  8124,  8134,
#         8046,  8033,  8187,  8088, 17033,  8006,  8007,  8040,  8155,
#         8015,  8121,  8029,  8172,  8030,  8035, 17103,  8163,  8203,
#         8107,  8008,  8009,  8073,  8153,  8010,  8113,  8061,  8204,
#         8022,  8192,  8218,  8011,  8092,  8012,  8141,  8191,  8013,
#         8014,  8094,  8282,  8194,  8205,  8301,  8096,  8296,  8126,
#         8268,  8266,  8904, 17022, 17095,  8169,  8125, 25120, 43148,
#         8263,  8200,  8289,  8016,  8166,  8089,  8017,  8037,  8067,
#         8298,  8283,  8018,  8196,  8202,  8047, 17079,  8270,  8104,
#        43037,  8260,  8252,  8217, 17160,  8307,  8077, 43153, 43136,
#         8211,  8074,  8238,  8051, 43155, 17006, 43028,  8198,  8221,
#        17142, 17118,  8076, 17009,  8208, 17152,  8231,  8179,  8056,
#         8041,  8159,  8105,  8209,  8305,  8162,  8248,  8230,  8049,
#         8240, 17048, 17068,  8136,  8264, 43020,  8158,  8032,  8244,
#        43171,  8273,  8284,  8154,  8224,  8267,  8043,  8110,  8028,
#         8122, 43123, 17202,  8106,  8259, 43047, 43014, 43004, 17137,
#        43051, 25207,  8058,  8119,  8214,  8135,  8021,  8144,  8052,
#         8023,  8902,  8210,  8302,  8024,  8025,  8026,  8027,  8286,
#         8219,  8031,  8060,  8275,  8034,  8235, 17155,  8036,  8038,
#         8039, 17023, 43100,  8086,  8042,  8234,  8145, 25124,  8044,
#         8165,  8045,  8181,  8048,  8050,  8053,  8127,  8262,  8069,
#         8054,  8290,  8291,  8055,  8183,  8072,  8057,  8059,  8228,
#         8062, 43140,  8063, 43163,  8064,  8065,  8066,  8269,  8295,
#        25010, 25021,  8178,  8070,  8071,  8223, 17034,  8148, 17193,
#         8075, 43131,  8157,  8078,  8079,  8080,  8081,  8082,  8083,
#         8220,  8084,  8085,  8304,  8288,  8115, 17013,  8087,  8090,
#         8091,  8140,  8175,  8093,  8206,  8095,  8097, 17146,  8098,
#         8274,  8099,  8199,  8100, 43145, 25040, 17039, 43142,  8250,
#         8103,  8143,  8108, 25203,  8109,  8255, 25023,  8171,  8111,
#         8112,  8116,  8149,  8182,  8242,  8213, 25148, 43109,  8117,
#         8215,  8150, 25179,  8222,  8251, 17117, 43074,  8212, 17147,
#        43111,  8236,  8294,  8189,  8292,  8128, 43093,  8129,  8130,
#         8131,  8237,  8510,  8132,  8133,  8137,  8207,  8138,  8139,
#         8142,  8146, 17215, 17114,  8285,  8151,  8152,  8261,  8167,
#        17184,  8300,  8160,  8226,  8164,  8287,  8168, 43055,  8170,
#         8174,  8176,  8177, 17213, 43905, 17030,  8905,  8185, 25189,
#         8188,  8190,  8193, 43907,  8195, 25052, 17015,  8201, 25027,
#        43013,  8229,  8216, 43043, 43137,  8227,  8225, 43095,  8232,
#         8233,  8239,  8249,  8241,  8243, 17047,  8246,  8253,  8254,
#         8256,  8257,  8258,  8276,  8265, 17089,  8293, 25209,  8271,
#         8272,  8278,  8277, 43903, 17141, 43161, 17199, 25243,  8280,
#        43060, 43120, 43024, 25113,  8306,  8297,  8299,  8303, 25051,
#         8308,  8901,  8903, 17001, 17002, 17003, 17004, 17049, 17005,
#        17069, 17061, 17201, 17024, 17084, 17094, 17007, 17008, 17180,
#        25245, 17083, 17164, 17010, 17011, 17062, 17012, 17124, 17014,
#        17035, 17139, 17092, 25072, 17016, 17066, 17218, 17018, 17019,
#        17074, 17020, 17028, 17021, 17148, 17189, 17027, 17025, 17026,
#        17029, 17031, 17032, 17140, 17076, 17055, 17209, 17036, 17037,
#        17038, 17091, 17040, 17041, 17042, 17043, 17167, 17044, 17046,
#        17181, 17195, 17233, 17050, 17051, 17052, 17175, 17178, 17151,
#        17054, 17056, 17057, 17058, 17060, 17206, 17211, 17075, 25225,
#        17217, 17063, 17064, 17065, 17221, 25019, 17234, 17067, 17070,
#        17071, 17073, 17187, 17077, 17078, 17169, 17087, 17186, 17130,
#        17080, 17081, 17082, 17085, 17086, 17088, 17090, 17093, 17177,
#        17172, 17145, 17097, 17098, 17099, 17100, 17101, 17102, 17105,
#        17207, 17106, 17107, 17109, 17110, 17111, 17112, 25112, 17115,
#        17116, 17132, 25011, 17119, 17120, 17128, 17121, 17123, 17125,
#        17126, 17129, 17902, 17133, 17161, 17134, 17135, 17136, 17138,
#        17188, 17143, 17144, 43906, 17200, 17149, 17150, 17158, 17153,
#        17154, 17157, 17159, 17162, 17163, 17165, 17166, 17168, 17170,
#        17171, 17173, 17174, 17198, 17176, 17191, 17182, 17183, 17185,
#        17208, 17190, 17192, 17194, 17196, 17197, 17225, 17204, 17210,
#        17203, 17205, 17212, 25137, 17214, 17216, 17901, 25001, 25002,
#        25003, 25217, 25047, 25004, 25005, 25006, 25007, 25211, 25008,
#        25228, 25231, 25009, 25013, 25012, 25014, 25015, 25016, 25017,
#        25020, 25022, 25024, 25086, 25025, 25046, 25029, 25030, 25031,
#        25032, 25033, 25034, 25035, 25036, 25037, 25038, 25039, 25220,
#        25069, 25041, 25042, 25183, 25043, 25173, 25044, 25045, 25049,
#        25048, 25050, 25127, 25053, 25055, 25056, 25057, 25058, 25059,
#        25121, 25060, 25061, 25062, 25156, 25063, 25064, 25067, 25068,
#        25070, 25071, 25110, 25073, 25074, 25075, 25076, 25077, 25078,
#        25079, 25081, 25082, 25085, 25192, 25087, 25088, 25089, 25092,
#        25093, 25094, 25096, 25122, 25097, 25098, 25099, 25100, 25101,
#        25102, 25103, 25104, 25105, 25109, 25111, 25114, 25115, 25234,
#        25118, 25119, 25210, 25212, 25125, 25240, 25133, 25230, 25135,
#        25123, 25126, 25128, 25129, 25130, 25131, 25132, 25134, 25136,
#        25252, 25158, 25138, 25139, 25140, 25141, 25143, 25142, 25145,
#        25146, 25149, 25150, 25151, 25163, 25152, 25153, 25154, 25155,
#        25157, 25911, 25161, 25193, 25164, 25166, 25165, 25167, 25168,
#        25169, 25170, 25171, 25172, 25174, 25175, 25176, 25177, 25180,
#        25181, 25182, 25185, 25186, 25190, 25215, 25191, 25194, 25196,
#        25197, 25200, 25201, 25202, 25239, 25906, 25204, 25205, 25206,
#        25208, 25216, 25905, 25244, 25218, 25219, 25221, 25222, 25223,
#        25224, 25226, 25227, 25907, 25232, 25233, 25238, 25242, 25247,
#        25248, 25249, 25250, 25251, 25253, 25254, 25255, 25901, 25902,
#        25903, 25904, 25908, 25909, 25910, 25912, 25913, 43001, 43002,
#        43003, 43156, 43053, 43005, 43006, 43102, 43007, 43008, 43009,
#        43010, 43011, 43042, 43012, 43017, 43092, 43104, 43062, 43078,
#        43904, 43901, 43015, 43016, 43031, 43018, 43117, 43086, 43021,
#        43029, 43022, 43023, 43025, 43026, 43027, 43132, 43030, 43081,
#        43032, 43033, 43034, 43035, 43036, 43050, 43039, 43114, 43166,
#        43125, 43040, 43041, 43129, 43126, 43044, 43045, 43046, 43048,
#        43049, 43052, 43054, 43082, 43056, 43057, 43058, 43059, 43061,
#        43063, 43064, 43071, 43065, 43066, 43067, 43068, 43138, 43069,
#        43070, 43072, 43073, 43159, 43075, 43076, 43077, 43133, 43079,
#        43080, 43083, 43084, 43085, 43088, 43178, 43089, 43090, 43091,
#        43162, 43099, 43119, 43094, 43096, 43097, 43098, 43165, 43101,
#        43116, 43103, 43105, 43106, 43107, 43108, 43170, 43902, 43110,
#        43112, 43113, 43115, 43118, 43141, 43121, 43150, 43122, 43128,
#        43124, 43127, 43130, 43135, 43134, 43139, 43143, 43144, 43146,
#        43147, 43157, 43164, 43149, 43151, 43152, 43154, 43158, 43160,
#        43167, 43168, 43169, 43176, 43172, 43173, 43174, 43175, 43177,
#        17903, 17230, 17222, 17224, 17220, 17223, 17226, 17227,  8247,
#        17232, 17228, 17096])
# Valores únicos en la columna 'codi_comarca':
# array([11., 33., 13.,  6., 40.,  7., 21., 30., 24., 41.,  8., 34., 14.,
#         3., 10., 17., 36., 20., 12., 22.,  9., 15.,  2., 28., 35., 42.,
#        nan, 31., 16.,  4., 19., 29., 27., 38., 26.,  1., 39.,  5., 32.,
#        23., 25., 18., 37.])
# Valores únicos en la columna 'codi_provincia':
# array([ 8, 43, 17, 25])
# Valores únicos en la columna 'referencia_cadastral':
# array(['8468003DF0986N0001TA', '8566417DF0986N0001PA',
#        '8367801DF0986N0015PX', ..., '6728033CG2762N0007PE',
#        '5852701CF6555S0017UL', '2603005DG3420S0001HA'], dtype=object)
# Valores únicos en la columna 'zona_climatica':
# array(['C2', 'D2', 'D1', nan, 'C3', 'E1', 'B3', 'D3'], dtype=object)
# Valores únicos en la columna 'metres_cadastre':
# array([ 164.  ,   70.53,   74.06, ..., 6738.  ,  483.17,  132.69])
# Valores únicos en la columna 'us_edifici':
# array(['Habitatge unifamiliar',
#        "Habitatge individual en bloc d'habitatges", 'Terciari',
#        "Bloc d'habitatges plurifamiliar", 'Vivienda unifamiliar',
#        'Vivienda individual en bloque de viviendas', 'Terciario',
#        "Bloc d'habitatges", 'Bloque de viviendas',
#        'Bloque de viviendas plurifamiliar', 'Habitatge Unifamiliar'],
#       dtype=object)
# Valores únicos en la columna 'qualificaci_de_consum_d':
# array(['D', 'E', 'G', 'F', 'C', 'B', 'A'], dtype=object)
# Valores únicos en la columna 'energia_prim_ria_no_renovable':
# array([151.3 , 192.11, 323.1 , ..., 758.78, 485.74, 567.58])
# Valores únicos en la columna 'qualificacio_d_emissions':
# array(['D', 'E', 'F', 'G', 'C', 'B', 'A'], dtype=object)
# Valores únicos en la columna 'emissions_de_co2':
# array([ 31.6 ,  49.59,  54.7 , ..., 162.72, 182.06, 195.69])
# Valores únicos en la columna 'consum_d_energia_final':
# array([  0.  ,  30.87, 156.79, ..., 365.33, 627.66, 384.68])
# Valores únicos en la columna 'cost_anual_aproximat_d_energia':
# array([   0.  , 2491.  ,  966.7 , ..., 2017.82, 4094.92, 1304.46])
# Valores únicos en la columna 'sistema_biomassa':
# array([ 0., nan,  1.])
# Valores únicos en la columna 'xarxa_districte':
# array([nan,  0.,  1.])
# Valores únicos en la columna 'energia_geotermica':
# array([ 0.,  1., nan])
# Valores únicos en la columna 'valor_aillaments':
# array([0.00e+00, 1.13e+00, 2.38e+00, 2.40e-01, 1.69e+00, 1.80e+00,
#        5.20e-01, 2.01e+00, 1.17e+00, 1.53e+00, 7.40e-01, 1.81e+00,
#        6.60e-01, 6.30e-01, 1.93e+00, 5.00e-01, 1.34e+00, 1.36e+00,
#        1.90e+00, 5.10e-01, 7.50e-01, 2.19e+00, 6.90e-01, 7.20e-01,
#        8.40e-01, 3.20e-01, 9.10e-01, 3.13e+00, 1.20e+00, 2.21e+00,
#        1.41e+00, 7.90e-01, 2.20e-01, 2.70e-01, 1.99e+00, 9.30e-01,
#        3.10e-01, 6.00e-01, 8.50e-01, 1.60e+00, 2.25e+00, 2.03e+00,
#        2.15e+00, 3.60e-01, 2.00e-01, 4.10e-01, 2.33e+00, 1.35e+00,
#        2.02e+00, 1.40e-01, 2.31e+00, 1.08e+00, 5.90e-01, 7.30e-01,
#        9.90e-01, 1.97e+00, 7.00e-01, 1.43e+00, 1.12e+00, 1.82e+00,
#        1.92e+00, 8.10e-01, 1.83e+00, 1.84e+00, 5.30e-01, 2.00e+00,
#        1.77e+00, 1.11e+00, 2.29e+00, 1.89e+00, 1.70e+00, 1.37e+00,
#        1.28e+00, 6.40e-01, 1.87e+00, 1.74e+00, 1.94e+00, 1.66e+00,
#        1.96e+00, 1.72e+00, 9.80e-01, 1.75e+00, 4.70e-01, 1.56e+00,
#        2.10e+00, 7.60e-01, 2.09e+00, 1.14e+00, 2.27e+00, 1.24e+00,
#        1.85e+00, 1.98e+00, 1.86e+00, 1.88e+00, 2.50e-01, 6.70e-01,
#        2.80e-01, 2.90e-01, 4.50e-01, 4.40e-01, 2.10e-01, 3.70e-01,
#        3.00e-01, 3.40e-01, 6.10e-01, 4.00e-01, 2.60e-01, 1.19e+00,
#        4.90e-01, 7.80e-01, 1.15e+00, 6.20e-01, 4.60e-01, 1.32e+00,
#        1.49e+00, 1.20e-01, 1.04e+00, 2.00e-02, 3.30e-01, 1.46e+00,
#        1.33e+00, 1.03e+00, 2.45e+00, 3.90e-01, 2.51e+00, 5.40e-01,
#        8.20e-01, 1.80e-01, 1.07e+00, 9.60e-01, 2.18e+00, 3.50e+00,
#        2.56e+00, 4.00e+00, 1.05e+00, 6.50e-01, 6.80e-01, 1.00e-02,
#        1.58e+00, 1.52e+00, 1.00e+00, 5.60e-01, 1.73e+00, 1.40e+00,
#        4.30e-01, 9.40e-01, 5.80e-01, 1.51e+00, 2.36e+00, 8.70e-01,
#        4.41e+00, 5.50e-01, 2.52e+00, 1.50e+00, 1.21e+00, 1.18e+00,
#        7.10e-01, 2.30e+00, 1.76e+00, 1.02e+00, 1.78e+00, 1.16e+00,
#        1.06e+00, 1.54e+00, 1.42e+00, 1.22e+00, 7.70e-01, 1.61e+00,
#        1.30e+00, 1.45e+00, 1.68e+00, 8.80e-01, 2.34e+00, 2.94e+00,
#        8.00e-01, 1.63e+00, 4.80e-01, 2.14e+00, 9.50e-01, 6.00e-02,
#        2.04e+00, 9.00e-01, 1.10e-01, 2.30e-01, 8.30e-01, 1.60e-01,
#        1.47e+00, 4.20e-01, 1.79e+00, 9.20e-01, 1.10e+00, 1.55e+00,
#        2.13e+00, 2.39e+00, 1.91e+00, 2.26e+00, 2.12e+00, 2.65e+00,
#        1.01e+00, 2.17e+00, 2.08e+00, 3.80e-01, 2.62e+00, 1.39e+00,
#        1.38e+00, 9.70e-01, 1.59e+00, 2.20e+00, 1.44e+00, 2.07e+00,
#        1.62e+00, 1.30e-01, 2.32e+00, 2.05e+00, 3.02e+00, 1.27e+00,
#        1.57e+00, 1.31e+00, 8.90e-01, 1.65e+00, 2.28e+00,      nan,
#        2.48e+00, 2.23e+00, 7.00e-02, 1.71e+00, 5.70e-01, 1.29e+00,
#        1.26e+00, 2.88e+00, 2.11e+00, 8.60e-01, 1.09e+00, 3.50e-01,
#        2.87e+00, 3.15e+00, 1.64e+00, 1.70e-01, 1.67e+00, 2.61e+00,
#        2.46e+00, 2.74e+00, 1.95e+00, 3.00e+00, 2.66e+00, 2.49e+00,
#        2.06e+00, 2.77e+00, 2.54e+00, 1.90e-01, 2.35e+00, 1.48e+00,
#        2.69e+00, 1.25e+00, 2.37e+00, 2.95e+00, 2.53e+00, 1.50e-01,
#        1.00e-01, 2.67e+00, 5.00e-02, 2.84e+00, 2.47e+00, 2.92e+00,
#        2.43e+00, 2.16e+00, 2.22e+00, 2.24e+00, 2.83e+00, 3.85e+00,
#        2.73e+00, 2.60e+00, 3.81e+00, 2.79e+00, 2.80e+00, 2.86e+00,
#        2.41e+00, 1.23e+00, 2.75e+00, 2.58e+00, 2.78e+00, 3.80e+00,
#        9.00e-02, 8.00e-02, 2.42e+00, 2.89e+00, 2.40e+00, 2.71e+00,
#        2.57e+00, 2.72e+00, 3.09e+00, 2.68e+00, 2.91e+00, 2.64e+00,
#        2.59e+00, 2.55e+00, 2.96e+00, 2.70e+00, 3.32e+00, 2.76e+00,
#        2.44e+00, 2.93e+00, 2.50e+00, 2.85e+00, 2.63e+00, 3.45e+00,
#        4.00e-02, 5.36e+00, 4.35e+00, 5.50e+00, 5.49e+00, 3.12e+00,
#        3.24e+00, 2.82e+00, 3.79e+00, 3.16e+00, 3.83e+00, 5.87e+00,
#        3.00e-02, 4.23e+00, 3.04e+00, 3.29e+00, 3.01e+00, 3.37e+00,
#        3.14e+00, 2.99e+00, 2.81e+00, 3.72e+00, 3.10e+00, 3.25e+00,
#        3.33e+00, 3.48e+00, 3.98e+00, 2.90e+00, 5.04e+00, 4.13e+00,
#        3.84e+00, 3.95e+00, 3.59e+00, 2.98e+00, 3.06e+00, 3.27e+00,
#        2.97e+00, 4.63e+00, 3.08e+00, 5.61e+00, 5.88e+00, 5.26e+00,
#        3.55e+00, 3.07e+00, 3.05e+00, 5.84e+00, 3.21e+00, 3.11e+00,
#        5.35e+00, 3.17e+00, 3.22e+00, 3.52e+00, 3.36e+00, 3.26e+00,
#        3.62e+00, 3.19e+00, 3.87e+00, 4.55e+00, 5.13e+00, 3.18e+00,
#        3.31e+00, 3.23e+00, 3.03e+00, 3.39e+00, 3.40e+00, 3.76e+00,
#        4.64e+00, 3.93e+00, 3.61e+00, 5.40e+00, 3.57e+00, 5.43e+00,
#        3.68e+00, 4.99e+00, 4.07e+00, 3.99e+00, 4.24e+00, 5.15e+00,
#        3.43e+00, 3.49e+00, 5.70e+00, 3.41e+00, 3.56e+00, 5.25e+00,
#        4.47e+00, 5.17e+00, 4.34e+00, 3.30e+00, 5.00e+00, 4.71e+00,
#        4.08e+00, 4.91e+00, 5.71e+00, 3.94e+00, 4.16e+00, 4.21e+00,
#        4.04e+00, 5.52e+00, 4.12e+00, 4.27e+00, 4.11e+00, 3.89e+00,
#        4.20e+00, 3.67e+00, 3.69e+00, 3.65e+00, 3.58e+00, 4.72e+00,
#        4.19e+00, 3.70e+00, 4.02e+00, 3.54e+00, 3.66e+00, 3.20e+00,
#        5.08e+00, 5.60e+00, 4.50e+00, 5.20e+00, 3.42e+00, 3.78e+00,
#        5.31e+00, 4.29e+00, 4.32e+00, 5.56e+00, 4.37e+00, 3.77e+00,
#        5.09e+00, 4.42e+00, 3.63e+00, 4.25e+00, 4.90e+00, 4.95e+00,
#        4.92e+00, 3.44e+00, 3.47e+00, 4.65e+00, 3.75e+00, 3.92e+00,
#        4.66e+00, 5.45e+00, 3.46e+00, 4.60e+00, 3.35e+00, 5.62e+00,
#        5.06e+00, 5.32e+00, 3.51e+00, 3.91e+00, 3.53e+00, 3.60e+00,
#        4.28e+00, 3.97e+00, 4.05e+00, 3.86e+00, 3.71e+00, 5.39e+00,
#        5.65e+00, 4.33e+00, 4.76e+00, 3.74e+00, 3.64e+00, 4.45e+00,
#        4.03e+00, 5.73e+00, 4.98e+00, 5.46e+00, 5.30e+00, 4.85e+00,
#        5.59e+00, 5.42e+00, 5.74e+00, 4.14e+00, 4.67e+00, 4.06e+00,
#        4.68e+00, 4.53e+00, 4.26e+00, 4.57e+00, 3.34e+00, 5.44e+00,
#        5.19e+00, 4.15e+00, 4.22e+00, 5.68e+00, 4.17e+00, 4.79e+00,
#        4.88e+00, 5.14e+00, 3.88e+00, 3.38e+00, 4.09e+00, 1.00e+02,
#        5.22e+00, 4.80e+00, 6.35e+00, 3.82e+00, 4.61e+00, 4.44e+00,
#        3.90e+00, 4.52e+00, 4.31e+00, 5.34e+00, 1.00e+01, 5.03e+00,
#        5.29e+00, 9.35e+00, 5.28e+00, 3.73e+00, 5.23e+00, 5.48e+00,
#        4.82e+00, 4.86e+00, 4.40e+00, 4.74e+00, 4.58e+00])
# Valores únicos en la columna 'valor_finestres':
# array([0.0000e+00, 4.3200e+00, 3.8300e+00, 3.4400e+00, 3.7200e+00,
#        4.2600e+00, 4.6100e+00, 3.7800e+00, 3.5400e+00, 4.7100e+00,
#        3.5700e+00, 5.0000e+00, 5.3700e+00, 5.7000e+00, 3.3100e+00,
#        3.6600e+00, 3.0800e+00, 3.7000e+00, 3.0700e+00, 5.1200e+00,
#        5.2300e+00, 3.2800e+00, 3.2000e+00, 3.9300e+00, 2.9600e+00,
#        3.8900e+00, 4.1600e+00, 3.9000e+00, 4.4400e+00, 4.3300e+00,
#        5.4900e+00, 5.0200e+00, 5.3600e+00, 3.8200e+00, 3.7300e+00,
#        5.2200e+00, 4.1400e+00, 5.2100e+00, 3.9400e+00, 2.9400e+00,
#        4.6700e+00, 5.2400e+00, 4.1100e+00, 4.2200e+00, 2.5700e+00,
#        4.0200e+00, 5.5700e+00, 4.3900e+00, 1.5500e+00, 3.3000e+00,
#        3.2900e+00, 3.9200e+00, 3.4900e+00, 5.1300e+00, 4.7500e+00,
#        4.5000e+00, 2.9700e+00, 4.6900e+00, 3.4200e+00, 4.0600e+00,
#        3.4500e+00, 4.0300e+00, 3.1600e+00, 4.0700e+00, 2.2100e+00,
#        4.0800e+00, 3.7100e+00, 4.3500e+00, 4.1800e+00, 3.5000e+00,
#        3.9800e+00, 4.2900e+00, 3.6700e+00, 4.0400e+00, 5.0500e+00,
#        3.3400e+00, 5.1700e+00, 3.4600e+00, 3.7700e+00, 4.0000e+00,
#        5.3000e+00, 4.2700e+00, 3.9500e+00, 4.4600e+00, 3.3600e+00,
#        3.5300e+00, 4.2000e+00, 3.3300e+00, 3.4700e+00, 4.9700e+00,
#        3.1100e+00, 3.3200e+00, 3.6000e+00, 5.1400e+00, 3.5100e+00,
#        1.5400e+00, 5.6400e+00, 4.5500e+00, 3.1900e+00, 3.9700e+00,
#        3.3800e+00, 2.8500e+00, 5.3400e+00, 4.0900e+00, 4.9900e+00,
#        3.9600e+00, 3.0200e+00, 3.8600e+00, 4.9100e+00, 5.5400e+00,
#        4.9500e+00, 4.1000e+00, 3.7600e+00, 4.8000e+00, 5.5900e+00,
#        3.6800e+00, 4.6800e+00, 1.3500e+00, 5.3500e+00, 4.2500e+00,
#        4.5800e+00, 3.9900e+00, 3.1300e+00, 3.8400e+00, 3.0300e+00,
#        3.8700e+00, 4.4900e+00, 4.5100e+00, 5.3900e+00, 4.1900e+00,
#        3.7500e+00, 5.4300e+00, 4.5300e+00, 4.1700e+00, 3.1400e+00,
#        4.7900e+00, 4.3800e+00, 2.5400e+00, 3.6300e+00, 4.4300e+00,
#        5.4700e+00, 2.6900e+00, 5.6600e+00, 4.9600e+00, 3.1500e+00,
#        4.9000e+00, 3.4000e+00, 3.2600e+00, 4.7000e+00, 4.1200e+00,
#        1.8100e+00, 2.9000e+00, 5.1600e+00, 4.8700e+00, 4.6400e+00,
#        3.0600e+00, 4.2300e+00, 4.3600e+00, 4.4100e+00, 4.0100e+00,
#        4.3700e+00, 4.9300e+00, 3.6100e+00, 3.3900e+00, 3.7400e+00,
#        5.3100e+00, 5.4000e+00, 4.6300e+00, 4.7400e+00, 3.0100e+00,
#        3.1800e+00, 3.2300e+00, 5.1800e+00, 5.0700e+00, 2.9800e+00,
#        3.5500e+00, 7.0000e-01, 5.2000e+00, 2.1200e+00, 1.8600e+00,
#        2.2400e+00, 1.0000e+08, 3.7900e+00, 1.7700e+00, 4.4500e+00,
#        3.2500e+00, 1.9900e+00, 3.6500e+00, 2.2500e+00, 1.9100e+00,
#        3.1000e+00, 2.2700e+00, 2.1800e+00, 2.9300e+00, 1.7400e+00,
#        5.3300e+00, 3.8800e+00, 2.1700e+00, 2.1300e+00, 3.2100e+00,
#        1.6600e+00, 1.9500e+00, 2.5200e+00, 2.1500e+00, 2.7800e+00,
#        3.3700e+00, 3.4800e+00, 2.0800e+00, 1.9200e+00, 3.3500e+00,
#        2.1400e+00, 1.9000e+00, 3.6400e+00, 2.0400e+00, 2.8300e+00,
#        1.9800e+00, 3.5600e+00, 2.8800e+00, 3.8000e+00, 7.3000e-01,
#        2.7300e+00, 2.9100e+00, 1.1600e+00, 4.6500e+00, 3.8500e+00,
#        1.8300e+00, 1.7500e+00, 2.1100e+00, 2.4800e+00, 2.0600e+00,
#        4.6000e+00, 2.7000e+00, 3.5200e+00, 2.7600e+00, 4.1300e+00,
#        1.2300e+00, 3.0000e+00, 1.2800e+00, 3.2200e+00, 4.2800e+00,
#        1.5200e+00, 4.8500e+00, 5.6500e+00, 5.4800e+00, 1.9400e+00,
#        4.3000e+00, 4.4200e+00, 3.4100e+00, 4.0500e+00, 4.8400e+00,
#        5.6300e+00, 3.9100e+00, 6.2700e+00, 2.2200e+00, 5.4600e+00,
#        4.7300e+00, 3.6200e+00, 5.0600e+00, 4.6200e+00, 2.1600e+00,
#        4.5900e+00, 5.0800e+00, 1.5800e+00, 4.5700e+00, 4.5200e+00,
#        3.5900e+00, 4.4700e+00, 2.8900e+00, 5.0300e+00, 1.3600e+00,
#        5.2500e+00, 4.2400e+00, 1.4100e+00, 3.4300e+00, 5.6100e+00,
#        4.8200e+00, 5.3800e+00, 4.4800e+00, 5.5200e+00, 2.9500e+00,
#        1.7200e+00, 3.5800e+00, 4.8100e+00, 3.8100e+00, 5.1000e+00,
#        3.0400e+00, 4.3100e+00, 5.0100e+00, 2.8100e+00, 2.6700e+00,
#        5.1100e+00, 4.8900e+00, 5.5600e+00, 2.6000e+00, 4.3400e+00,
#        3.0900e+00, 1.2900e+00, 4.7600e+00, 5.4500e+00, 2.5600e+00,
#        2.9900e+00, 2.2300e+00, 3.0500e+00, 4.5400e+00, 2.4200e+00,
#        2.8200e+00, 2.5500e+00, 5.2600e+00, 2.3700e+00, 4.4000e+00,
#        3.6900e+00, 1.5100e+00, 1.6800e+00, 1.7100e+00, 1.4400e+00,
#        4.2100e+00, 4.6600e+00, 2.5800e+00, 5.4100e+00, 4.9800e+00,
#        1.6300e+00, 1.1800e+00, 4.7700e+00, 1.5600e+00, 1.4800e+00,
#        2.7700e+00, 5.0400e+00, 2.8000e+00, 2.2000e+00, 2.0500e+00,
#        2.8700e+00, 1.9700e+00, 1.0000e+00, 4.8300e+00, 1.2000e+00,
#        5.2000e-01, 2.5100e+00, 5.6700e+00, 3.2700e+00, 2.0000e+00,
#        5.5800e+00, 4.9200e+00, 1.7300e+00, 2.0700e+00, 2.4500e+00,
#        1.7000e+00, 4.7800e+00, 1.5900e+00, 5.6900e+00, 5.6200e+00,
#        4.5600e+00, 3.1700e+00, 6.4300e+00, 5.7400e+00, 5.2900e+00,
#        2.9200e+00, 4.9400e+00, 2.3900e+00, 2.8400e+00, 1.8700e+00,
#               nan, 5.2700e+00, 1.4600e+00, 1.5700e+00, 1.6000e+00,
#        2.4400e+00, 1.4000e+00, 4.7200e+00, 2.0100e+00, 2.8600e+00,
#        2.4700e+00, 1.8500e+00, 1.9300e+00, 1.6400e+00, 1.7600e+00,
#        3.2400e+00, 2.1000e+00, 1.6900e+00, 1.1000e+00, 2.4600e+00,
#        2.2800e+00, 2.3300e+00, 5.5000e+00, 2.0200e+00, 2.6100e+00,
#        5.4200e+00, 5.6000e+00, 3.1200e+00, 2.3400e+00, 1.8800e+00,
#        5.1900e+00, 5.2800e+00, 2.5300e+00, 2.3500e+00, 5.0900e+00,
#        2.7400e+00, 4.8600e+00, 4.8800e+00, 4.1500e+00, 2.1900e+00,
#        2.6200e+00, 1.6500e+00, 2.2900e+00, 2.6600e+00, 1.2400e+00,
#        2.7200e+00, 2.4900e+00, 2.0900e+00, 1.8000e+00, 5.6800e+00,
#        2.6800e+00, 1.2600e+00, 5.4400e+00, 5.3200e+00, 1.2100e+00,
#        1.3300e+00, 1.3900e+00, 1.3200e+00, 1.3400e+00, 1.3000e+00,
#        2.3100e+00, 9.1000e-01, 1.6100e+00, 1.4300e+00, 2.2600e+00,
#        1.4900e+00, 2.4000e+00, 2.5900e+00, 8.2000e-01, 2.0300e+00,
#        2.6400e+00, 1.7800e+00, 1.5300e+00, 1.4500e+00, 1.6700e+00,
#        1.6200e+00, 1.0800e+00, 5.1500e+00, 2.4100e+00, 1.3700e+00,
#        1.0300e+00, 1.5000e+00, 5.5500e+00, 2.7900e+00, 1.4700e+00,
#        2.6500e+00, 5.5300e+00, 5.5100e+00, 2.7100e+00, 2.4300e+00,
#        1.8200e+00, 2.3200e+00, 4.5000e+01, 2.3000e+00, 2.6300e+00,
#        1.8400e+00, 2.3600e+00, 1.9600e+00, 1.3100e+00, 1.8900e+00,
#        1.1700e+00, 1.1900e+00, 1.1500e+00, 1.0100e+00, 5.8300e+00,
#        2.3800e+00, 1.3800e+00, 2.7500e+00, 1.2700e+00, 2.5000e+00,
#        9.7000e-01, 1.4200e+00, 1.2500e+00, 1.7900e+00, 1.0500e+00,
#        1.1400e+00, 1.2200e+00, 7.2000e-01, 7.9000e-01, 1.1300e+00,
#        6.7300e+00, 6.0300e+00, 6.0100e+00, 9.0000e-01, 6.5200e+00,
#        6.3700e+00, 6.9600e+00, 6.1400e+00, 1.1200e+00, 2.0000e+01,
#        1.1100e+00, 7.1000e-01, 6.4000e-01, 1.0000e+02, 6.3600e+00,
#        5.8900e+00, 8.7000e-01, 8.5600e+00, 7.0500e+00, 5.7800e+00,
#        6.1300e+00, 6.1200e+00, 6.5000e+00, 5.9900e+00, 6.8800e+00,
#        8.8000e-01, 9.2000e-01, 5.7600e+00, 1.6950e+01, 6.6600e+00,
#        8.5900e+00, 1.4760e+01, 6.8200e+00, 6.9200e+00, 5.8400e+00,
#        6.2900e+00, 6.3100e+00, 5.9000e+00, 6.9300e+00, 7.4000e-01,
#        3.3740e+01, 9.8000e-01, 6.4700e+00, 6.5000e-01, 8.9000e-01,
#        5.9600e+00, 6.7000e-01, 8.5000e-01, 6.2800e+00, 6.1600e+00,
#        5.8000e+00, 6.0600e+00, 7.0200e+00, 6.9700e+00, 6.6100e+00,
#        5.9400e+00, 6.7500e+00, 5.9700e+00, 1.1150e+01, 6.1000e+00,
#        1.0700e+00, 8.1000e-01, 6.5800e+00, 8.0000e-01, 6.6000e+00,
#        6.2100e+00, 6.4500e+00, 6.8600e+00, 1.0600e+00, 1.4960e+01,
#        6.5500e+00, 5.7100e+00, 6.5700e+00, 5.8700e+00, 6.0000e-01,
#        1.0000e+01, 7.8900e+00, 6.5900e+00, 5.0000e+01, 6.9900e+00,
#        1.0900e+00, 9.5100e+00, 6.6000e-01, 4.7000e-01, 5.7500e+00,
#        9.4000e-01, 9.6000e-01, 1.0400e+00, 9.9000e-01, 1.0200e+00,
#        8.4000e-01, 9.5000e-01, 5.9500e+00, 5.7200e+00, 6.6200e+00,
#        5.7900e+00, 1.2142e+02, 4.0000e-01, 5.8500e+00, 6.0200e+00,
#        6.0000e+00, 6.6300e+00, 6.0700e+00, 5.8800e+00, 5.9800e+00,
#        6.2600e+00, 6.2300e+00, 6.3200e+00, 9.3000e-01, 6.6400e+00,
#        5.8100e+00, 9.1800e+00, 5.7700e+00, 6.7700e+00, 7.0100e+00,
#        7.0700e+00, 1.7000e+01, 2.0000e-01, 2.5000e-01, 6.1100e+00,
#        6.6900e+00, 1.9210e+01, 7.5000e-01, 6.8100e+00, 7.8000e-01,
#        5.9100e+00, 4.9000e-01, 6.3000e+00, 6.1900e+00, 6.2000e+00,
#        5.9200e+00, 8.0300e+00, 6.6800e+00, 6.8300e+00, 8.4800e+00,
#        6.7100e+00, 6.7900e+00, 6.6500e+00, 6.4800e+00, 7.7000e-01,
#        8.6000e-01, 6.8000e-01, 6.2500e+00, 5.8200e+00, 5.9300e+00,
#        6.0400e+00, 5.8600e+00, 6.1700e+00, 6.8400e+00, 7.0800e+00,
#        6.9000e+00, 8.3000e-01, 1.8860e+01, 6.5100e+00, 4.0000e-02,
#        6.4600e+00, 1.0000e-01, 6.7800e+00, 6.0900e+00, 7.0300e+00,
#        4.2000e-01, 6.9500e+00, 6.2400e+00, 1.0500e+01, 8.8900e+00,
#        5.0000e-01, 6.7000e+00, 6.9000e-01, 5.8000e-01, 5.6000e-01,
#        3.6000e-01, 3.9980e+01, 6.3400e+00, 6.7200e+00, 6.9800e+00,
#        6.4000e+00, 4.1000e-01, 6.7600e+00, 6.3800e+00, 6.1000e-01,
#        6.4200e+00, 7.6000e-01, 7.8500e+00, 6.0800e+00, 7.0000e+00,
#        4.5000e-01, 6.4400e+00, 1.1221e+02, 2.7480e+01, 6.3000e-01,
#        3.5000e-01, 5.7000e-01, 7.8000e+00, 2.7860e+01, 3.7000e-01,
#        8.5180e+01, 5.9400e+01, 6.1800e+00, 6.3500e+00, 6.0000e-02,
#        7.4200e+00, 5.3000e-01, 7.5000e+00, 2.3000e-01, 5.7300e+00,
#        5.5000e-01, 6.2000e-01, 4.4000e-01, 1.7000e-01, 6.5400e+00,
#        1.5790e+01, 2.8000e-01, 4.6000e-01, 6.4100e+00, 6.5300e+00,
#        1.2000e+01, 8.0100e+00, 6.0500e+00, 8.8200e+00, 7.7800e+00,
#        2.1000e-01, 6.8000e+00, 7.3300e+00, 6.3900e+00, 9.9400e+00,
#        7.4000e+00, 7.2000e+00, 7.8100e+00, 7.2800e+00, 6.9100e+00,
#        6.4900e+00, 6.7400e+00, 6.3300e+00, 3.0000e-01, 6.8500e+00,
#        3.2000e-01, 6.5600e+00, 6.2200e+00, 6.1500e+00, 6.8900e+00,
#        6.6700e+00, 2.6820e+01, 1.9000e-01])
# Valores únicos en la columna 'valor_aillaments_cte':
# array([0.49, 0.41, 0.  , 0.37, 0.56])
# Valores únicos en la columna 'valor_finestres_cte':
# array([2.1, 1.8, 0. , 2.3])
# Valores únicos en la columna 'utm_x':
# array([408317.96, 408446.6 , 408154.13, ..., 326541.43, 432659.09,
#        432538.36])
# Valores únicos en la columna 'utm_y':
# array([4596612.14, 4596345.98, 4596596.29, ..., 4672685.66, 4640170.78,
#        4640179.33])
# Valores únicos en la columna 'tipus_tramit':
# array(['Edificis existents', 'Edificis existents acabats',
#        'Edificis acabats'], dtype=object)
# Valores únicos en la columna 'qualificaci_emissions':
# array([nan, 'E', 'C', 'D', 'F', 'G', 'B', 'A'], dtype=object)
# Valores únicos en la columna 'emissions_calefacci':
# array([   nan,  36.53,   6.97, ..., 119.09, 161.75, 170.93])
# Valores únicos en la columna 'qualificaci_emissions_1':
# array([nan, 'C', 'B', 'A', 'D', 'E', 'F', 'G'], dtype=object)
# Valores únicos en la columna 'emissions_refrigeraci':
# array([  nan,  1.64,  1.45, ..., 50.48, 37.14, 23.85])
# Valores únicos en la columna 'qualificaci_emissions_acs':
# array([nan, 'G', 'E', 'D', 'F', 'A', 'C', 'B'], dtype=object)
# Valores únicos en la columna 'emissions_acs':
# array([   nan,  10.99,  12.4 , ...,  74.69, 260.08, 202.36])
# Valores únicos en la columna 'emissions_enllumenament':
# array([   nan,   0.  ,   4.96, ...,  44.27, 229.26,  44.18])
# Valores únicos en la columna 'qualificaci_energia_calefacci':
# array([nan, 'E', 'C', 'F', 'D', 'G', 'B', 'A'], dtype=object)
# Valores únicos en la columna 'energia_calefacci':
# array([   nan, 172.5 ,  32.91, ..., 670.55, 613.21, 474.18])
# Valores únicos en la columna 'qualificaci_energia':
# array([nan, 'D', 'B', 'C', 'A', 'E', 'G', 'F'], dtype=object)
# Valores únicos en la columna 'energia_refrigeraci':
# array([   nan,   9.68,   8.56, ..., 219.27,  72.1 , 140.77])
# Valores únicos en la columna 'qualificaci_energia_acs':
# array([nan, 'G', 'F', 'E', 'B', 'C', 'D', 'A'], dtype=object)
# Valores únicos en la columna 'energia_acs':
# array([   nan,  64.88,  58.55, ..., 955.59, 190.56, 237.8 ])
# Valores únicos en la columna 'energia_enllumenament':
# array([   nan,   0.  ,  29.28, ...,  70.8 , 235.38, 260.82])
# Valores únicos en la columna 'qualificaci_energia_calefacci_1':
# array([nan, 'G', 'C', 'E', 'F', 'D', 'B', 'A'], dtype=object)
# Valores únicos en la columna 'energia_calefacci_demanda':
# array([   nan, 133.36,  25.44, ..., 262.14, 268.78, 362.75])
# Valores únicos en la columna 'qualificaci_energia_2':
# array([nan, 'D', 'B', 'C', 'A', 'E', 'G', 'F', '-'], dtype=object)
# Valores únicos en la columna 'energia_refrigeraci_demanda':
# array([   nan,   9.91,   8.76, ...,  73.48, 108.53, 144.09])
# Valores únicos en la columna 'ventilacio_us_residencial':
# array([  nan,  0.63,  0.86,  0.8 ,  1.65,  0.37,  0.76,  0.6 ,  0.82,
#         0.72,  1.15,  0.68,  0.55,  0.85,  0.78,  0.54,  0.97,  0.5 ,
#         0.16,  0.88,  0.81,  0.83,  1.  ,  0.52,  0.58,  0.77,  0.79,
#         1.68,  0.67,  0.48,  0.92,  2.46,  0.84,  0.75,  0.96,  0.74,
#         0.9 ,  0.3 ,  0.64,  0.98,  1.01,  0.22,  0.41,  0.93,  0.95,
#         0.4 ,  0.7 ,  0.31,  2.65,  0.91,  0.56,  0.51,  0.27,  0.36,
#         0.87,  0.66,  1.37,  0.94,  0.57,  0.49,  0.69,  1.2 ,  0.62,
#         0.99,  0.53,  0.45,  0.21,  0.73,  1.08,  1.81,  0.71,  0.24,
#         0.46,  1.5 ,  0.65,  1.04,  0.42,  0.44,  0.47,  1.02,  1.05,
#         0.33,  0.59,  0.89,  0.25,  0.61,  0.35,  1.6 ,  0.05,  0.38,
#         0.43,  1.3 ,  0.1 ,  0.18,  1.12,  1.11,  1.06,  0.01,  1.19,
#         1.86,  1.1 ,  1.26,  1.22,  1.27,  0.28,  0.06,  1.25,  1.43,
#         1.46,  0.2 ,  0.34,  0.29,  1.24,  1.47,  1.42,  1.21,  1.44,
#         1.94,  0.32,  1.63,  1.84,  1.38,  1.4 ,  0.14,  0.03,  2.84,
#         2.28,  1.17,  3.07,  2.23,  1.64,  2.56,  2.48,  0.23,  1.03,
#         1.07,  1.79,  0.26,  1.56,  2.62,  1.39,  1.23,  1.16,  0.39,
#         1.51,  1.34,  0.17,  1.18,  1.74,  1.33,  1.49,  1.35,  1.45,
#         1.9 ,  1.14,  1.54,  1.29,  1.36,  1.82,  1.76,  0.08,  1.7 ,
#         3.12,  1.09,  1.73,  1.28,  0.  ,  3.6 ,  2.02,  3.98,  4.34,
#         2.2 ,  1.8 ,  2.3 ,  1.71,  1.91,  1.13,  1.61,  1.32,  1.85,
#         2.39,  0.15,  1.31,  0.13,  1.55,  1.53,  1.62,  1.88,  2.19,
#         2.43,  1.75,  1.67,  1.69,  2.  ,  2.16,  3.8 ,  2.26,  1.59,
#         1.96,  2.92,  3.71,  1.77,  2.7 ,  0.09,  2.5 ,  2.9 ,  3.  ,
#         3.01,  2.11,  2.29,  1.48,  2.6 ,  2.09,  1.89,  3.7 ,  2.98,
#         2.27,  1.92,  1.99,  2.35,  2.52,  0.19,  1.52,  2.42,  1.41,
#         1.83,  2.85,  1.57,  2.03,  1.95,  1.58,  0.02,  3.84,  0.04,
#         3.49,  2.04,  0.11,  1.98,  1.87,  1.66,  2.49,  2.68,  2.51,
#         2.18,  3.79,  0.12,  1.72,  4.  ,  2.55,  0.07,  2.4 ,  3.09,
#         4.04,  3.03,  2.61,  2.1 ,  3.2 ,  2.25,  2.01,  3.5 ,  2.97,
#         2.66,  1.93,  1.78,  2.06,  2.44,  2.38,  2.86,  4.52,  2.93,
#         2.22, 10.  ,  3.31,  3.08,  2.89,  3.78,  2.87,  2.12,  2.36,
#         2.15,  2.07,  2.94,  2.21,  2.08,  5.43,  2.05,  4.8 ,  3.15,
#         2.45,  2.77,  3.16,  2.53,  2.41,  2.34,  2.82,  3.88,  3.19,
#         2.58,  2.47,  2.64,  2.72,  2.17,  2.24,  4.5 ,  5.  ,  3.36,
#         2.75,  3.05,  3.58,  2.59,  3.69,  2.73,  3.61,  3.38,  2.54,
#         2.13,  4.28,  4.75,  1.97,  3.14,  2.63,  2.83,  2.32,  2.67,
#         2.96,  2.37,  2.79,  3.59,  3.25,  2.8 ,  3.94,  3.66,  3.9 ,
#         2.91,  2.99,  2.14,  3.74,  4.1 ,  3.04,  3.56,  2.78,  3.47,
#         4.78,  3.42,  2.74,  2.81,  3.17,  2.33,  3.18,  3.4 ,  3.27,
#         2.76,  3.63,  3.51,  3.55,  3.62,  3.44,  3.39,  3.89,  3.02,
#         2.88,  3.21,  3.91])
# Valores únicos en la columna 'longitud':
# array([1.90126124, 1.90284311, 1.89930063, ..., 0.89941776, 2.18801537,
#        2.1865588 ])
# Valores únicos en la columna 'latitud':
# array([41.51589997, 41.51351771, 41.51573846, ..., 42.18709791,
#        41.9106154 , 41.9106821 ])
# Valores únicos en la columna 'georeferencia':
# array(['POINT (1.901261244149 41.515899972165)',
#        'POINT (1.902843106253 41.513517711742)',
#        'POINT (1.899300634003 41.51573845805)', ...,
#        'POINT (0.899417757899 42.187097913344)',
#        'POINT (2.188015372842 41.910615399107)',
#        'POINT (2.186558796006 41.91068209703)'], dtype=object)
# Valores únicos en la columna 'rehabilitacio_energetica':
# array([nan,  0.,  1.])
# Valores únicos en la columna 'data_entrada':
# array(['26/01/2016', '16/11/2015', '22/04/2016', ..., '27/08/2022',
#        '18/01/2025', '09/04/2023'], dtype=object)
# Valores únicos en la columna 'mundissec':
# array([8.0018010e+09, 8.0018010e+09, 8.0018010e+09, ..., 4.3907601e+10,
#        4.3907601e+10,           nan])

# %% [markdown]
# ### Censal sections

# %%
import requests

# URL de descarga del ZIP con los datos más recientes
url = "https://datacloud.icgc.cat/datacloud/bseccen_etrs89/shp/bseccenv10sh1f1_20230101_0.zip"

# Descargar el archivo ZIP
zip_path = "seccions_censals.zip"
response = requests.get(url)
with open(zip_path, "wb") as file:
    file.write(response.content)

print("Descarga completa:", zip_path)
# Out:
# Descarga completa: seccions_censals.zip

# %%
import zipfile
import os

# Extraer archivos en una carpeta
extract_path = "seccions_censals/"
with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("Archivos extraídos en:", extract_path)

# Listar archivos extraídos
print(os.listdir(extract_path))
# Out:
# Archivos extraídos en: seccions_censals/
# ['bseccenv10sh1f1_20230101_0.html', 'bseccenv10sh1f1_20230101_0.shx', 'bseccenv10sh1f1_20230101_0.sbx', 'bseccenv10sh1f1_20230101_0.prj', 'bseccenv10sh1f1_20230101_0.shp', 'bseccenv10sh1f1_20230101_0.dbf', 'bseccenv10sh1f1_20230101_0.sbn']

# %%
import geopandas as gpd

# Ruta del archivo SHP
shapefile_path = os.path.join(extract_path, "bseccenv10sh1f1_20230101_0.shp")

# Cargar el shapefile
seccions_censals = gpd.read_file(shapefile_path)
display(seccions_censals)
# Out:
#      MUNICIPI DISTRICTE SECCIO    MUNDISSEC  \
# 0      080018        01    001  08001801001
# 1      080018        01    002  08001801002
# 2      080018        01    003  08001801003
# 3      080018        01    004  08001801004
# 4      080018        01    005  08001801005
# ...       ...       ...    ...          ...
# 5103   439060        01    002  43906001002
# 5104   439076        01    001  43907601001
# 5105   439076        01    002  43907601002
# 5106   439076        01    003  43907601003
# 5107   439076        01    004  43907601004
#
#                                                geometry
# 0     POLYGON ((408792.512 4596753.053, 408797.803 4...
# 1     POLYGON ((408265.107 4597223.944, 408314.501 4...
# 2     POLYGON ((409202.138 4598159.531, 409215.4 459...
# 3     POLYGON ((408670.544 4598076.591, 408718.938 4...
# 4     POLYGON ((408075.992 4597102.922, 408093.732 4...
# ...                                                 ...
# 5103  MULTIPOLYGON (((308777.86 4521146.72, 308777.1...
# 5104  POLYGON ((347378.253 4554705.805, 347385.9 455...
# 5105  POLYGON ((348005.5 4553797.1, 348017.748 45537...
# 5106  POLYGON ((346261.4 4555701.4, 346505.5 4555732...
# 5107  POLYGON ((347613.675 4553644.65, 347514.585 45...
#
# [5108 rows x 5 columns]

# %%
print(seccions_censals.columns)
# Out:
# Index(['MUNICIPI', 'DISTRICTE', 'SECCIO', 'MUNDISSEC', 'geometry'], dtype='object')

# %%
display(seccions_censals.info())
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5108 entries, 0 to 5107
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MUNICIPI   5108 non-null   object
#  1   DISTRICTE  5108 non-null   object
#  2   SECCIO     5108 non-null   object
#  3   MUNDISSEC  5108 non-null   object
#  4   geometry   5108 non-null   geometry
# dtypes: geometry(1), object(4)
# memory usage: 199.7+ KB
# None

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Visualizar el mapa de las secciones censales
fig, ax = plt.subplots(figsize=(10, 10))

# Dibujar el mapa usando la geometría de las secciones censales
seccions_censals.plot(ax=ax, column='MUNDISSEC', cmap='Set3', edgecolor='black', legend=True)

plt.title('Mapa de Secciones Censales', fontsize=15)
plt.xlabel('Longitud')
plt.ylabel('Latitud')

# Mostrar el mapa
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Unir dataset de secciones censales con el dataset principal de certificados a través de MUNDISSEC, para tener información detallada por barrios o zonas más pequeñas dentro de la ciudad.

# %%
seccions_censals['MUNDISSEC']
# Out:
# 0       08001801001
# 1       08001801002
# 2       08001801003
# 3       08001801004
# 4       08001801005
#            ...
# 5103    43906001002
# 5104    43907601001
# 5105    43907601002
# 5106    43907601003
# 5107    43907601004
# Name: MUNDISSEC, Length: 5108, dtype: object

# %%
certificats_clean['mundissec'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1336925 entries, 0 to 1336924
# Series name: mundissec
# Non-Null Count    Dtype
# --------------    -----
# 1317571 non-null  float64
# dtypes: float64(1)
# memory usage: 10.2 MB

# %%
certificats_clean['mundissec'] = certificats_clean['mundissec'].astype('object')

# %%
# Convertir la columna 'mundissec' de tipo object a tipo float
certificats_clean['mundissec'] = pd.to_numeric(certificats_clean['mundissec'], errors='coerce')

# Verificar el cambio
print(certificats_clean.dtypes['mundissec'])
# Out:
# float64

# %%
# Convertir solo los valores no NaN a enteros (sin decimales) y luego a 'object'
certificats_clean['mundissec'] = certificats_clean['mundissec'].apply(lambda x: str(int(x)) if pd.notnull(x) else x)

# Verificar el cambio
print(certificats_clean.dtypes['mundissec'])
# Out:
# object

# %%
display(certificats_clean['mundissec'])
# Out:
# 0          8001801001
# 1          8001801001
# 2          8001801001
# 3          8001801001
# 4          8001801001
#               ...
# 1336920           NaN
# 1336921           NaN
# 1336922           NaN
# 1336923           NaN
# 1336924           NaN
# Name: mundissec, Length: 1336925, dtype: object

# %%
# Cambiar el nombre de la columna 'mundissec' a 'MUNDISSEC'
certificats_clean = certificats_clean.rename(columns={'mundissec': 'MUNDISSEC'})


print(certificats_clean.columns)
# Out:
# Index(['num_cas', 'codi_poblacio', 'codi_comarca', 'codi_provincia',
#        'referencia_cadastral', 'zona_climatica', 'metres_cadastre',
#        'us_edifici', 'qualificaci_de_consum_d',
#        'energia_prim_ria_no_renovable', 'qualificacio_d_emissions',
#        'emissions_de_co2', 'consum_d_energia_final',
#        'cost_anual_aproximat_d_energia', 'sistema_biomassa', 'xarxa_districte',
#        'energia_geotermica', 'valor_aillaments', 'valor_finestres',
#        'valor_aillaments_cte', 'valor_finestres_cte', 'utm_x', 'utm_y',
#        'tipus_tramit', 'qualificaci_emissions', 'emissions_calefacci',
#        'qualificaci_emissions_1', 'emissions_refrigeraci',
#        'qualificaci_emissions_acs', 'emissions_acs', 'emissions_enllumenament',
#        'qualificaci_energia_calefacci', 'energia_calefacci',
#        'qualificaci_energia', 'energia_refrigeraci', 'qualificaci_energia_acs',
#        'energia_acs', 'energia_enllumenament',
#        'qualificaci_energia_calefacci_1', 'energia_calefacci_demanda',
#        'qualificaci_energia_2', 'energia_refrigeraci_demanda',
#        'ventilacio_us_residencial', 'longitud', 'latitud', 'georeferencia',
#        'rehabilitacio_energetica', 'data_entrada', 'MUNDISSEC'],
#       dtype='object')

# %% [markdown]
# Unir certificats amd les dades de seccions censals

# %%
# Elimina ceros a la izquierda en MUNDISSEC
seccions_censals['MUNDISSEC'] = seccions_censals['MUNDISSEC'].str.lstrip('0')

# %%
display(certificats_clean['MUNDISSEC'])
display(seccions_censals['MUNDISSEC'])
# Out:
# 0          8001801001
# 1          8001801001
# 2          8001801001
# 3          8001801001
# 4          8001801001
#               ...
# 1336920           NaN
# 1336921           NaN
# 1336922           NaN
# 1336923           NaN
# 1336924           NaN
# Name: MUNDISSEC, Length: 1336925, dtype: object
# 0        8001801001
# 1        8001801002
# 2        8001801003
# 3        8001801004
# 4        8001801005
#            ...
# 5103    43906001002
# 5104    43907601001
# 5105    43907601002
# 5106    43907601003
# 5107    43907601004
# Name: MUNDISSEC, Length: 5108, dtype: object

# %%
certifcats_amb_seccions_censals = certificats_clean.merge(seccions_censals, on='MUNDISSEC', how='left')

# %%
display(certifcats_amb_seccions_censals)
# Out:
#            num_cas  codi_poblacio  codi_comarca  codi_provincia  \
# 0        BMGDF6CPF           8001          11.0               8
# 1        YT0MZMXMG           8001          11.0               8
# 2        D4F3KFL7T           8001          11.0               8
# 3        WNCV3P13M           8001          11.0               8
# 4        9K0RVRLD4           8001          11.0               8
# ...            ...            ...           ...             ...
# 1336920  WGVBWQCCS          43076          29.0              43
# 1336921  J20RTDPHP           8247          24.0               8
# 1336922  L0C4VRTWB          25215          25.0              25
# 1336923  YQF488ZVJ          43153          36.0              43
# 1336924  34XQR8KYB           8247          24.0               8
#
#          referencia_cadastral zona_climatica  metres_cadastre  \
# 0        8468003DF0986N0001TA             C2           164.00
# 1        8566417DF0986N0001PA             C2            70.53
# 2        8367801DF0986N0015PX             C2            74.06
# 3        8667613DF0986N0001WA             C2           102.00
# 4        8566002DF0986N0001QA             C2            33.00
# ...                       ...            ...              ...
# 1336920  000300300CF15D0001BI             C3            92.00
# 1336921  3005306DG3430N0048TL             D1            43.47
# 1336922  6728033CG2762N0007PE             D3            38.00
# 1336923  5852701CF6555S0017UL             B3            53.00
# 1336924  2603005DG3420S0001HA             D1            82.00
#
#                                         us_edifici qualificaci_de_consum_d  \
# 0                            Habitatge unifamiliar                       D
# 1                            Habitatge unifamiliar                       E
# 2        Habitatge individual en bloc d'habitatges                       G
# 3                            Habitatge unifamiliar                       E
# 4        Habitatge individual en bloc d'habitatges                       G
# ...                                            ...                     ...
# 1336920                      Habitatge unifamiliar                       E
# 1336921  Habitatge individual en bloc d'habitatges                       G
# 1336922  Habitatge individual en bloc d'habitatges                       G
# 1336923                                  Terciario                       E
# 1336924                      Habitatge unifamiliar                       G
#
#          energia_prim_ria_no_renovable  ...  longitud    latitud  \
# 0                               151.30  ...  1.901261  41.515900
# 1                               192.11  ...  1.902843  41.513518
# 2                               323.10  ...  1.899301  41.515738
# 3                                31.06  ...  1.903057  41.513610
# 4                               247.06  ...  1.902255  41.513983
# ...                                ...  ...       ...        ...
# 1336920                         237.78  ...       NaN        NaN
# 1336921                         369.80  ...  2.190868  41.912715
# 1336922                         340.45  ...  0.899886  42.185600
# 1336923                         567.58  ...  1.402140  41.135469
# 1336924                         455.13  ...  2.186559  41.910682
#
#                                   georeferencia  rehabilitacio_energetica  \
# 0        POINT (1.901261244149 41.515899972165)                       NaN
# 1        POINT (1.902843106253 41.513517711742)                       NaN
# 2         POINT (1.899300634003 41.51573845805)                       NaN
# 3        POINT (1.903056537018 41.513609820129)                       NaN
# 4        POINT (1.902255349697 41.513983450863)                       0.0
# ...                                         ...                       ...
# 1336920                                     NaN                       0.0
# 1336921  POINT (2.190867874724 41.912715454327)                       NaN
# 1336922  POINT (0.899885987426 42.185599824229)                       0.0
# 1336923  POINT (1.402139949595 41.135468924025)                       0.0
# 1336924   POINT (2.186558796006 41.91068209703)                       0.0
#
#          data_entrada   MUNDISSEC  MUNICIPI  DISTRICTE  SECCIO  \
# 0          26/01/2016  8001801001    080018         01     001
# 1          16/11/2015  8001801001    080018         01     001
# 2          22/04/2016  8001801001    080018         01     001
# 3          22/04/2015  8001801001    080018         01     001
# 4          02/06/2023  8001801001    080018         01     001
# ...               ...         ...       ...        ...     ...
# 1336920    07/01/2025         NaN       NaN        NaN     NaN
# 1336921    06/06/2016         NaN       NaN        NaN     NaN
# 1336922    30/09/2019         NaN       NaN        NaN     NaN
# 1336923    14/04/2021         NaN       NaN        NaN     NaN
# 1336924    11/08/2022         NaN       NaN        NaN     NaN
#
#                                                   geometry
# 0        POLYGON ((408792.512 4596753.053, 408797.803 4...
# 1        POLYGON ((408792.512 4596753.053, 408797.803 4...
# 2        POLYGON ((408792.512 4596753.053, 408797.803 4...
# 3        POLYGON ((408792.512 4596753.053, 408797.803 4...
# 4        POLYGON ((408792.512 4596753.053, 408797.803 4...
# ...                                                    ...
# 1336920                                               None
# 1336921                                               None
# 1336922                                               None
# 1336923                                               None
# 1336924                                               None
#
# [1336925 rows x 53 columns]

# %%
certifcats_amb_seccions_censals[['MUNDISSEC', 'MUNICIPI', 'DISTRICTE', 'SECCIO', 'geometry']].isna().sum()
# Out:
# MUNDISSEC    19354
# MUNICIPI     19354
# DISTRICTE    19354
# SECCIO       19354
# geometry     19354
# dtype: int64

# %%
# Filtra el DataFrame por MUNDISSEC igual a 8001801001
df_filtrado = certifcats_amb_seccions_censals[certifcats_amb_seccions_censals['MUNDISSEC'] == "8001801001"]

df_filtrado[['MUNDISSEC', 'MUNICIPI', 'DISTRICTE', 'SECCIO', 'geometry']]
# Out:
#       MUNDISSEC MUNICIPI DISTRICTE SECCIO  \
# 0    8001801001   080018        01    001
# 1    8001801001   080018        01    001
# 2    8001801001   080018        01    001
# 3    8001801001   080018        01    001
# 4    8001801001   080018        01    001
# ..          ...      ...       ...    ...
# 221  8001801001   080018        01    001
# 222  8001801001   080018        01    001
# 223  8001801001   080018        01    001
# 224  8001801001   080018        01    001
# 225  8001801001   080018        01    001
#
#                                               geometry
# 0    POLYGON ((408792.512 4596753.053, 408797.803 4...
# 1    POLYGON ((408792.512 4596753.053, 408797.803 4...
# 2    POLYGON ((408792.512 4596753.053, 408797.803 4...
# 3    POLYGON ((408792.512 4596753.053, 408797.803 4...
# 4    POLYGON ((408792.512 4596753.053, 408797.803 4...
# ..                                                 ...
# 221  POLYGON ((408792.512 4596753.053, 408797.803 4...
# 222  POLYGON ((408792.512 4596753.053, 408797.803 4...
# 223  POLYGON ((408792.512 4596753.053, 408797.803 4...
# 224  POLYGON ((408792.512 4596753.053, 408797.803 4...
# 225  POLYGON ((408792.512 4596753.053, 408797.803 4...
#
# [226 rows x 5 columns]

# %%
seccions_censals.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5108 entries, 0 to 5107
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MUNICIPI   5108 non-null   object
#  1   DISTRICTE  5108 non-null   object
#  2   SECCIO     5108 non-null   object
#  3   MUNDISSEC  5108 non-null   object
#  4   geometry   5108 non-null   geometry
# dtypes: geometry(1), object(4)
# memory usage: 199.7+ KB

# %%
certifcats_amb_seccions_censals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1336925 entries, 0 to 1336924
# Data columns (total 53 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   num_cas                          1336925 non-null  object
#  1   codi_poblacio                    1336925 non-null  int64
#  2   codi_comarca                     1336908 non-null  float64
#  3   codi_provincia                   1336925 non-null  int64
#  4   referencia_cadastral             1335859 non-null  object
#  5   zona_climatica                   1308447 non-null  object
#  6   metres_cadastre                  1336925 non-null  float64
#  7   us_edifici                       1336925 non-null  object
#  8   qualificaci_de_consum_d          1336925 non-null  object
#  9   energia_prim_ria_no_renovable    1336795 non-null  float64
#  10  qualificacio_d_emissions         1336925 non-null  object
#  11  emissions_de_co2                 1336800 non-null  float64
#  12  consum_d_energia_final           1308439 non-null  float64
#  13  cost_anual_aproximat_d_energia   1308439 non-null  float64
#  14  sistema_biomassa                 1323686 non-null  float64
#  15  xarxa_districte                  976758 non-null   float64
#  16  energia_geotermica               1336873 non-null  float64
#  17  valor_aillaments                 1308439 non-null  float64
#  18  valor_finestres                  1308439 non-null  float64
#  19  valor_aillaments_cte             1336925 non-null  float64
#  20  valor_finestres_cte              1336925 non-null  float64
#  21  utm_x                            1317867 non-null  float64
#  22  utm_y                            1317867 non-null  float64
#  23  tipus_tramit                     1336925 non-null  object
#  24  qualificaci_emissions            1258683 non-null  object
#  25  emissions_calefacci              1262803 non-null  float64
#  26  qualificaci_emissions_1          1213677 non-null  object
#  27  emissions_refrigeraci            1262802 non-null  float64
#  28  qualificaci_emissions_acs        1231860 non-null  object
#  29  emissions_acs                    1262803 non-null  float64
#  30  emissions_enllumenament          1228008 non-null  float64
#  31  qualificaci_energia_calefacci    1258731 non-null  object
#  32  energia_calefacci                1262802 non-null  float64
#  33  qualificaci_energia              1213702 non-null  object
#  34  energia_refrigeraci              1262683 non-null  float64
#  35  qualificaci_energia_acs          1233052 non-null  object
#  36  energia_acs                      1262802 non-null  float64
#  37  energia_enllumenament            1244495 non-null  float64
#  38  qualificaci_energia_calefacci_1  1259517 non-null  object
#  39  energia_calefacci_demanda        1262806 non-null  float64
#  40  qualificaci_energia_2            1213934 non-null  object
#  41  energia_refrigeraci_demanda      1262503 non-null  float64
#  42  ventilacio_us_residencial        424294 non-null   float64
#  43  longitud                         1317867 non-null  float64
#  44  latitud                          1317867 non-null  float64
#  45  georeferencia                    1317867 non-null  object
#  46  rehabilitacio_energetica         959377 non-null   float64
#  47  data_entrada                     1336925 non-null  object
#  48  MUNDISSEC                        1317571 non-null  object
#  49  MUNICIPI                         1317571 non-null  object
#  50  DISTRICTE                        1317571 non-null  object
#  51  SECCIO                           1317571 non-null  object
#  52  geometry                         1317571 non-null  geometry
# dtypes: float64(29), geometry(1), int64(2), object(21)
# memory usage: 540.6+ MB

# %%
certifcats_amb_seccions_censals = certifcats_amb_seccions_censals.drop(columns=['MUNICIPI'])

# %%
certificats_clean.to_csv('certificats_data_clean.csv', index=False)

files.download('certificats_data_clean.csv')

# %%
certificats_clean

# %%
# Guarda el DataFrame como un archivo CSV
seccions_censals.to_csv('seccions_censals.csv', index=False)

files.download('seccions_censals.csv')

# %% [markdown]
# ### Merge new data

# %% [markdown]
# -ENCUESTAS (2008): https://www.ine.es/dyngs/INEbase/es/operacion.htm?c=Estadistica_C&cid=1254736176950&menu=resultados&idp=1254735576508
#
# HABITATGE CATALUÑA EN DADES: https://analisi.transparenciacatalunya.cat/?sortBy=relevance&pageSize=20&category=Habitatge
# https://analisi.transparenciacatalunya.cat/d/hepw-33ik (PREU MITJA LLOGUER PER MUNICIPI)
#
# https://www.ine.es/dynt3/inebase/es/index.htm?padre=12385&capsel=12384# (IMPORTANT PER VISUALIZAR-HO)
# https://www.idescat.cat/indicadors/?id=aec&n=15384&lang=es (IMPORTANT)

# %% [markdown]
# ### Other questions

# %% [markdown]
# Quin és l’impacte de l’adopció d’energies renovables en les qualificacions d’eficiència energètica?

# %%
certificats_net = pd.read_csv("/content/drive/MyDrive/HACKATHON_PROVES/certificats_clean.csv")

# %%
display(certificats_net)
# Out:
#            num_cas  codi_poblacio  codi_comarca  codi_provincia  \
# 0        BMGDF6CPF           8001          11.0               8
# 1        YT0MZMXMG           8001          11.0               8
# 2        D4F3KFL7T           8001          11.0               8
# 3        WNCV3P13M           8001          11.0               8
# 4        9K0RVRLD4           8001          11.0               8
# ...            ...            ...           ...             ...
# 1336920  WGVBWQCCS          43076          29.0              43
# 1336921  J20RTDPHP           8247          24.0               8
# 1336922  L0C4VRTWB          25215          25.0              25
# 1336923  YQF488ZVJ          43153          36.0              43
# 1336924  34XQR8KYB           8247          24.0               8
#
#          referencia_cadastral zona_climatica  metres_cadastre  \
# 0        8468003DF0986N0001TA             C2           164.00
# 1        8566417DF0986N0001PA             C2            70.53
# 2        8367801DF0986N0015PX             C2            74.06
# 3        8667613DF0986N0001WA             C2           102.00
# 4        8566002DF0986N0001QA             C2            33.00
# ...                       ...            ...              ...
# 1336920  000300300CF15D0001BI             C3            92.00
# 1336921  3005306DG3430N0048TL             D1            43.47
# 1336922  6728033CG2762N0007PE             D3            38.00
# 1336923  5852701CF6555S0017UL             B3            53.00
# 1336924  2603005DG3420S0001HA             D1            82.00
#
#                                         us_edifici qualificaci_de_consum_d  \
# 0                            Habitatge unifamiliar                       D
# 1                            Habitatge unifamiliar                       E
# 2        Habitatge individual en bloc d'habitatges                       G
# 3                            Habitatge unifamiliar                       E
# 4        Habitatge individual en bloc d'habitatges                       G
# ...                                            ...                     ...
# 1336920                      Habitatge unifamiliar                       E
# 1336921  Habitatge individual en bloc d'habitatges                       G
# 1336922  Habitatge individual en bloc d'habitatges                       G
# 1336923                                  Terciario                       E
# 1336924                      Habitatge unifamiliar                       G
#
#          energia_prim_ria_no_renovable  ... energia_calefacci_demanda  \
# 0                               151.30  ...                       NaN
# 1                               192.11  ...                       NaN
# 2                               323.10  ...                       NaN
# 3                                31.06  ...                       NaN
# 4                               247.06  ...                    133.36
# ...                                ...  ...                       ...
# 1336920                         237.78  ...                     83.18
# 1336921                         369.80  ...                    149.82
# 1336922                         340.45  ...                    116.61
# 1336923                         567.58  ...                    212.42
# 1336924                         455.13  ...                    236.77
#
#          qualificaci_energia_2  energia_refrigeraci_demanda  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                            D                         9.91
# ...                        ...                          ...
# 1336920                      B                        12.65
# 1336921                    NaN                         0.02
# 1336922                      G                        57.57
# 1336923                      G                       144.09
# 1336924                      D                        12.24
#
#          ventilacio_us_residencial  longitud    latitud  \
# 0                              NaN  1.901261  41.515900
# 1                             0.63  1.902843  41.513518
# 2                              NaN  1.899301  41.515738
# 3                             0.63  1.903057  41.513610
# 4                              NaN  1.902255  41.513983
# ...                            ...       ...        ...
# 1336920                        NaN       NaN        NaN
# 1336921                       0.63  2.190868  41.912715
# 1336922                        NaN  0.899886  42.185600
# 1336923                        NaN  1.402140  41.135469
# 1336924                        NaN  2.186559  41.910682
#
#                                   georeferencia  rehabilitacio_energetica  \
# 0        POINT (1.901261244149 41.515899972165)                       NaN
# 1        POINT (1.902843106253 41.513517711742)                       NaN
# 2         POINT (1.899300634003 41.51573845805)                       NaN
# 3        POINT (1.903056537018 41.513609820129)                       NaN
# 4        POINT (1.902255349697 41.513983450863)                       0.0
# ...                                         ...                       ...
# 1336920                                     NaN                       0.0
# 1336921  POINT (2.190867874724 41.912715454327)                       NaN
# 1336922  POINT (0.899885987426 42.185599824229)                       0.0
# 1336923  POINT (1.402139949595 41.135468924025)                       0.0
# 1336924   POINT (2.186558796006 41.91068209703)                       0.0
#
#          data_entrada     mundissec
# 0          26/01/2016  8.001801e+09
# 1          16/11/2015  8.001801e+09
# 2          22/04/2016  8.001801e+09
# 3          22/04/2015  8.001801e+09
# 4          02/06/2023  8.001801e+09
# ...               ...           ...
# 1336920    07/01/2025           NaN
# 1336921    06/06/2016           NaN
# 1336922    30/09/2019           NaN
# 1336923    14/04/2021           NaN
# 1336924    11/08/2022           NaN
#
# [1336925 rows x 49 columns]

# %%
# Convertir a valores numéricos, forzando errores a NaN si hay problemas
certificats_net[cols_consumo] = certificats_net[cols_consumo].apply(pd.to_numeric, errors='coerce')

# %%
certificats_net[cols_consumo].describe().round(2)
# Out:
#        consum_d_energia_final  cost_anual_aproximat_d_energia  \
# count              1308439.00                      1308439.00
# mean                   132.75                          849.58
# std                    138.37                         9490.73
# min                   -123.75                        -2441.69
# 25%                     73.74                            8.63
# 50%                    129.44                           15.01
# 75%                    180.73                          500.72
# max                  60589.20                      5300218.69
#
#        energia_calefacci  energia_refrigeraci  energia_acs  \
# count         1262802.00           1262683.00   1262802.00
# mean              142.47                 8.76        52.89
# std                88.24                11.53       110.43
# min                 0.00                -4.73        -5.06
# 25%                89.42                 3.46        26.69
# 50%               129.31                 6.07        45.53
# 75%               180.98                11.05        68.51
# max             20919.03              3438.24     72154.64
#
#        energia_enllumenament  energia_calefacci_demanda  \
# count             1244495.00                 1262806.00
# mean                    5.70                      99.50
# std                    52.75                      49.42
# min                   -99.71                       0.00
# 25%                     0.00                      66.17
# 50%                     0.00                      92.28
# 75%                     0.00                     125.52
# max                 15657.01                    3622.30
#
#        energia_refrigeraci_demanda
# count                   1262503.00
# mean                          8.07
# std                           8.98
# min                           0.00
# 25%                           3.40
# 50%                           5.80
# 75%                          10.39
# max                        1573.10

# %%
# Columnas de consumo de energía
cols_consumo = [
    "consum_d_energia_final",
    "cost_anual_aproximat_d_energia",
    "energia_calefacci",
    "energia_refrigeraci",
    "energia_acs",
    "energia_enllumenament",
    "energia_calefacci_demanda",
    "energia_refrigeraci_demanda"
]

# Mostrar estadísticas descriptivas
certificats_net[cols_consumo].describe()
# Out:
#        consum_d_energia_final  cost_anual_aproximat_d_energia  \
# count            1.308439e+06                    1.308439e+06
# mean             1.327467e+02                    8.495791e+02
# std              1.383655e+02                    9.490725e+03
# min             -1.237500e+02                   -2.441690e+03
# 25%              7.374000e+01                    8.630000e+00
# 50%              1.294400e+02                    1.501000e+01
# 75%              1.807300e+02                    5.007200e+02
# max              6.058920e+04                    5.300219e+06
#
#        energia_calefacci  energia_refrigeraci   energia_acs  \
# count       1.262802e+06         1.262683e+06  1.262802e+06
# mean        1.424693e+02         8.763096e+00  5.289414e+01
# std         8.823625e+01         1.153429e+01  1.104300e+02
# min         0.000000e+00        -4.730000e+00 -5.060000e+00
# 25%         8.942000e+01         3.460000e+00  2.669000e+01
# 50%         1.293100e+02         6.070000e+00  4.553000e+01
# 75%         1.809800e+02         1.105000e+01  6.851000e+01
# max         2.091903e+04         3.438240e+03  7.215464e+04
#
#        energia_enllumenament  energia_calefacci_demanda  \
# count           1.244495e+06               1.262806e+06
# mean            5.701210e+00               9.950120e+01
# std             5.275293e+01               4.941546e+01
# min            -9.971000e+01               0.000000e+00
# 25%             0.000000e+00               6.617000e+01
# 50%             0.000000e+00               9.228000e+01
# 75%             0.000000e+00               1.255200e+02
# max             1.565701e+04               3.622300e+03
#
#        energia_refrigeraci_demanda
# count                 1.262503e+06
# mean                  8.071672e+00
# std                   8.979883e+00
# min                   0.000000e+00
# 25%                   3.400000e+00
# 50%                   5.800000e+00
# 75%                   1.039000e+01
# max                   1.573100e+03

# %%
# Seleccionar solo las columnas necesarias
df_selected = certificats_net[['qualificaci_de_consum_d', 'energia_prim_ria_no_renovable', 'qualificacio_d_emissions']]
display(df_selected)
# Out:
#         qualificaci_de_consum_d  energia_prim_ria_no_renovable  \
# 0                             D                         151.30
# 1                             E                         192.11
# 2                             G                         323.10
# 3                             E                          31.06
# 4                             G                         247.06
# ...                         ...                            ...
# 1336920                       E                         237.78
# 1336921                       G                         369.80
# 1336922                       G                         340.45
# 1336923                       E                         567.58
# 1336924                       G                         455.13
#
#         qualificacio_d_emissions
# 0                              D
# 1                              E
# 2                              F
# 3                              E
# 4                              F
# ...                          ...
# 1336920                        E
# 1336921                        F
# 1336922                        E
# 1336923                        E
# 1336924                        G
#
# [1336925 rows x 3 columns]

# %%
df = pd.read_csv("/content/drive/MyDrive/HACKATHON_PROVES/df.csv")

# %% [markdown]
# # Q1

# %% [markdown]
# # Q2

# %% [markdown]
# # Q3: ¿Cómo influye la dependencia de la red eléctrica en la eficiencia energética global?
#
# Para abordar esta pregunta, se analizará la dependencia de las viviendas con la red eléctrica a partir de diversas variables energéticas. Se desarrollará una métrica que permita clasificar los edificios como "dependientes" o "independientes", considerando factores clave relacionados con el consumo y la generación de energía.
#
# El análisis incluirá la conexión del edificio a una red de calefacción o refrigeración distrital (xarxa_districte), el uso de fuentes de energía alternativas como la geotermia (energia_geotermica) o biomasa (sistema_biomassa), y el consumo energético específico en calefacción (energia_calefacci), refrigeración (energia_refrigeraci), agua caliente sanitaria (energia_acs) e iluminación (energia_enllumenament). Además, se evaluará el consumo total de energía (consum_d_energia_final) y su costo anual aproximado (cost_anual_aproximat_d_energia) para determinar el nivel de dependencia de la red eléctrica.
#
# A partir de estos datos, se establecerán criterios para definir umbrales de dependencia, permitiendo clasificar los edificios y analizar cómo la variabilidad en estos factores influye en la eficiencia energética global.

# %%
df = pd.read_csv("/content/certificats_data_clean.csv")

# %%
sub_df = df[['energia_calefacci', 'energia_refrigeraci', 'energia_acs', 'energia_enllumenament', 'consum_d_energia_final', 'cost_anual_aproximat_d_energia']]

# %%
percentiles = sub_df.quantile([0.33, 0.66])

def calcular_dependencia(row):
    puntuacion = 0

    if row['xarxa_districte'] == 1:
        puntuacion -= 1
    if row['energia_geotermica'] == 1:
        puntuacion -= 2
    if row['sistema_biomassa'] == 1:
        puntuacion -= 2

    for var in ['energia_calefacci', 'energia_refrigeraci', 'energia_acs', 'energia_enllumenament', 'consum_d_energia_final']:
        if row[var] >= percentiles.loc[0.66, var]:
            puntuacion += 2
        elif row[var] >= percentiles.loc[0.33, var]:
            puntuacion += 1
        else:
            puntuacion -= 1

    if row['cost_anual_aproximat_d_energia'] >= percentiles.loc[0.66, 'cost_anual_aproximat_d_energia']:
        puntuacion += 2
    elif row['cost_anual_aproximat_d_energia'] >= percentiles.loc[0.33, 'cost_anual_aproximat_d_energia']:
        puntuacion += 1
    else:
        puntuacion -= 1

    return 1 if puntuacion > 2 else 0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df["dependencia_red"] = df.apply(calcular_dependencia, axis=1)

# %%
print(df[['referencia_cadastral', 'dependencia_red']].head())

# %% [markdown]
# # Q4

# %% [markdown]
# # ¿Qué zonas geográficas tienen el mayor potencial para la producción de energía renovable y la autosuficiencia?

# %% [markdown]
# Para responder a esta pregunta hemos decidido considerar dos factores: El primero, factores medioambientales; segundo, presupuesto disponible para el aprovechamiento de estos factores. Esto en razón a que de nada sirve que en un municipio se presenten factores medioambientales que propicien la producción de energías renovables pero su presupuesto para inversión en este rubro sea mínima, por lo cual probablemente no habrá aprovechamiento.
#
# Se decidió usar el nivel de desagregación del territorio por municipios para diferenciar entre zonas geográficas, ya que divide el territorio de forma óptima, así como también cada unidad (municipio) tiene la potestad de ejecutar su propio presupuesto. De igual forma, los datos medioambientales obtenidos están desagregados por municipios.
#
# Se tomaran entonces los datos obtenidos por diferentes estaciones meteorológicas esparcidas a lo largo de Catalunya y se calcularan los valores de velocidad promedio del viento (m/s) oobtenidos para cada municipio. Luego se uniran estos datos con el presupuesto que existe para cada zona, para encontrar la zona con niveles altos de presupuesto y factores ambientales propicios.

# %%
# !pip install pdfminer.six
# Out:
# Collecting pdfminer.six
#   Downloading pdfminer.six-20240706-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six) (3.4.1)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=36.0.0->pdfminer.six) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.22)
# Downloading pdfminer.six-20240706-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 32.7 MB/s eta 0:00:00
# Installing collected packages: pdfminer.six
# Successfully installed pdfminer.six-20240706

# %%
import pandas as pd

presupuesto = pd.read_csv("/content/drive/MyDrive/Hackathon/pressupostos_2024.csv", sep = ";", encoding="latin-1", on_bad_lines='skip')
#Filtrar la BD:
presupuesto_filtrado = presupuesto[(presupuesto["Tipus d'ens"] == 'Municipis') & ((presupuesto['Descripció estructura'] == "Administració general del medi ambient") | (presupuesto['Descripció estructura'] == "Medi ambient") | (presupuesto['Descripció estructura'] == "Protecció i millora del medi ambient"))]
#Sumar por cada ayuntamiento el presupuesto para invertir en medio ambiente (Cada uno de los tres programas):
presupuesto_filtrado["Previsió/Crèdits inicials consolidats"] = pd.to_numeric(presupuesto_filtrado["Previsió/Crèdits inicials consolidats"].str.replace(',', '.'), errors="coerce")
presupuesto_sumado = presupuesto_filtrado.groupby(["Codi de l'ens dependent/adscrit"])["Previsió/Crèdits inicials consolidats"].sum()

#Función para extraer los primeros 5 dígitos del código de municipio, ya que está concatenado con otros códigos diferentes
def obtener_codigo(codigo):
    codigo = str(codigo)
    if len(codigo)==9:
      try:
         return str(codigo)[:5]
      except:
         return codigo

    else:
      try:
         return str(codigo)[:6]
      except:
         return codigo

#Aplicar la función a presupuesto_sumado
presupuesto_sumado = presupuesto_sumado.reset_index()
presupuesto_sumado["codigo"] = presupuesto_sumado["Codi de l'ens dependent/adscrit"].apply(obtener_codigo)
presupuesto_final = presupuesto_sumado.drop(columns=["Codi de l'ens dependent/adscrit"])
presupuesto_final
# Out:
# <ipython-input-4-4aeb054b2ff6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   presupuesto_filtrado["Previsió/Crèdits inicials consolidats"] = pd.to_numeric(presupuesto_filtrado["Previsió/Crèdits inicials consolidats"].str.replace(',', '.'), errors="coerce")
#      Previsió/Crèdits inicials consolidats  codigo
# 0                               1634339.00   80018
# 1                                577763.19   80039
# 2                                784000.00   80044
# 3                                957700.00   80057
# 4                               1461721.74   80060
# ..                                     ...     ...
# 784                               82151.20  439039
# 785                              128600.00  439044
# 786                             3740871.38  439057
# 787                              449414.40  439060
# 788                              697500.00  439076
#
# [789 rows x 2 columns]

# %%
datos_estacion = pd.read_csv("/content/drive/MyDrive/Hackathon/Copia de dades_estacions.csv")
#Filtrar la BD:
datos_estacion_filtrados = datos_estacion[(datos_estacion["acronim"] == 'VV6') | (datos_estacion["acronim"] == 'VV10') | (datos_estacion["acronim"] == 'VV2') | (datos_estacion["acronim"] == 'VVx2') | (datos_estacion["acronim"] == 'VVx6') | (datos_estacion["acronim"] == 'VVx10')]
# Queremos sumar los 'valor_lectura' y luego dividir para sacar el promedio de todas las lecturas
datos_estacion_suma = datos_estacion_filtrados.groupby("codi_municipi")["valor_lectura"].sum()
datos_estacion_count = datos_estacion_filtrados.groupby("codi_municipi")["valor_lectura"].count()
datos_estacion_promedio = datos_estacion_suma / datos_estacion_count
datos_estacion_promedio
# Out:
# codi_municipi
# 80155      6.25
# 80229      2.60
# 80543      3.85
# 80620      2.10
# 80811     10.60
#           ...
# 431482     5.90
# 431541     0.75
# 431573     0.65
# 431785     2.25
# 439044     4.85
# Name: valor_lectura, Length: 63, dtype: float64

# %%
presupuesto_final['codigo'] = pd.to_numeric(presupuesto_final['codigo'], errors='coerce')
#Left join de presuspuesto_final y datos_estacion_suma:
merged_df = pd.merge(presupuesto_final.reset_index(), datos_estacion_promedio, left_on='codigo', right_on='codi_municipi', how='left')
merged_df.fillna(0, inplace=True)
merged_df
# Out:
#      index  Previsió/Crèdits inicials consolidats  codigo  valor_lectura
# 0        0                             1634339.00   80018           0.00
# 1        1                              577763.19   80039           0.00
# 2        2                              784000.00   80044           0.00
# 3        3                              957700.00   80057           0.00
# 4        4                             1461721.74   80060           0.00
# ..     ...                                    ...     ...            ...
# 784    784                               82151.20  439039           0.00
# 785    785                              128600.00  439044           4.85
# 786    786                             3740871.38  439057           0.00
# 787    787                              449414.40  439060           0.00
# 788    788                              697500.00  439076           0.00
#
# [789 rows x 4 columns]

# %%
merged_df['codigo'] = pd.to_numeric(merged_df['codigo'], errors='coerce')
merged_df.to_csv('merged_data.csv', index=False)
from google.colab import files
files.download('merged_data.csv')
